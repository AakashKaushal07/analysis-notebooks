# %%
import pandas as pd
from datetime import datetime
import soccerdata as sd
import os,sys,requests
import sql_connector as SQL
import config

import matplotlib.pyplot as plt
from mplsoccer import Pitch,VerticalPitch
PITCH_SIZE = (120,80,12.75)

FOTMOB_URL = config.getFotMobUrls()
FOTMOB_LEAGUE = config.getFotMobLeagueDict()
CONFIG = config.getGeneralConfig()


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)
import warnings

# Suppress the SettingWithCopyWarning
warnings.simplefilter(action='ignore', category='SettingWithCopyWarning')
warnings.simplefilter(action='ignore', category='DeprecationWarning')
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5696\3170656805.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# [04/04/24 02:19:55] INFO     Custom team name replacements loaded from                                _config.py:82
#                              C:\Users\Hp\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    _config.py:204
#                              C:\Users\Hp\soccerdata\config\league_dict.json.

# %%
matches = SQL.execute_select_query("select * from match_schedule where id > 58995")

# %%
matches
# Out:
# [{'id': 58996,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 4),
#   'home_team': 'Chaves',
#   'away_team': 'Farense',
#   'score': '1–1',
#   'whoscored_id': 1748557,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748557/Live/Portugal-Liga-Portugal-2023-2024-Chaves-Farense',
#   'fbref_id': '541b66ca',
#   'fbref_url': '/en/matches/541b66ca/Chaves-Farense-February-4-2024-Primeira-Liga',
#   'fotmob_id': 4233425,
#   'fotmob_url': '/matches/farense-vs-chaves/2249c1#4233425',
#   'read_status': 'NotStarted'},
#  {'id': 58997,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 4),
#   'home_team': 'Vizela',
#   'away_team': 'Vitoria de Guimaraes',
#   'score': '0–1',
#   'whoscored_id': 1748561,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748561/Live/Portugal-Liga-Portugal-2023-2024-Vizela-Vitoria-de-Guimaraes',
#   'fbref_id': 'f0449e9f',
#   'fbref_url': '/en/matches/f0449e9f/Vizela-Vitoria-Guimaraes-February-4-2024-Primeira-Liga',
#   'fotmob_id': 4233432,
#   'fotmob_url': '/matches/vizela-vs-vitoria-de-guimaraes/19lguw#4233432',
#   'read_status': 'NotStarted'},
#  {'id': 58998,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 4),
#   'home_team': 'Benfica',
#   'away_team': 'Gil Vicente',
#   'score': '3–0',
#   'whoscored_id': 1748574,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748574/Live/Portugal-Liga-Portugal-2023-2024-Benfica-Gil-Vicente',
#   'fbref_id': 'f90383d8',
#   'fbref_url': '/en/matches/f90383d8/Benfica-Gil-Vicente-FC-February-4-2024-Primeira-Liga',
#   'fotmob_id': 4233422,
#   'fotmob_url': '/matches/gil-vicente-vs-benfica/35mims#4233422',
#   'read_status': 'NotStarted'},
#  {'id': 58999,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 4),
#   'home_team': 'Estoril',
#   'away_team': 'Estrela da Amadora',
#   'score': '1–0',
#   'whoscored_id': 1748572,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748572/Live/Portugal-Liga-Portugal-2023-2024-Estoril-Estrela-da-Amadora',
#   'fbref_id': 'f42e8b9f',
#   'fbref_url': '/en/matches/f42e8b9f/Estoril-Estrela-February-4-2024-Primeira-Liga',
#   'fotmob_id': 4233421,
#   'fotmob_url': '/matches/estoril-vs-estrela-da-amadora/7gzq45jx#4233421',
#   'read_status': 'NotStarted'},
#  {'id': 59000,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 4),
#   'home_team': 'Braga',
#   'away_team': 'Moreirense',
#   'score': '1–0',
#   'whoscored_id': 1748580,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748580/Live/Portugal-Liga-Portugal-2023-2024-Braga-Moreirense',
#   'fbref_id': '03180431',
#   'fbref_url': '/en/matches/03180431/Braga-Moreirense-February-4-2024-Primeira-Liga',
#   'fotmob_id': 4233424,
#   'fotmob_url': '/matches/moreirense-vs-braga/2v4q4e#4233424',
#   'read_status': 'NotStarted'},
#  {'id': 59001,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 5),
#   'home_team': 'Casa Pia AC',
#   'away_team': 'Boavista',
#   'score': '0–0',
#   'whoscored_id': 1748569,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748569/Live/Portugal-Liga-Portugal-2023-2024-Casa-Pia-AC-Boavista',
#   'fbref_id': '137cdc50',
#   'fbref_url': '/en/matches/137cdc50/Casa-Pia-Boavista-February-5-2024-Primeira-Liga',
#   'fotmob_id': 4233420,
#   'fotmob_url': '/matches/boavista-vs-casa-pia-ac/b9gkeus#4233420',
#   'read_status': 'NotStarted'},
#  {'id': 59002,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 9),
#   'home_team': 'Estrela da Amadora',
#   'away_team': 'Portimonense',
#   'score': '3–0',
#   'whoscored_id': 1748570,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748570/Live/Portugal-Liga-Portugal-2023-2024-Estrela-da-Amadora-Portimonense',
#   'fbref_id': 'f8c179f7',
#   'fbref_url': '/en/matches/f8c179f7/Estrela-Portimonense-February-9-2024-Primeira-Liga',
#   'fotmob_id': 4233456,
#   'fotmob_url': '/matches/portimonense-vs-estrela-da-amadora/7hy66uf0#4233456',
#   'read_status': 'NotStarted'},
#  {'id': 59003,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 10),
#   'home_team': 'Farense',
#   'away_team': 'Famalicao',
#   'score': '1–1',
#   'whoscored_id': 1748544,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748544/Live/Portugal-Liga-Portugal-2023-2024-Farense-Famalicao',
#   'fbref_id': 'ae738aef',
#   'fbref_url': '/en/matches/ae738aef/Farense-Famalicao-February-10-2024-Primeira-Liga',
#   'fotmob_id': 4233430,
#   'fotmob_url': '/matches/famalicao-vs-farense/hdexd#4233430',
#   'read_status': 'NotStarted'},
#  {'id': 59004,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 10),
#   'home_team': 'Moreirense',
#   'away_team': 'Chaves',
#   'score': '1–0',
#   'whoscored_id': 1748541,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748541/Live/Portugal-Liga-Portugal-2023-2024-Moreirense-Chaves',
#   'fbref_id': 'eb3b7359',
#   'fbref_url': '/en/matches/eb3b7359/Moreirense-Chaves-February-10-2024-Primeira-Liga',
#   'fotmob_id': 4233429,
#   'fotmob_url': '/matches/moreirense-vs-chaves/2prupx#4233429',
#   'read_status': 'NotStarted'},
#  {'id': 59005,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 10),
#   'home_team': 'Boavista',
#   'away_team': 'Estoril',
#   'score': '2–1',
#   'whoscored_id': 1748563,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748563/Live/Portugal-Liga-Portugal-2023-2024-Boavista-Estoril',
#   'fbref_id': '87c77766',
#   'fbref_url': '/en/matches/87c77766/Boavista-Estoril-February-10-2024-Primeira-Liga',
#   'fotmob_id': 4233447,
#   'fotmob_url': '/matches/estoril-vs-boavista/28m3kx#4233447',
#   'read_status': 'NotStarted'},
#  {'id': 59006,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 11),
#   'home_team': 'Rio Ave',
#   'away_team': 'Casa Pia AC',
#   'score': '1–0',
#   'whoscored_id': 1748546,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748546/Live/Portugal-Liga-Portugal-2023-2024-Rio-Ave-Casa-Pia-AC',
#   'fbref_id': '1da4a1c3',
#   'fbref_url': '/en/matches/1da4a1c3/Rio-Ave-Casa-Pia-February-11-2024-Primeira-Liga',
#   'fotmob_id': 4233431,
#   'fotmob_url': '/matches/rio-ave-vs-casa-pia-ac/b6mysb2#4233431',
#   'read_status': 'NotStarted'},
#  {'id': 59007,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 11),
#   'home_team': 'Sporting CP',
#   'away_team': 'Braga',
#   'score': '5–0',
#   'whoscored_id': 1748538,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748538/Live/Portugal-Liga-Portugal-2023-2024-Sporting-CP-Braga',
#   'fbref_id': '15aa5f81',
#   'fbref_url': '/en/matches/15aa5f81/Sporting-CP-Braga-February-11-2024-Primeira-Liga',
#   'fotmob_id': 4233428,
#   'fotmob_url': '/matches/sporting-cp-vs-braga/3bguh4#4233428',
#   'read_status': 'NotStarted'},
#  {'id': 59008,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 11),
#   'home_team': 'Vitoria de Guimaraes',
#   'away_team': 'Benfica',
#   'score': '2–2',
#   'whoscored_id': 1748535,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748535/Live/Portugal-Liga-Portugal-2023-2024-Vitoria-de-Guimaraes-Benfica',
#   'fbref_id': 'f5c04027',
#   'fbref_url': '/en/matches/f5c04027/Vitoria-Guimaraes-Benfica-February-11-2024-Primeira-Liga',
#   'fotmob_id': 4233427,
#   'fotmob_url': '/matches/vitoria-de-guimaraes-vs-benfica/2ke1w4#4233427',
#   'read_status': 'NotStarted'},
#  {'id': 59009,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 12),
#   'home_team': 'Arouca',
#   'away_team': 'FC Porto',
#   'score': '3–2',
#   'whoscored_id': 1748560,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748560/Live/Portugal-Liga-Portugal-2023-2024-Arouca-FC-Porto',
#   'fbref_id': '95825025',
#   'fbref_url': '/en/matches/95825025/Arouca-Porto-February-12-2024-Primeira-Liga',
#   'fotmob_id': 4233446,
#   'fotmob_url': '/matches/fc-porto-vs-arouca/6gzs1k8#4233446',
#   'read_status': 'NotStarted'},
#  {'id': 59010,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 13),
#   'home_team': 'Gil Vicente',
#   'away_team': 'Vizela',
#   'score': '0–1',
#   'whoscored_id': 1748573,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748573/Live/Portugal-Liga-Portugal-2023-2024-Gil-Vicente-Vizela',
#   'fbref_id': '2915b740',
#   'fbref_url': '/en/matches/2915b740/Gil-Vicente-FC-Vizela-February-13-2024-Primeira-Liga',
#   'fotmob_id': 4233457,
#   'fotmob_url': '/matches/vizela-vs-gil-vicente/1ouamw#4233457',
#   'read_status': 'NotStarted'},
#  {'id': 59011,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 16),
#   'home_team': 'Famalicao',
#   'away_team': 'Rio Ave',
#   'score': '2–1',
#   'whoscored_id': 1748571,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748571/Live/Portugal-Liga-Portugal-2023-2024-Famalicao-Rio-Ave',
#   'fbref_id': '76a29585',
#   'fbref_url': '/en/matches/76a29585/Famalicao-Rio-Ave-February-16-2024-Primeira-Liga',
#   'fotmob_id': 4233449,
#   'fotmob_url': '/matches/famalicao-vs-rio-ave/qqdd3#4233449',
#   'read_status': 'NotStarted'},
#  {'id': 59012,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 17),
#   'home_team': 'Chaves',
#   'away_team': 'Boavista',
#   'score': '2–1',
#   'whoscored_id': 1748622,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748622/Live/Portugal-Liga-Portugal-2023-2024-Chaves-Boavista',
#   'fbref_id': '6fbe9cf2',
#   'fbref_url': '/en/matches/6fbe9cf2/Chaves-Boavista-February-17-2024-Primeira-Liga',
#   'fotmob_id': 4233453,
#   'fotmob_url': '/matches/boavista-vs-chaves/2snjf0#4233453',
#   'read_status': 'NotStarted'},
#  {'id': 59013,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 17),
#   'home_team': 'Portimonense',
#   'away_team': 'Vitoria de Guimaraes',
#   'score': '1–1',
#   'whoscored_id': 1748565,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748565/Live/Portugal-Liga-Portugal-2023-2024-Portimonense-Vitoria-de-Guimaraes',
#   'fbref_id': 'ba76ba70',
#   'fbref_url': '/en/matches/ba76ba70/Portimonense-Vitoria-Guimaraes-February-17-2024-Primeira-Liga',
#   'fotmob_id': 4233454,
#   'fotmob_url': '/matches/vitoria-de-guimaraes-vs-portimonense/2kber6#4233454',
#   'read_status': 'NotStarted'},
#  {'id': 59014,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 17),
#   'home_team': 'FC Porto',
#   'away_team': 'Estrela da Amadora',
#   'score': '2–0',
#   'whoscored_id': 1748620,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748620/Live/Portugal-Liga-Portugal-2023-2024-FC-Porto-Estrela-da-Amadora',
#   'fbref_id': 'b55989cd',
#   'fbref_url': '/en/matches/b55989cd/Porto-Estrela-February-17-2024-Primeira-Liga',
#   'fotmob_id': 4233452,
#   'fotmob_url': '/matches/fc-porto-vs-estrela-da-amadora/7hybcqc0#4233452',
#   'read_status': 'NotStarted'},
#  {'id': 59015,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 18),
#   'home_team': 'Casa Pia AC',
#   'away_team': 'Arouca',
#   'score': '1–0',
#   'whoscored_id': 1748567,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748567/Live/Portugal-Liga-Portugal-2023-2024-Casa-Pia-AC-Arouca',
#   'fbref_id': '6f16a8be',
#   'fbref_url': '/en/matches/6f16a8be/Casa-Pia-Arouca-February-18-2024-Primeira-Liga',
#   'fotmob_id': 4233455,
#   'fotmob_url': '/matches/arouca-vs-casa-pia-ac/vllfbf8#4233455',
#   'read_status': 'NotStarted'},
#  {'id': 59016,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 18),
#   'home_team': 'Benfica',
#   'away_team': 'Vizela',
#   'score': '6–1',
#   'whoscored_id': 1748617,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748617/Live/Portugal-Liga-Portugal-2023-2024-Benfica-Vizela',
#   'fbref_id': 'a13d733c',
#   'fbref_url': '/en/matches/a13d733c/Benfica-Vizela-February-18-2024-Primeira-Liga',
#   'fotmob_id': 4233451,
#   'fotmob_url': '/matches/vizela-vs-benfica/1owqws#4233451',
#   'read_status': 'NotStarted'},
#  {'id': 59017,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 18),
#   'home_team': 'Estoril',
#   'away_team': 'Gil Vicente',
#   'score': '1–3',
#   'whoscored_id': 1748568,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748568/Live/Portugal-Liga-Portugal-2023-2024-Estoril-Gil-Vicente',
#   'fbref_id': 'a01a9755',
#   'fbref_url': '/en/matches/a01a9755/Estoril-Gil-Vicente-FC-February-18-2024-Primeira-Liga',
#   'fotmob_id': 4233448,
#   'fotmob_url': '/matches/estoril-vs-gil-vicente/2ka9zt#4233448',
#   'read_status': 'NotStarted'},
#  {'id': 59018,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 18),
#   'home_team': 'Braga',
#   'away_team': 'Farense',
#   'score': '2–1',
#   'whoscored_id': 1748615,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748615/Live/Portugal-Liga-Portugal-2023-2024-Braga-Farense',
#   'fbref_id': '284f8ac8',
#   'fbref_url': '/en/matches/284f8ac8/Braga-Farense-February-18-2024-Primeira-Liga',
#   'fotmob_id': 4233450,
#   'fotmob_url': '/matches/farense-vs-braga/26sgoy#4233450',
#   'read_status': 'NotStarted'},
#  {'id': 59019,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 19),
#   'home_team': 'Moreirense',
#   'away_team': 'Sporting CP',
#   'score': '0–2',
#   'whoscored_id': 1748629,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748629/Live/Portugal-Liga-Portugal-2023-2024-Moreirense-Sporting-CP',
#   'fbref_id': 'a25380bc',
#   'fbref_url': '/en/matches/a25380bc/Moreirense-Sporting-CP-February-19-2024-Primeira-Liga',
#   'fotmob_id': 4233458,
#   'fotmob_url': '/matches/moreirense-vs-sporting-cp/2ppitu#4233458',
#   'read_status': 'NotStarted'},
#  {'id': 59020,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 23),
#   'home_team': 'Arouca',
#   'away_team': 'Famalicao',
#   'score': '3–2',
#   'whoscored_id': 1748616,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748616/Live/Portugal-Liga-Portugal-2023-2024-Arouca-Famalicao',
#   'fbref_id': '9b72ae73',
#   'fbref_url': '/en/matches/9b72ae73/Arouca-Famalicao-February-23-2024-Primeira-Liga',
#   'fotmob_id': 4233482,
#   'fotmob_url': '/matches/famalicao-vs-arouca/5uy3d72#4233482',
#   'read_status': 'NotStarted'},
#  {'id': 59021,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 24),
#   'home_team': 'Farense',
#   'away_team': 'Moreirense',
#   'score': '0–1',
#   'whoscored_id': 1748626,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748626/Live/Portugal-Liga-Portugal-2023-2024-Farense-Moreirense',
#   'fbref_id': '39fc237d',
#   'fbref_url': '/en/matches/39fc237d/Farense-Moreirense-February-24-2024-Primeira-Liga',
#   'fotmob_id': 4233486,
#   'fotmob_url': '/matches/farense-vs-moreirense/1pbrj8#4233486',
#   'read_status': 'NotStarted'},
#  {'id': 59022,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 24),
#   'home_team': 'Estrela da Amadora',
#   'away_team': 'Chaves',
#   'score': '1–1',
#   'whoscored_id': 1748576,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748576/Live/Portugal-Liga-Portugal-2023-2024-Estrela-da-Amadora-Chaves',
#   'fbref_id': 'd07b36c7',
#   'fbref_url': '/en/matches/d07b36c7/Estrela-Chaves-February-24-2024-Primeira-Liga',
#   'fotmob_id': 4233459,
#   'fotmob_url': '/matches/chaves-vs-estrela-da-amadora/7hybzytr#4233459',
#   'read_status': 'NotStarted'},
#  {'id': 59023,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 24),
#   'home_team': 'Vitoria de Guimaraes',
#   'away_team': 'Casa Pia AC',
#   'score': '0–2',
#   'whoscored_id': 1748610,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748610/Live/Portugal-Liga-Portugal-2023-2024-Vitoria-de-Guimaraes-Casa-Pia-AC',
#   'fbref_id': '9ccb94d9',
#   'fbref_url': '/en/matches/9ccb94d9/Vitoria-Guimaraes-Casa-Pia-February-24-2024-Primeira-Liga',
#   'fotmob_id': 4233479,
#   'fotmob_url': '/matches/vitoria-de-guimaraes-vs-casa-pia-ac/b6ncz3t#4233479',
#   'read_status': 'NotStarted'},
#  {'id': 59024,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 25),
#   'home_team': 'Vizela',
#   'away_team': 'Estoril',
#   'score': '3–3',
#   'whoscored_id': 1748612,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748612/Live/Portugal-Liga-Portugal-2023-2024-Vizela-Estoril',
#   'fbref_id': 'fa8f14c6',
#   'fbref_url': '/en/matches/fa8f14c6/Vizela-Estoril-February-25-2024-Primeira-Liga',
#   'fotmob_id': 4233480,
#   'fotmob_url': '/matches/vizela-vs-estoril/19kxrd#4233480',
#   'read_status': 'NotStarted'},
#  {'id': 59025,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 25),
#   'home_team': 'Benfica',
#   'away_team': 'Portimonense',
#   'score': '4–0',
#   'whoscored_id': 1748613,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748613/Live/Portugal-Liga-Portugal-2023-2024-Benfica-Portimonense',
#   'fbref_id': '88e24293',
#   'fbref_url': '/en/matches/88e24293/Benfica-Portimonense-February-25-2024-Primeira-Liga',
#   'fotmob_id': 4233481,
#   'fotmob_url': '/matches/portimonense-vs-benfica/35mxph#4233481',
#   'read_status': 'NotStarted'},
#  {'id': 59026,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 25),
#   'home_team': 'Gil Vicente',
#   'away_team': 'FC Porto',
#   'score': '1–1',
#   'whoscored_id': 1748624,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748624/Live/Portugal-Liga-Portugal-2023-2024-Gil-Vicente-FC-Porto',
#   'fbref_id': 'd707b614',
#   'fbref_url': '/en/matches/d707b614/Gil-Vicente-FC-Porto-February-25-2024-Primeira-Liga',
#   'fotmob_id': 4233485,
#   'fotmob_url': '/matches/gil-vicente-vs-fc-porto/35mxpi#4233485',
#   'read_status': 'NotStarted'},
#  {'id': 59027,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 25),
#   'home_team': 'Rio Ave',
#   'away_team': 'Sporting CP',
#   'score': '3–3',
#   'whoscored_id': 1748621,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748621/Live/Portugal-Liga-Portugal-2023-2024-Rio-Ave-Sporting-CP',
#   'fbref_id': '0a5627f7',
#   'fbref_url': '/en/matches/0a5627f7/Rio-Ave-Sporting-CP-February-25-2024-Primeira-Liga',
#   'fotmob_id': 4233484,
#   'fotmob_url': '/matches/rio-ave-vs-sporting-cp/2kber9#4233484',
#   'read_status': 'NotStarted'},
#  {'id': 59028,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 2, 26),
#   'home_team': 'Boavista',
#   'away_team': 'Braga',
#   'score': '0–4',
#   'whoscored_id': 1748619,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748619/Live/Portugal-Liga-Portugal-2023-2024-Boavista-Braga',
#   'fbref_id': '38b70741',
#   'fbref_url': '/en/matches/38b70741/Boavista-Braga-February-26-2024-Primeira-Liga',
#   'fotmob_id': 4233483,
#   'fotmob_url': '/matches/boavista-vs-braga/2y377s#4233483',
#   'read_status': 'NotStarted'},
#  {'id': 59029,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 1),
#   'home_team': 'Chaves',
#   'away_team': 'Arouca',
#   'score': '1–5',
#   'whoscored_id': 1748631,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748631/Live/Portugal-Liga-Portugal-2023-2024-Chaves-Arouca',
#   'fbref_id': 'eab019c5',
#   'fbref_url': '/en/matches/eab019c5/Chaves-Arouca-March-1-2024-Primeira-Liga',
#   'fotmob_id': 4233488,
#   'fotmob_url': '/matches/chaves-vs-arouca/6gzvn30#4233488',
#   'read_status': 'NotStarted'},
#  {'id': 59030,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 2),
#   'home_team': 'Moreirense',
#   'away_team': 'Rio Ave',
#   'score': '0–0',
#   'whoscored_id': 1748979,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748979/Live/Portugal-Liga-Portugal-2023-2024-Moreirense-Rio-Ave',
#   'fbref_id': '349be474',
#   'fbref_url': '/en/matches/349be474/Moreirense-Rio-Ave-March-2-2024-Primeira-Liga',
#   'fotmob_id': 4233478,
#   'fotmob_url': '/matches/rio-ave-vs-moreirense/26118f#4233478',
#   'read_status': 'NotStarted'},
#  {'id': 59031,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 2),
#   'home_team': 'Estoril',
#   'away_team': 'Vitoria de Guimaraes',
#   'score': '1–3',
#   'whoscored_id': 1748641,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748641/Live/Portugal-Liga-Portugal-2023-2024-Estoril-Vitoria-de-Guimaraes',
#   'fbref_id': 'a205a1fb',
#   'fbref_url': '/en/matches/a205a1fb/Estoril-Vitoria-Guimaraes-March-2-2024-Primeira-Liga',
#   'fotmob_id': 4233493,
#   'fotmob_url': '/matches/estoril-vs-vitoria-de-guimaraes/219715#4233493',
#   'read_status': 'NotStarted'},
#  {'id': 59032,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 2),
#   'home_team': 'Braga',
#   'away_team': 'Estrela da Amadora',
#   'score': '3–0',
#   'whoscored_id': 1748637,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748637/Live/Portugal-Liga-Portugal-2023-2024-Braga-Estrela-da-Amadora',
#   'fbref_id': 'd9ee56a6',
#   'fbref_url': '/en/matches/d9ee56a6/Braga-Estrela-March-2-2024-Primeira-Liga',
#   'fotmob_id': 4233491,
#   'fotmob_url': '/matches/braga-vs-estrela-da-amadora/7i74yy9w#4233491',
#   'read_status': 'NotStarted'},
#  {'id': 59033,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 3),
#   'home_team': 'Casa Pia AC',
#   'away_team': 'Gil Vicente',
#   'score': '0–0',
#   'whoscored_id': 1748639,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748639/Live/Portugal-Liga-Portugal-2023-2024-Casa-Pia-AC-Gil-Vicente',
#   'fbref_id': '1599e9c6',
#   'fbref_url': '/en/matches/1599e9c6/Casa-Pia-Gil-Vicente-FC-March-3-2024-Primeira-Liga',
#   'fotmob_id': 4233492,
#   'fotmob_url': '/matches/gil-vicente-vs-casa-pia-ac/bdopent#4233492',
#   'read_status': 'NotStarted'},
#  {'id': 59034,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 3),
#   'home_team': 'Portimonense',
#   'away_team': 'Vizela',
#   'score': '0–0',
#   'whoscored_id': 1748980,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748980/Live/Portugal-Liga-Portugal-2023-2024-Portimonense-Vizela',
#   'fbref_id': '99618232',
#   'fbref_url': '/en/matches/99618232/Portimonense-Vizela-March-3-2024-Primeira-Liga',
#   'fotmob_id': 4233494,
#   'fotmob_url': '/matches/vizela-vs-portimonense/1oulo1#4233494',
#   'read_status': 'NotStarted'},
#  {'id': 59035,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 3),
#   'home_team': 'Sporting CP',
#   'away_team': 'Farense',
#   'score': '3–2',
#   'whoscored_id': 1748635,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748635/Live/Portugal-Liga-Portugal-2023-2024-Sporting-CP-Farense',
#   'fbref_id': '349d5178',
#   'fbref_url': '/en/matches/349d5178/Sporting-CP-Farense-March-3-2024-Primeira-Liga',
#   'fotmob_id': 4233490,
#   'fotmob_url': '/matches/farense-vs-sporting-cp/2228am#4233490',
#   'read_status': 'NotStarted'},
#  {'id': 59036,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 3),
#   'home_team': 'FC Porto',
#   'away_team': 'Benfica',
#   'score': '5–0',
#   'whoscored_id': 1748628,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748628/Live/Portugal-Liga-Portugal-2023-2024-FC-Porto-Benfica',
#   'fbref_id': 'fdb30a3f',
#   'fbref_url': '/en/matches/fdb30a3f/Porto-Benfica-March-3-2024-Primeira-Liga',
#   'fotmob_id': 4233487,
#   'fotmob_url': '/matches/benfica-vs-fc-porto/35qac2#4233487',
#   'read_status': 'NotStarted'},
#  {'id': 59037,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 4),
#   'home_team': 'Famalicao',
#   'away_team': 'Boavista',
#   'score': '1–1',
#   'whoscored_id': 1748633,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748633/Live/Portugal-Liga-Portugal-2023-2024-Famalicao-Boavista',
#   'fbref_id': 'ba133c78',
#   'fbref_url': '/en/matches/ba133c78/Famalicao-Boavista-March-4-2024-Primeira-Liga',
#   'fotmob_id': 4233489,
#   'fotmob_url': '/matches/famalicao-vs-boavista/v9k8x#4233489',
#   'read_status': 'NotStarted'},
#  {'id': 59038,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 8),
#   'home_team': 'Portimonense',
#   'away_team': 'FC Porto',
#   'score': '0–3',
#   'whoscored_id': 1748978,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748978/Live/Portugal-Liga-Portugal-2023-2024-Portimonense-FC-Porto',
#   'fbref_id': '699ebc12',
#   'fbref_url': '/en/matches/699ebc12/Portimonense-Porto-March-8-2024-Primeira-Liga',
#   'fotmob_id': 4233477,
#   'fotmob_url': '/matches/portimonense-vs-fc-porto/35ncs8#4233477',
#   'read_status': 'NotStarted'},
#  {'id': 59039,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 8),
#   'home_team': 'Estrela da Amadora',
#   'away_team': 'Casa Pia AC',
#   'score': '3–1',
#   'whoscored_id': 1748584,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748584/Live/Portugal-Liga-Portugal-2023-2024-Estrela-da-Amadora-Casa-Pia-AC',
#   'fbref_id': 'e1224463',
#   'fbref_url': '/en/matches/e1224463/Estrela-Casa-Pia-March-8-2024-Primeira-Liga',
#   'fotmob_id': 4233462,
#   'fotmob_url': '/matches/casa-pia-ac-vs-estrela-da-amadora/akjo83as#4233462',
#   'read_status': 'NotStarted'},
#  {'id': 59040,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 9),
#   'home_team': 'Vizela',
#   'away_team': 'Farense',
#   'score': '2–1',
#   'whoscored_id': 1748586,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748586/Live/Portugal-Liga-Portugal-2023-2024-Vizela-Farense',
#   'fbref_id': '9c63d059',
#   'fbref_url': '/en/matches/9c63d059/Vizela-Farense-March-9-2024-Primeira-Liga',
#   'fotmob_id': 4233463,
#   'fotmob_url': '/matches/vizela-vs-farense/x1ngg#4233463',
#   'read_status': 'NotStarted'},
#  {'id': 59041,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 9),
#   'home_team': 'Boavista',
#   'away_team': 'Moreirense',
#   'score': '1–0',
#   'whoscored_id': 1748595,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748595/Live/Portugal-Liga-Portugal-2023-2024-Boavista-Moreirense',
#   'fbref_id': '7cbfdaf5',
#   'fbref_url': '/en/matches/7cbfdaf5/Boavista-Moreirense-March-9-2024-Primeira-Liga',
#   'fotmob_id': 4233466,
#   'fotmob_url': '/matches/moreirense-vs-boavista/2dnb46#4233466',
#   'read_status': 'NotStarted'},
#  {'id': 59042,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 9),
#   'home_team': 'Rio Ave',
#   'away_team': 'Braga',
#   'score': '0–0',
#   'whoscored_id': 1748977,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748977/Live/Portugal-Liga-Portugal-2023-2024-Rio-Ave-Braga',
#   'fbref_id': '066d0ad6',
#   'fbref_url': '/en/matches/066d0ad6/Rio-Ave-Braga-March-9-2024-Primeira-Liga',
#   'fotmob_id': 4233476,
#   'fotmob_url': '/matches/rio-ave-vs-braga/2pl7me#4233476',
#   'read_status': 'NotStarted'},
#  {'id': 59043,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 9),
#   'home_team': 'Vitoria de Guimaraes',
#   'away_team': 'Famalicao',
#   'score': '1–0',
#   'whoscored_id': 1748582,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748582/Live/Portugal-Liga-Portugal-2023-2024-Vitoria-de-Guimaraes-Famalicao',
#   'fbref_id': 'e6bb4742',
#   'fbref_url': '/en/matches/e6bb4742/Vitoria-Guimaraes-Famalicao-March-9-2024-Primeira-Liga',
#   'fotmob_id': 4233461,
#   'fotmob_url': '/matches/famalicao-vs-vitoria-de-guimaraes/qqzax#4233461',
#   'read_status': 'NotStarted'},
#  {'id': 59044,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 10),
#   'home_team': 'Arouca',
#   'away_team': 'Sporting CP',
#   'score': '0–3',
#   'whoscored_id': 1748592,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748592/Live/Portugal-Liga-Portugal-2023-2024-Arouca-Sporting-CP',
#   'fbref_id': 'c8fdf700',
#   'fbref_url': '/en/matches/c8fdf700/Arouca-Sporting-CP-March-10-2024-Primeira-Liga',
#   'fotmob_id': 4233465,
#   'fotmob_url': '/matches/sporting-cp-vs-arouca/6gza1yr#4233465',
#   'read_status': 'NotStarted'},
#  {'id': 59045,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 10),
#   'home_team': 'Benfica',
#   'away_team': 'Estoril',
#   'score': '3–1',
#   'whoscored_id': 1748589,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748589/Live/Portugal-Liga-Portugal-2023-2024-Benfica-Estoril',
#   'fbref_id': '6353de56',
#   'fbref_url': '/en/matches/6353de56/Benfica-Estoril-March-10-2024-Primeira-Liga',
#   'fotmob_id': 4233464,
#   'fotmob_url': '/matches/estoril-vs-benfica/2kdaph#4233464',
#   'read_status': 'NotStarted'},
#  {'id': 59046,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 11),
#   'home_team': 'Gil Vicente',
#   'away_team': 'Chaves',
#   'score': '0–0',
#   'whoscored_id': 1748579,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748579/Live/Portugal-Liga-Portugal-2023-2024-Gil-Vicente-Chaves',
#   'fbref_id': '39b216ee',
#   'fbref_url': '/en/matches/39b216ee/Gil-Vicente-FC-Chaves-March-11-2024-Primeira-Liga',
#   'fotmob_id': 4233460,
#   'fotmob_url': '/matches/gil-vicente-vs-chaves/35ncs9#4233460',
#   'read_status': 'NotStarted'},
#  {'id': 59047,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 15),
#   'home_team': 'Estoril',
#   'away_team': 'Portimonense',
#   'score': '1–0',
#   'whoscored_id': 1748590,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748590/Live/Portugal-Liga-Portugal-2023-2024-Estoril-Portimonense',
#   'fbref_id': '096e698a',
#   'fbref_url': '/en/matches/096e698a/Estoril-Portimonense-March-15-2024-Primeira-Liga',
#   'fotmob_id': 4233474,
#   'fotmob_url': '/matches/estoril-vs-portimonense/2kankx#4233474',
#   'read_status': 'NotStarted'},
#  {'id': 59048,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 16),
#   'home_team': 'Famalicao',
#   'away_team': 'Estrela da Amadora',
#   'score': '0–0',
#   'whoscored_id': 1748581,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748581/Live/Portugal-Liga-Portugal-2023-2024-Famalicao-Estrela-da-Amadora',
#   'fbref_id': 'bac9063c',
#   'fbref_url': '/en/matches/bac9063c/Famalicao-Estrela-March-16-2024-Primeira-Liga',
#   'fotmob_id': 4233470,
#   'fotmob_url': '/matches/famalicao-vs-estrela-da-amadora/7dwxtlbx#4233470',
#   'read_status': 'NotStarted'},
#  {'id': 59049,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 16),
#   'home_team': 'Braga',
#   'away_team': 'Gil Vicente',
#   'score': '2–1',
#   'whoscored_id': 1748585,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748585/Live/Portugal-Liga-Portugal-2023-2024-Braga-Gil-Vicente',
#   'fbref_id': '9b334b8b',
#   'fbref_url': '/en/matches/9b334b8b/Braga-Gil-Vicente-FC-March-16-2024-Primeira-Liga',
#   'fotmob_id': 4233472,
#   'fotmob_url': '/matches/gil-vicente-vs-braga/3bf4ne#4233472',
#   'read_status': 'NotStarted'},
#  {'id': 59050,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 16),
#   'home_team': 'Farense',
#   'away_team': 'Rio Ave',
#   'score': '1–1',
#   'whoscored_id': 1748606,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748606/Live/Portugal-Liga-Portugal-2023-2024-Farense-Rio-Ave',
#   'fbref_id': '7e1c2cb9',
#   'fbref_url': '/en/matches/7e1c2cb9/Farense-Rio-Ave-March-16-2024-Primeira-Liga',
#   'fotmob_id': 4233475,
#   'fotmob_url': '/matches/farense-vs-rio-ave/1l2jk8#4233475',
#   'read_status': 'NotStarted'},
#  {'id': 59051,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 16),
#   'home_team': 'FC Porto',
#   'away_team': 'Vizela',
#   'score': '4–1',
#   'whoscored_id': 1748583,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748583/Live/Portugal-Liga-Portugal-2023-2024-FC-Porto-Vizela',
#   'fbref_id': '6ae89005',
#   'fbref_url': '/en/matches/6ae89005/Porto-Vizela-March-16-2024-Primeira-Liga',
#   'fotmob_id': 4233471,
#   'fotmob_url': '/matches/vizela-vs-fc-porto/1ox1y5#4233471',
#   'read_status': 'NotStarted'},
#  {'id': 59052,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 17),
#   'home_team': 'Chaves',
#   'away_team': 'Vitoria de Guimaraes',
#   'score': '1–2',
#   'whoscored_id': 1748587,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748587/Live/Portugal-Liga-Portugal-2023-2024-Chaves-Vitoria-de-Guimaraes',
#   'fbref_id': 'c3b6c244',
#   'fbref_url': '/en/matches/c3b6c244/Chaves-Vitoria-Guimaraes-March-17-2024-Primeira-Liga',
#   'fotmob_id': 4233473,
#   'fotmob_url': '/matches/vitoria-de-guimaraes-vs-chaves/2ket2x#4233473',
#   'read_status': 'NotStarted'},
#  {'id': 59053,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 17),
#   'home_team': 'Moreirense',
#   'away_team': 'Arouca',
#   'score': '1–0',
#   'whoscored_id': 1748575,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748575/Live/Portugal-Liga-Portugal-2023-2024-Moreirense-Arouca',
#   'fbref_id': 'a3eb87ff',
#   'fbref_url': '/en/matches/a3eb87ff/Moreirense-Arouca-March-17-2024-Primeira-Liga',
#   'fotmob_id': 4233468,
#   'fotmob_url': '/matches/moreirense-vs-arouca/6d1yx8t#4233468',
#   'read_status': 'NotStarted'},
#  {'id': 59054,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 17),
#   'home_team': 'Casa Pia AC',
#   'away_team': 'Benfica',
#   'score': '0–1',
#   'whoscored_id': 1748598,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748598/Live/Portugal-Liga-Portugal-2023-2024-Casa-Pia-AC-Benfica',
#   'fbref_id': '0c5fd228',
#   'fbref_url': '/en/matches/0c5fd228/Casa-Pia-Benfica-March-17-2024-Primeira-Liga',
#   'fotmob_id': 4233467,
#   'fotmob_url': '/matches/benfica-vs-casa-pia-ac/bdprkod#4233467',
#   'read_status': 'NotStarted'},
#  {'id': 59055,
#   'competition': 'Primeira_Liga',
#   'season': '23-24',
#   'stage': 'nan',
#   'date': datetime.date(2024, 3, 17),
#   'home_team': 'Sporting CP',
#   'away_team': 'Boavista',
#   'score': '6–1',
#   'whoscored_id': 1748578,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1748578/Live/Portugal-Liga-Portugal-2023-2024-Sporting-CP-Boavista',
#   'fbref_id': '8f947473',
#   'fbref_url': '/en/matches/8f947473/Sporting-CP-Boavista-March-17-2024-Primeira-Liga',
#   'fotmob_id': 4233469,
#   'fotmob_url': '/matches/boavista-vs-sporting-cp/2sl6ar#4233469',
#   'read_status': 'NotStarted'},
#  {'id': 59056,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 28),
#   'home_team': 'Royal Antwerp',
#   'away_team': 'Anderlecht',
#   'score': '0–0',
#   'whoscored_id': 1188682,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188682/Live/Belgium-Jupiler-Pro-League-2017-2018-Royal-Antwerp-Anderlecht',
#   'fbref_id': '735f6afe',
#   'fbref_url': '/en/matches/735f6afe/Antwerp-Anderlecht-July-28-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519777,
#   'fotmob_url': '/matches/anderlecht-vs-royal-antwerp/2v95es#2519777',
#   'read_status': 'NotStarted'},
#  {'id': 59057,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 29),
#   'home_team': 'Lokeren',
#   'away_team': 'Club Bruges',
#   'score': '0–4',
#   'whoscored_id': 1188683,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188683/Live/Belgium-Jupiler-Pro-League-2017-2018-Lokeren-Club-Bruges',
#   'fbref_id': 'de8bf289',
#   'fbref_url': '/en/matches/de8bf289/Lokeren-Club-Brugge-July-29-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519778,
#   'fotmob_url': '/matches/club-brugge-vs-lokeren/2s3h0a#2519778',
#   'read_status': 'NotStarted'},
#  {'id': 59058,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 29),
#   'home_team': 'Eupen',
#   'away_team': 'Zulte Waregem',
#   'score': '0–5',
#   'whoscored_id': 1188685,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188685/Live/Belgium-Jupiler-Pro-League-2017-2018-Eupen-Zulte-Waregem',
#   'fbref_id': '3f2f1892',
#   'fbref_url': '/en/matches/3f2f1892/Eupen-Zulte-Waregem-July-29-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519780,
#   'fotmob_url': '/matches/eupen-vs-zulte-waregem/27lhi7#2519780',
#   'read_status': 'NotStarted'},
#  {'id': 59059,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 29),
#   'home_team': 'Genk',
#   'away_team': 'SK Beveren',
#   'score': '3–3',
#   'whoscored_id': 1188684,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188684/Live/Belgium-Jupiler-Pro-League-2017-2018-Genk-SK-Beveren',
#   'fbref_id': '6c2520f9',
#   'fbref_url': '/en/matches/6c2520f9/Genk-Waasland-Beveren-July-29-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519779,
#   'fotmob_url': '/matches/sk-beveren-vs-genk/2th5uc#2519779',
#   'read_status': 'NotStarted'},
#  {'id': 59060,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 29),
#   'home_team': 'Sporting Charleroi',
#   'away_team': 'Kortrijk',
#   'score': '1–0',
#   'whoscored_id': 1188686,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188686/Live/Belgium-Jupiler-Pro-League-2017-2018-Sporting-Charleroi-Kortrijk',
#   'fbref_id': '1f0690a3',
#   'fbref_url': '/en/matches/1f0690a3/Charleroi-Kortrijk-July-29-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519781,
#   'fotmob_url': '/matches/kortrijk-vs-sporting-charleroi/2uiuo5#2519781',
#   'read_status': 'NotStarted'},
#  {'id': 59061,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 30),
#   'home_team': 'KV Mechelen',
#   'away_team': 'Standard Liege',
#   'score': '1–1',
#   'whoscored_id': 1188687,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188687/Live/Belgium-Jupiler-Pro-League-2017-2018-KV-Mechelen-Standard-Liege',
#   'fbref_id': '4c13466d',
#   'fbref_url': '/en/matches/4c13466d/Mechelen-Standard-Liege-July-30-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519782,
#   'fotmob_url': '/matches/kv-mechelen-vs-standard-liege/2qhjgv#2519782',
#   'read_status': 'NotStarted'},
#  {'id': 59062,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 30),
#   'home_team': 'St.Truiden',
#   'away_team': 'Gent',
#   'score': '3–2',
#   'whoscored_id': 1188688,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188688/Live/Belgium-Jupiler-Pro-League-2017-2018-St-Truiden-Gent',
#   'fbref_id': 'f256c2cd',
#   'fbref_url': '/en/matches/f256c2cd/Sint-Truiden-Gent-July-30-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519783,
#   'fotmob_url': '/matches/gent-vs-sttruiden/3axza7#2519783',
#   'read_status': 'NotStarted'},
#  {'id': 59063,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 7, 30),
#   'home_team': 'Oostende',
#   'away_team': 'Royal Excel Mouscron',
#   'score': '0–1',
#   'whoscored_id': 1188689,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188689/Live/Belgium-Jupiler-Pro-League-2017-2018-Oostende-Royal-Excel-Mouscron',
#   'fbref_id': '0d2af91f',
#   'fbref_url': '/en/matches/0d2af91f/Oostende-Excel-Mouscron-July-30-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519784,
#   'fotmob_url': '/matches/oostende-vs-royal-excel-mouscron/iezi71k#2519784',
#   'read_status': 'NotStarted'},
#  {'id': 59064,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 4),
#   'home_team': 'Standard Liege',
#   'away_team': 'Genk',
#   'score': '2–1',
#   'whoscored_id': 1188690,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188690/Live/Belgium-Jupiler-Pro-League-2017-2018-Standard-Liege-Genk',
#   'fbref_id': '12d44dac',
#   'fbref_url': '/en/matches/12d44dac/Standard-Liege-Genk-August-4-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519785,
#   'fotmob_url': '/matches/standard-liege-vs-genk/3ar4lp#2519785',
#   'read_status': 'NotStarted'},
#  {'id': 59065,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 5),
#   'home_team': 'Royal Excel Mouscron',
#   'away_team': 'Sporting Charleroi',
#   'score': '2–5',
#   'whoscored_id': 1188691,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188691/Live/Belgium-Jupiler-Pro-League-2017-2018-Royal-Excel-Mouscron-Sporting-Charleroi',
#   'fbref_id': '4e49bca3',
#   'fbref_url': '/en/matches/4e49bca3/Excel-Mouscron-Charleroi-August-5-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519786,
#   'fotmob_url': '/matches/sporting-charleroi-vs-royal-excel-mouscron/ilmb3h2#2519786',
#   'read_status': 'NotStarted'},
#  {'id': 59066,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 5),
#   'home_team': 'Kortrijk',
#   'away_team': 'Lokeren',
#   'score': '1–0',
#   'whoscored_id': 1188692,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188692/Live/Belgium-Jupiler-Pro-League-2017-2018-Kortrijk-Lokeren',
#   'fbref_id': 'f617e6ae',
#   'fbref_url': '/en/matches/f617e6ae/Kortrijk-Lokeren-August-5-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519787,
#   'fotmob_url': '/matches/kortrijk-vs-lokeren/2um195#2519787',
#   'read_status': 'NotStarted'},
#  {'id': 59067,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 5),
#   'home_team': 'SK Beveren',
#   'away_team': 'KV Mechelen',
#   'score': '2–2',
#   'whoscored_id': 1188693,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188693/Live/Belgium-Jupiler-Pro-League-2017-2018-SK-Beveren-KV-Mechelen',
#   'fbref_id': 'a6119ab9',
#   'fbref_url': '/en/matches/a6119ab9/Waasland-Beveren-Mechelen-August-5-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519788,
#   'fotmob_url': '/matches/kv-mechelen-vs-sk-beveren/2ata4g#2519788',
#   'read_status': 'NotStarted'},
#  {'id': 59068,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 5),
#   'home_team': 'Zulte Waregem',
#   'away_team': 'St.Truiden',
#   'score': '2–0',
#   'whoscored_id': 1188694,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188694/Live/Belgium-Jupiler-Pro-League-2017-2018-Zulte-Waregem-St-Truiden',
#   'fbref_id': '4079b062',
#   'fbref_url': '/en/matches/4079b062/Zulte-Waregem-Sint-Truiden-August-5-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519789,
#   'fotmob_url': '/matches/sttruiden-vs-zulte-waregem/3b1u4g#2519789',
#   'read_status': 'NotStarted'},
#  {'id': 59069,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 6),
#   'home_team': 'Gent',
#   'away_team': 'Royal Antwerp',
#   'score': '0–1',
#   'whoscored_id': 1188695,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188695/Live/Belgium-Jupiler-Pro-League-2017-2018-Gent-Royal-Antwerp',
#   'fbref_id': 'd7064c29',
#   'fbref_url': '/en/matches/d7064c29/Gent-Antwerp-August-6-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519790,
#   'fotmob_url': '/matches/royal-antwerp-vs-gent/3au4i1#2519790',
#   'read_status': 'NotStarted'},
#  {'id': 59070,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 6),
#   'home_team': 'Anderlecht',
#   'away_team': 'Oostende',
#   'score': '1–0',
#   'whoscored_id': 1188696,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188696/Live/Belgium-Jupiler-Pro-League-2017-2018-Anderlecht-Oostende',
#   'fbref_id': '25d1f9ee',
#   'fbref_url': '/en/matches/25d1f9ee/Anderlecht-Oostende-August-6-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519791,
#   'fotmob_url': '/matches/oostende-vs-anderlecht/2g5rav#2519791',
#   'read_status': 'NotStarted'},
#  {'id': 59071,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 6),
#   'home_team': 'Club Bruges',
#   'away_team': 'Eupen',
#   'score': '3–1',
#   'whoscored_id': 1188697,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188697/Live/Belgium-Jupiler-Pro-League-2017-2018-Club-Bruges-Eupen',
#   'fbref_id': '9123e847',
#   'fbref_url': '/en/matches/9123e847/Club-Brugge-Eupen-August-6-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519792,
#   'fotmob_url': '/matches/eupen-vs-club-brugge/1s9ws5#2519792',
#   'read_status': 'NotStarted'},
#  {'id': 59072,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 11),
#   'home_team': 'Zulte Waregem',
#   'away_team': 'Club Bruges',
#   'score': '1–2',
#   'whoscored_id': 1188754,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188754/Live/Belgium-Jupiler-Pro-League-2017-2018-Zulte-Waregem-Club-Bruges',
#   'fbref_id': '8cd0c803',
#   'fbref_url': '/en/matches/8cd0c803/Zulte-Waregem-Club-Brugge-August-11-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519849,
#   'fotmob_url': '/matches/club-brugge-vs-zulte-waregem/2s5smz#2519849',
#   'read_status': 'NotStarted'},
#  {'id': 59073,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 12),
#   'home_team': 'KV Mechelen',
#   'away_team': 'Gent',
#   'score': '1–1',
#   'whoscored_id': 1188755,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188755/Live/Belgium-Jupiler-Pro-League-2017-2018-KV-Mechelen-Gent',
#   'fbref_id': '2fa3244f',
#   'fbref_url': '/en/matches/2fa3244f/Mechelen-Gent-August-12-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519850,
#   'fotmob_url': '/matches/kv-mechelen-vs-gent/2qjvoy#2519850',
#   'read_status': 'NotStarted'},
#  {'id': 59074,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 12),
#   'home_team': 'Eupen',
#   'away_team': 'Kortrijk',
#   'score': '1–2',
#   'whoscored_id': 1188756,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188756/Live/Belgium-Jupiler-Pro-League-2017-2018-Eupen-Kortrijk',
#   'fbref_id': 'b0ad260d',
#   'fbref_url': '/en/matches/b0ad260d/Eupen-Kortrijk-August-12-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519851,
#   'fotmob_url': '/matches/eupen-vs-kortrijk/1ualhu#2519851',
#   'read_status': 'NotStarted'},
#  {'id': 59075,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 12),
#   'home_team': 'Lokeren',
#   'away_team': 'Royal Excel Mouscron',
#   'score': '0–2',
#   'whoscored_id': 1188757,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1188757/Live/Belgium-Jupiler-Pro-League-2017-2018-Lokeren-Royal-Excel-Mouscron',
#   'fbref_id': '4cbaf682',
#   'fbref_url': '/en/matches/4cbaf682/Lokeren-Excel-Mouscron-August-12-2017-Belgian-First-Division-A',
#   'fotmob_id': 2519852,
#   'fotmob_url': '/matches/lokeren-vs-royal-excel-mouscron/ilnnw3e#2519852',
#   'read_status': 'NotStarted'},
#  {'id': 59076,
#   'competition': 'Pro_League',
#   'season': '17-18',
#   'stage': 'First Division A',
#   'date': datetime.date(2017, 8, 12),
#   'home_team': 'Oostende',
#   'away_team': 'SK Beveren',
#   'score': '0–3',
#   'whoscored_id': 1188758,
# ...
#   'fbref_id': '679fd9d6',
#   'fbref_url': '/en/matches/679fd9d6/Charleroi-Kortrijk-December-7-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360888,
#   'fotmob_url': '/matches/kortrijk-vs-sporting-charleroi/2uiuo5#3360888',
#   'read_status': 'NotStarted'},
#  {'id': 59971,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 8),
#   'home_team': 'OH Leuven',
#   'away_team': 'Royal Excel Mouscron',
#   'score': '2–0',
#   'whoscored_id': 1476513,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476513/Live/Belgium-Jupiler-Pro-League-2020-2021-OH-Leuven-Royal-Excel-Mouscron',
#   'fbref_id': '8c70c4a3',
#   'fbref_url': '/en/matches/8c70c4a3/OH-Leuven-Excel-Mouscron-December-8-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392205,
#   'fotmob_url': '/matches/oh-leuven-vs-royal-excel-mouscron/hjj2cm0#3392205',
#   'read_status': 'NotStarted'},
#  {'id': 59972,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 11),
#   'home_team': 'Anderlecht',
#   'away_team': 'Genk',
#   'score': '1–0',
#   'whoscored_id': 1463650,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463650/Live/Belgium-Jupiler-Pro-League-2020-2021-Anderlecht-Genk',
#   'fbref_id': '4d07efb5',
#   'fbref_url': '/en/matches/4d07efb5/Anderlecht-Genk-December-11-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360915,
#   'fotmob_url': '/matches/anderlecht-vs-genk/2v8r1g#3360915',
#   'read_status': 'NotStarted'},
#  {'id': 59973,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 12),
#   'home_team': 'Royal Excel Mouscron',
#   'away_team': 'Beerschot',
#   'score': '3–1',
#   'whoscored_id': 1476493,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476493/Live/Belgium-Jupiler-Pro-League-2020-2021-Royal-Excel-Mouscron-Beerschot',
#   'fbref_id': '22d11028',
#   'fbref_url': '/en/matches/22d11028/Excel-Mouscron-Beerschot-Wilrijk-December-12-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392185,
#   'fotmob_url': '/matches/royal-excel-mouscron-vs-beerschot/4p9x58hw#3392185',
#   'read_status': 'NotStarted'},
#  {'id': 59974,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 12),
#   'home_team': 'Cercle Bruges',
#   'away_team': 'Oostende',
#   'score': '0–1',
#   'whoscored_id': 1463688,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463688/Live/Belgium-Jupiler-Pro-League-2020-2021-Cercle-Bruges-Oostende',
#   'fbref_id': 'd23638b4',
#   'fbref_url': '/en/matches/d23638b4/Cercle-Brugge-Oostende-December-12-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360946,
#   'fotmob_url': '/matches/oostende-vs-cercle-brugge/2uiuo3#3360946',
#   'read_status': 'NotStarted'},
#  {'id': 59975,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 12),
#   'home_team': 'Kortrijk',
#   'away_team': 'OH Leuven',
#   'score': '0–3',
#   'whoscored_id': 1476509,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476509/Live/Belgium-Jupiler-Pro-League-2020-2021-Kortrijk-OH-Leuven',
#   'fbref_id': '0588eb7c',
#   'fbref_url': '/en/matches/0588eb7c/Kortrijk-OH-Leuven-December-12-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392201,
#   'fotmob_url': '/matches/oh-leuven-vs-kortrijk/vuytr#3392201',
#   'read_status': 'NotStarted'},
#  {'id': 59976,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 12),
#   'home_team': 'St.Truiden',
#   'away_team': 'Sporting Charleroi',
#   'score': '1–2',
#   'whoscored_id': 1463757,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463757/Live/Belgium-Jupiler-Pro-League-2020-2021-St-Truiden-Sporting-Charleroi',
#   'fbref_id': '91df99f6',
#   'fbref_url': '/en/matches/91df99f6/Sint-Truiden-Charleroi-December-12-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361011,
#   'fotmob_url': '/matches/sporting-charleroi-vs-sttruiden/3avu6d#3361011',
#   'read_status': 'NotStarted'},
#  {'id': 59977,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 13),
#   'home_team': 'Royal Antwerp',
#   'away_team': 'Club Bruges',
#   'score': '0–2',
#   'whoscored_id': 1463729,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463729/Live/Belgium-Jupiler-Pro-League-2020-2021-Royal-Antwerp-Club-Bruges',
#   'fbref_id': '69997dad',
#   'fbref_url': '/en/matches/69997dad/Antwerp-Club-Brugge-December-13-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360987,
#   'fotmob_url': '/matches/club-brugge-vs-royal-antwerp/2s144j#3360987',
#   'read_status': 'NotStarted'},
#  {'id': 59978,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 13),
#   'home_team': 'Gent',
#   'away_team': 'Standard Liege',
#   'score': '2–1',
#   'whoscored_id': 1463791,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463791/Live/Belgium-Jupiler-Pro-League-2020-2021-Gent-Standard-Liege',
#   'fbref_id': '40d7d482',
#   'fbref_url': '/en/matches/40d7d482/Gent-Standard-Liege-December-13-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361049,
#   'fotmob_url': '/matches/standard-liege-vs-gent/3asu97#3361049',
#   'read_status': 'NotStarted'},
#  {'id': 59979,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 13),
#   'home_team': 'KV Mechelen',
#   'away_team': 'SK Beveren',
#   'score': '2–3',
#   'whoscored_id': 1476482,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476482/Live/Belgium-Jupiler-Pro-League-2020-2021-KV-Mechelen-SK-Beveren',
#   'fbref_id': 'd7a1c969',
#   'fbref_url': '/en/matches/d7a1c969/Mechelen-Waasland-Beveren-December-13-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392174,
#   'fotmob_url': '/matches/kv-mechelen-vs-sk-beveren/2ata4g#3392174',
#   'read_status': 'NotStarted'},
#  {'id': 59980,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 15),
#   'home_team': 'Cercle Bruges',
#   'away_team': 'Sporting Charleroi',
#   'score': '3–4',
#   'whoscored_id': 1463695,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463695/Live/Belgium-Jupiler-Pro-League-2020-2021-Cercle-Bruges-Sporting-Charleroi',
#   'fbref_id': 'e0427802',
#   'fbref_url': '/en/matches/e0427802/Cercle-Brugge-Charleroi-December-15-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360953,
#   'fotmob_url': '/matches/cercle-brugge-vs-sporting-charleroi/3aq9s5#3360953',
#   'read_status': 'NotStarted'},
#  {'id': 59981,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 15),
#   'home_team': 'Royal Excel Mouscron',
#   'away_team': 'OH Leuven',
#   'score': '2–2',
#   'whoscored_id': 1476464,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476464/Live/Belgium-Jupiler-Pro-League-2020-2021-Royal-Excel-Mouscron-OH-Leuven',
#   'fbref_id': 'cb289082',
#   'fbref_url': '/en/matches/cb289082/Excel-Mouscron-OH-Leuven-December-15-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392159,
#   'fotmob_url': '/matches/oh-leuven-vs-royal-excel-mouscron/hjj2cm0#3392159',
#   'read_status': 'NotStarted'},
#  {'id': 59982,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 15),
#   'home_team': 'Anderlecht',
#   'away_team': 'Oostende',
#   'score': '2–1',
#   'whoscored_id': 1463747,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463747/Live/Belgium-Jupiler-Pro-League-2020-2021-Anderlecht-Oostende',
#   'fbref_id': 'cea2d2b8',
#   'fbref_url': '/en/matches/cea2d2b8/Anderlecht-Oostende-December-15-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361016,
#   'fotmob_url': '/matches/oostende-vs-anderlecht/2g5rav#3361016',
#   'read_status': 'NotStarted'},
#  {'id': 59983,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 16),
#   'home_team': 'Royal Antwerp',
#   'away_team': 'Zulte Waregem',
#   'score': '0–1',
#   'whoscored_id': 1463675,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463675/Live/Belgium-Jupiler-Pro-League-2020-2021-Royal-Antwerp-Zulte-Waregem',
#   'fbref_id': '77d10037',
#   'fbref_url': '/en/matches/77d10037/Antwerp-Zulte-Waregem-December-16-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360933,
#   'fotmob_url': '/matches/royal-antwerp-vs-zulte-waregem/3axz9y#3360933',
#   'read_status': 'NotStarted'},
#  {'id': 59984,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 16),
#   'home_team': 'Gent',
#   'away_team': 'SK Beveren',
#   'score': '3–0',
#   'whoscored_id': 1476438,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476438/Live/Belgium-Jupiler-Pro-League-2020-2021-Gent-SK-Beveren',
#   'fbref_id': '80b5477e',
#   'fbref_url': '/en/matches/80b5477e/Gent-Waasland-Beveren-December-16-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392130,
#   'fotmob_url': '/matches/sk-beveren-vs-gent/2tiqu2#3392130',
#   'read_status': 'NotStarted'},
#  {'id': 59985,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 16),
#   'home_team': 'Kortrijk',
#   'away_team': 'Standard Liege',
#   'score': '2–1',
#   'whoscored_id': 1463826,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463826/Live/Belgium-Jupiler-Pro-League-2020-2021-Kortrijk-Standard-Liege',
#   'fbref_id': 'aeeb96ad',
#   'fbref_url': '/en/matches/aeeb96ad/Kortrijk-Standard-Liege-December-16-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361084,
#   'fotmob_url': '/matches/kortrijk-vs-standard-liege/2uigcn#3361084',
#   'read_status': 'NotStarted'},
#  {'id': 59986,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 17),
#   'home_team': 'KV Mechelen',
#   'away_team': 'Club Bruges',
#   'score': '0–3',
#   'whoscored_id': 1463631,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463631/Live/Belgium-Jupiler-Pro-League-2020-2021-KV-Mechelen-Club-Bruges',
#   'fbref_id': '84af2439',
#   'fbref_url': '/en/matches/84af2439/Mechelen-Club-Brugge-December-17-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360887,
#   'fotmob_url': '/matches/kv-mechelen-vs-club-brugge/29hx8n#3360887',
#   'read_status': 'NotStarted'},
#  {'id': 59987,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 18),
#   'home_team': 'Sporting Charleroi',
#   'away_team': 'Anderlecht',
#   'score': '1–0',
#   'whoscored_id': 1463766,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463766/Live/Belgium-Jupiler-Pro-League-2020-2021-Sporting-Charleroi-Anderlecht',
#   'fbref_id': '621290f9',
#   'fbref_url': '/en/matches/621290f9/Charleroi-Anderlecht-December-18-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361024,
#   'fotmob_url': '/matches/anderlecht-vs-sporting-charleroi/2v8co5#3361024',
#   'read_status': 'NotStarted'},
#  {'id': 59988,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 19),
#   'home_team': 'Zulte Waregem',
#   'away_team': 'St.Truiden',
#   'score': '0–2',
#   'whoscored_id': 1463724,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463724/Live/Belgium-Jupiler-Pro-League-2020-2021-Zulte-Waregem-St-Truiden',
#   'fbref_id': '742203ac',
#   'fbref_url': '/en/matches/742203ac/Zulte-Waregem-Sint-Truiden-December-19-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360981,
#   'fotmob_url': '/matches/sttruiden-vs-zulte-waregem/3b1u4g#3360981',
#   'read_status': 'NotStarted'},
#  {'id': 59989,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 19),
#   'home_team': 'Genk',
#   'away_team': 'Kortrijk',
#   'score': '2–0',
#   'whoscored_id': 1463717,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463717/Live/Belgium-Jupiler-Pro-League-2020-2021-Genk-Kortrijk',
#   'fbref_id': '1cfaac2e',
#   'fbref_url': '/en/matches/1cfaac2e/Genk-Kortrijk-December-19-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360967,
#   'fotmob_url': '/matches/kortrijk-vs-genk/2uj8zo#3360967',
#   'read_status': 'NotStarted'},
#  {'id': 59990,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 20),
#   'home_team': 'Club Bruges',
#   'away_team': 'Gent',
#   'score': '0–1',
#   'whoscored_id': 1463825,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463825/Live/Belgium-Jupiler-Pro-League-2020-2021-Club-Bruges-Gent',
#   'fbref_id': 'be8c91c4',
#   'fbref_url': '/en/matches/be8c91c4/Club-Brugge-Gent-December-20-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361083,
#   'fotmob_url': '/matches/club-brugge-vs-gent/2s2aka#3361083',
#   'read_status': 'NotStarted'},
#  {'id': 59991,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 20),
#   'home_team': 'OH Leuven',
#   'away_team': 'KV Mechelen',
#   'score': '1–2',
#   'whoscored_id': 1476465,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476465/Live/Belgium-Jupiler-Pro-League-2020-2021-OH-Leuven-KV-Mechelen',
#   'fbref_id': '6a4a5d43',
#   'fbref_url': '/en/matches/6a4a5d43/OH-Leuven-Mechelen-December-20-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392160,
#   'fotmob_url': '/matches/oh-leuven-vs-kv-mechelen/tmtgn#3392160',
#   'read_status': 'NotStarted'},
#  {'id': 59992,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 20),
#   'home_team': 'Standard Liege',
#   'away_team': 'Royal Excel Mouscron',
#   'score': '0–1',
#   'whoscored_id': 1463711,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463711/Live/Belgium-Jupiler-Pro-League-2020-2021-Standard-Liege-Royal-Excel-Mouscron',
#   'fbref_id': '76811e5e',
#   'fbref_url': '/en/matches/76811e5e/Standard-Liege-Excel-Mouscron-December-20-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360970,
#   'fotmob_url': '/matches/standard-liege-vs-royal-excel-mouscron/ilm4zwe#3360970',
#   'read_status': 'NotStarted'},
#  {'id': 59993,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 20),
#   'home_team': 'SK Beveren',
#   'away_team': 'Royal Antwerp',
#   'score': '0–3',
#   'whoscored_id': 1476481,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1476481/Live/Belgium-Jupiler-Pro-League-2020-2021-SK-Beveren-Royal-Antwerp',
#   'fbref_id': 'a5cdd90e',
#   'fbref_url': '/en/matches/a5cdd90e/Waasland-Beveren-Antwerp-December-20-2020-Belgian-First-Division-A',
#   'fotmob_id': 3392173,
#   'fotmob_url': '/matches/sk-beveren-vs-royal-antwerp/2thk38#3392173',
#   'read_status': 'NotStarted'},
#  {'id': 59994,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 26),
#   'home_team': 'Club Bruges',
#   'away_team': 'Eupen',
#   'score': '3–0',
#   'whoscored_id': 1463706,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463706/Live/Belgium-Jupiler-Pro-League-2020-2021-Club-Bruges-Eupen',
#   'fbref_id': 'ec43bc5e',
#   'fbref_url': '/en/matches/ec43bc5e/Club-Brugge-Eupen-December-26-2020-Belgian-First-Division-A',
#   'fotmob_id': 3360964,
#   'fotmob_url': '/matches/eupen-vs-club-brugge/1s9ws5#3360964',
#   'read_status': 'NotStarted'},
#  {'id': 59995,
#   'competition': 'Pro_League',
#   'season': '20-21',
#   'stage': 'Jupiler League',
#   'date': datetime.date(2020, 12, 26),
#   'home_team': 'Zulte Waregem',
#   'away_team': 'Cercle Bruges',
#   'score': '1–0',
#   'whoscored_id': 1463820,
#   'whoscored_url': 'https://1xbet.whoscored.com/Matches/1463820/Live/Belgium-Jupiler-Pro-League-2020-2021-Zulte-Waregem-Cercle-Bruges',
#   'fbref_id': 'd4207465',
#   'fbref_url': '/en/matches/d4207465/Zulte-Waregem-Cercle-Brugge-December-26-2020-Belgian-First-Division-A',
#   'fotmob_id': 3361078,
#   'fotmob_url': '/matches/cercle-brugge-vs-zulte-waregem/3aw9l4#3361078',
#   'read_status': 'NotStarted'},
#  ...]

# %%
def prepare_shot_data_df(shot_data,team_data):
    shot_df = []
    for shot in shot_data:
        t = {}
        t['event_type'] = shot['eventType']
        t['is_blocked'] = shot['isBlocked']
        t['is_on_target'] = shot['isOnTarget']
        t['team'] = team_data[shot['teamId']]
        t['player'] = shot['playerName']
        t['shot_x'] = shot['x']
        t['shot_y'] = shot['y']
        t['minute'] = shot['min']
        t['min_added'] = shot['minAdded'] if shot['minAdded'] else 0
        t['goal_crossed_y'] = shot['goalCrossedY']
        t['goal_crossed_z'] = shot['goalCrossedZ']
        t['xG'] = shot['expectedGoals']
        t['xGOT'] = shot['expectedGoalsOnTarget'] if shot['expectedGoalsOnTarget'] else 0
        t['shot_type'] = shot['shotType']
        t['is_own_goal'] = shot['isOwnGoal']
        t['play_type'] = shot['situation']
        shot_df.append(t)
    return pd.DataFrame(shot_df)

def prepare_momentum_data_df(mmt_info):
    momentum_df = []
    for mmt in mmt_info:
        mmt['value'] = mmt['value']/10
        momentum_df.append(mmt)
    return momentum_df
    
def get_fotmob_data_of_match_by_id(FOTMOB_URL,match_id):
    url = FOTMOB_URL['game'].format(match_id)
    
    try:
        res = requests.get(url)
        data =res.json()
        team_data = {
            data['general']['homeTeam']['id'] : data['general']['homeTeam']['name'],
            data['general']['awayTeam']['id'] : data['general']['awayTeam']['name'],
        }
        shot_data = data['content']['shotmap']['shots']
        momentum = data['content']['momentum']
        if momentum :
            momentum = prepare_momentum_data_df(momentum['main']['data'])
        else:
            momentum = pd.DataFrame()
        return prepare_shot_data_df(shot_data,team_data),momentum
    except Exception as e :
        print("Exception " , e)

# %%
def get_dfs(ws_id,fb_id,fm_id,season,league):
    ws = sd.WhoScored(leagues=league, seasons=2000+int(season))
    fb = sd.FBref(leagues=league, seasons=2000+int(season))
    
    whoscored_events = ws.read_events(match_id=ws_id)
    fbref_events = fb.read_shot_events(match_id=fb_id)
    fotmob_shot_events,fotmob_momentum_transition = get_fotmob_data_of_match_by_id(FOTMOB_URL,fm_id)
    if fbref_events.shape[0] == fotmob_shot_events.shape[0]:
        fotmob_shot_events['shot_distance'] = [dis for dis in fbref_events['distance']]
    return whoscored_events.reset_index(),fbref_events.reset_index(),fotmob_shot_events,fotmob_momentum_transition

# %%
def change_db_match_state(state,id,db_lock=False):
    if db_lock:
        db_lock.acquire()    
    SQL.execute_update_query(f"update match_schedule set state='{state}' where id = {id}")
    if db_lock:
        db_lock.release()

# %%
def add_momentum_values(ws,FM_mmt):
    ws['momentum'] = None
    period = "FirstHalf"
    if FM_mmt:
        ht_flag = True
    
        for i,row in enumerate(FM_mmt):
            # print(row)
            current_min = row['minute']
            m = row['minute']
            if ht_flag:
                if i==0:
                    prev_min = int(current_min - 1)
                else:
                    prev_min = int(FM_mmt[i-1]['minute'])
            momentum = row['value']
            if int(current_min) > 45:
                period = "SecondHalf"
            if ((int(current_min) == 45 ) & (current_min%45 != 0)) or ((int(current_min) == 90 ) & (current_min%90 != 0)):
                current_min = int(int(current_min)+(current_min%int(current_min))*10)
                min_index_query = ws[(ws['minute'] > prev_min) & (ws['minute'] <= current_min) & (ws['period'] == period)]
                ht_flag=False
                prev_min = current_min
            else:
                ht_flag=True
                min_index_query = ws[(ws['minute'] > prev_min) & (ws['minute'] <= current_min) & (ws['period'] == period)]
    
            ws.loc[ min_index_query.index , 'momentum'] = momentum
    else:
        ws['momentum'] = 0
    return ws

# %%
def merge_shot_data(df,FB,FM,shot_indexes):
    df['x_g'] = None
    df['x_got'] = None
    df['shot_distance'] = None
    df['body_part'] = None
    df['play_type'] = None
    for i,l in enumerate(shot_indexes) :
        try:
        # if 1==1:
            ws_row = df.loc[l].copy()
            fm_row = FM.iloc[i].copy()  # Assuming 'l' corresponds to the index in FM
            fb_row = FB.iloc[i].copy()  # Assuming 'l' corresponds to the index in FB
            
            # Check types and assign values
            ws_row['x_g'] = float(fm_row['xG']) if pd.notnull(fm_row['xG']) else None
            ws_row['x_got'] = float(fm_row['xGOT']) if pd.notnull(fm_row['xGOT']) else None
            ws_row['shot_distance'] = float(fm_row['shot_distance']) if pd.notnull(fm_row['shot_distance']) else None
            ws_row['body_part'] = fm_row['shot_type'] if pd.notnull(fm_row['shot_type']) else None
            ws_row['play_type'] = fm_row['play_type'] if pd.notnull(fm_row['play_type']) else None
    # Update the DataFrame
            df.loc[l] = ws_row
        except Exception as e:
            print(i,l)
            print(e)
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            print(exc_type, fname, exc_tb.tb_lineno)
    return df

# %%
def merge_dfs(DB_id,WS,FB,FM,season,league):
    shot_indexes_in_ws = WS[WS['type'].str.contains('shot|goal', case=False)]
    # df = WS.copy()
    try:
        change_db_match_state('In Progress',DB_id)
        merged_shot_data = merge_shot_data(WS,FB,FM,shot_indexes_in_ws)
        df = add_momentum_values(merged_shot_data,FM_mmt)
        change_db_match_state('Done',DB_id)
    except Exception as e :
        print(e)
        change_db_match_state('Error',DB_id)
        df=pd.DataFrame()
    return df

# %%
def get_complete_event_dataframe(DB_id,ws_id,fb_id,fm_id,season_name,league):
    season = season_name.split('-')[0]
    WS,FB,FM_shot,FM_mmt = get_dfs(ws_id,fb_id,fm_id,season,league)
    df = merge_dfs(DB_id,WS,FB,FM,season,league)
    os.makedirs(rf"D:/Visual Analysis/event dfs/{league}/{season_name}")
    df.to_excel(rf"D:/Visual Analysis/event dfs/{league}/{season_name}/{DB_id}.xlsx")

# %%
match = matches[0]
ws_id = match['whoscored_id']
db_id = match['id']
fb_id = match['fbref_id']
fm_id = match['fotmob_id']
season_name = match['season']
league = match['competition']

# %%
get_complete_event_dataframe(db_id,ws_id,fb_id,fm_id,season_name,league)
# Out:
# [04/04/24 02:20:25] INFO     Saving cached data to C:\Users\Hp\soccerdata\data\WhoScored              _common.py:91
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_complete_event_dataframe(db_id,ws_id,fb_id,fm_id,season_name,league)
#
# Cell In[12], line 3, in get_complete_event_dataframe(DB_id, ws_id, fb_id, fm_id, season_name, league)
#       1 def get_complete_event_dataframe(DB_id,ws_id,fb_id,fm_id,season_name,league):
#       2     season = season_name.split('-')[0]
# ----> 3     WS,FB,FM_shot,FM_mmt = get_dfs(ws_id,fb_id,fm_id,season,league)
#       4     df = merge_dfs(DB_id,WS,FB,FM,season,league)
#       5     os.makedirs(rf"D:/Visual Analysis/event dfs/{league}/{season_name}")
#
# Cell In[7], line 2, in get_dfs(ws_id, fb_id, fm_id, season, league)
#       1 def get_dfs(ws_id,fb_id,fm_id,season,league):
# ----> 2     ws = sd.WhoScored(leagues=league, seasons=2000+int(season))
#       3     fb = sd.FBref(leagues=league, seasons=2000+int(season))
#       5     whoscored_events = ws.read_events(match_id=ws_id)
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\soccerdata\whoscored.py:186, in WhoScored.__init__(self, leagues, seasons, proxy, no_cache, no_store, data_dir, path_to_browser, headless)
#     172 def __init__(
#     173     self,
#     174     leagues: Optional[Union[str, List[str]]] = None,
#    (...)
#     183     headless: bool = False,
#     184 ):
#     185     """Initialize the WhoScored reader."""
# --> 186     super().__init__(
#     187         leagues=leagues,
#     188         proxy=proxy,
#     189         no_cache=no_cache,
#     190         no_store=no_store,
#     191         data_dir=data_dir,
#     192         path_to_browser=path_to_browser,
#     193         headless=headless,
#     194     )
#     195     self.seasons = seasons  # type: ignore
#     196     self.rate_limit = 5
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\soccerdata\_common.py:389, in BaseSeleniumReader.__init__(self, leagues, proxy, no_cache, no_store, data_dir, path_to_browser, headless)
#     386 self.headless = headless
#     388 try:
# --> 389     self._driver = self._init_webdriver()
#     390 except WebDriverException as e:
#     391     logger.error(
#     392         """
#     393         The ChromeDriver was unable to initiate/spawn a new
#    (...)
#     397         e,
#     398     )
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\soccerdata\_common.py:426, in BaseSeleniumReader._init_webdriver(self)
#     424     chrome_options.add_argument("--proxy-server=" + proxy_str)
#     425     chrome_options.add_argument("--host-resolver-rules=" + resolver_rules)
# --> 426 return uc.Chrome(options=chrome_options)
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\undetected_chromedriver\__init__.py:258, in Chrome.__init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, desired_capabilities, advanced_elements, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, user_multi_procs, **kw)
#     251 self.patcher = Patcher(
#     252     executable_path=driver_executable_path,
#     253     force=patcher_force_close,
#     254     version_main=version_main,
#     255     user_multi_procs=user_multi_procs,
#     256 )
#     257 # self.patcher.auto(user_multiprocess = user_multi_num_procs)
# --> 258 self.patcher.auto()
#     260 # self.patcher = patcher
#     261 if not options:
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\undetected_chromedriver\patcher.py:175, in Patcher.auto(self, executable_path, force, version_main, _)
#     172 except FileNotFoundError:
#     173     pass
# --> 175 release = self.fetch_release_number()
#     176 self.version_main = release.version[0]
#     177 self.version_full = release
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\undetected_chromedriver\patcher.py:254, in Patcher.fetch_release_number(self)
#     251         response = conn.read().decode()
#     253     last_versions = json.loads(response)
# --> 254     return LooseVersion(last_versions["channels"]["Stable"]["version"])
#     256 # Fetch the latest minor version of the major version provided
#     257 path = "/latest-versions-per-milestone-with-downloads.json"
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\setuptools\_distutils\version.py:55, in Version.__init__(self, vstring)
#      53 if vstring:
#      54     self.parse(vstring)
# ---> 55 warnings.warn(
#      56     "distutils Version classes are deprecated. "
#      57     "Use packaging.version instead.",
#      58     DeprecationWarning,
#      59     stacklevel=2,
#      60 )
#
# TypeError: issubclass() arg 2 must be a class, a tuple of classes, or a union

# %%
os.makedirs(rf"D:/Visual Analysis/event dfs/{league}/{match['season']}")

# %%
pd.read_excel()
