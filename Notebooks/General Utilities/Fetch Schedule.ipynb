# %%
import soccerdata as sd
import pandas as pd
import traceback
import matplotlib.pyplot as plt
from mplsoccer import Pitch,VerticalPitch
from datetime import datetime,timedelta
import requests,json,config
import matplotlib.patches as patches
import math,sys,os,random
from threading import Thread
import time,concurrent
import numpy as np
from math import isnan
# import mysql.connector
from bs4 import BeautifulSoup

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
FOTMOB_URL = config.getFotMobUrls()
FOTMOB_LEAGUE = config.getFotMobLeagueDict()
CONFIG = config.getGeneralConfig()

# %%
FOTMOB_LEAGUE
# Out:
# {'ENG-Premier League': 47,
#  'ESP-La Liga': 87,
#  'ITA-Serie A': 55,
#  'GER-Bundesliga': 54,
#  'FRA-Ligue 1': 53,
#  'INT-World Cup': 77,
#  'UCL': 42,
#  'UEL': 73,
#  'UECL': 10216,
#  'Eredivisie': 57,
#  'Pro_League': 40,
#  'Primeira_Liga': 61}

# %%
def getFotMobSeasonFixture(league,seasons): # Example [2016,2017] or "23_24"
    # # making season list
    if "list" in str(type(seasons)):
        # "%2F".join(['20'+str(x)for x in season.split('_')])
        season_name_str = [(f'{x%2000}-{(x+1)%2000}',f'20{str(x)}%2F20{str(x+1)}')for x in seasons]
        fixture_urls = [(season,FOTMOB_URL['fixture'].format(FOTMOB_LEAGUE[league],season_str)) for season,season_str in season_name_str]
        
    else:
        season_name_str = "%2F".join(['20'+str(x)for x in seasons.split('_')])
        fixture_urls = [FOTMOB_URL['fixture'].format(FOTMOB_LEAGUE[league],season_name)]
    all_fixtures = []
    for season_nm,fixture_url in fixture_urls:
        fixture_res = requests.get(fixture_url)
        # return
        df = pd.DataFrame()
        
        if fixture_res.status_code == 200 :
            try:
                fixtures = fixture_res.json()
                for match in fixtures :
                    i = df.shape[0]
                    df.loc[i, 'id']=match['id']
                    df.loc[i, 'league']=league.split('-')[-1].strip(' ')
                    df.loc[i, 'season']=season_nm
                    df.loc[i, 'url']=match['pageUrl']
                    df.loc[i, 'home_team']=match['home']['name']
                    df.loc[i, 'away_team']=match['away']['name']
                    df.loc[i, 'date']=match['status']['utcTime']
                all_fixtures.append(df)
            except JSONDecodeError as jde :
                print("Json Error ")
                print("Data Response ",fixture_res.content.decode())
                all_fixtures.append(df)
            except Exception as e :
                print("General Error ")
                print("Exception as  : ",str(e))
                all_fixtures.append(df)
    print(f"Returning {len(all_fixtures)} DFs combination")            
    return pd.concat(all_fixtures, ignore_index=True)    
# getFotMobSeasonFixture(league,season_name)
# getFotMobSeasonFixture(league,[2017,2016])
# getFotMobSeasonFixture(league,season)

# %%
def pre_process_dataframe_for_schedules(df_name,df_under):
    
    df_under = df_under
    if df_name == "WS":
        df_under = df_under.reset_index()
        df_under['date'] = pd.to_datetime(df_under['date']).dt.tz_localize(None).dt.tz_localize('UTC') + timedelta(hours=-1)
        df_under['season'] = df_under['season'].astype(str).apply(lambda x: x[:2] + '-' + x[2:])
    elif df_name == "FB" :
        df_under = df_under.reset_index()
        df_under['season'] = df_under['season'].astype(str).apply(lambda x: x[:2] + '-' + x[2:])
        df_under['date'] = df_under['date'].astype(str)
        df_under['time'] = df_under['time'].astype(str).replace('<NA>',"00:00")
        df_under['date'] = df_under['date']+' '+df_under['time']+":00"
        df_under['date'] = pd.to_datetime(df_under['date']).dt.tz_localize(None).dt.tz_localize('UTC') + timedelta(hours=-2)
        
    else:
        df_under = df_under.reset_index()
        df_under['date'] = pd.to_datetime(df_under['date'].str.split('Z').str[0].str.split(".").str[0],format='%Y-%m-%dT%H:%M:%S')
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('.').str[0],format='%Y-%m-%dT%H:%M:%SZ')
        # df_under['date'] = pd.to_datetime(df_under['date']) + timedelta(hours=1)
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('T').str[0])
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('T').str[0])
        df_under['date'] = df_under['date'].dt.tz_localize(None).dt.tz_localize('UTC')

    # df_under['date'] = df_under['date'].dt.date
    return df_under.sort_values(['date', 'home_team', 'away_team'])
# pre_process_dataframe_for_schedules('FM',fotmob_df),\
# pre_process_dataframe_for_schedules('FB',fbref_df),\
# pre_process_dataframe_for_schedules('WS',whoscored_df)

# %%
def update_team_alias(WS_df,FB_df,FM_df,file_path,write_mode=True):
    try:
        season_set = set([x.year for x in WS_df['date']])
        if write_mode or 1:
            with open(file_path,'r') as f :
                existing_alias = json.load(f)
        else:
            existing_alias = {}
        team_alias = existing_alias      
        for season in season_set:
            # print("")
            # print(team_alias)
            WS_mw1,FB_mw1,FM_mw1 = getFirstMatchweekOfSeason(WS_df,FB_df,FM_df,season)
            if WS_mw1.empty or FB_mw1.empty or FM_mw1.empty:
                continue
            # x = getFirstMatchweekOfSeason(WS_df,FB_df,FM_df,season)
            # WS = sorted(list(set(sortedlist(WS_mw1['home_team'].unique()) + list(WS_mw1['away_team'].unique())))))
            # FB = sorted(list(set(sorted(list(FB_mw1['home_team'].unique()) + list(FB_mw1['away_team'].unique())))))
            # FM = sorted(list(set(sorted(list(FM_mw1['home_team'].unique()) + list(FM_mw1['away_team'].unique())))))
            
            WS = list(WS_mw1['home_team'].unique()) + list(WS_mw1['away_team'].unique())
            FB = list(FB_mw1['home_team'].unique()) + list(FB_mw1['away_team'].unique())
            FM = list(FM_mw1['home_team'].unique()) + list(FM_mw1['away_team'].unique())
            print(len(WS),len(FB),len(FM))
            # print(WS)
            # print(FM)
            # print(FB)
            for i,team in enumerate(WS):
                flag = False
                if team not in team_alias.keys():
                    team_alias[team] = [team]
                    flag = True
                if flag : 
                    if team != FB[i] :
                        team_alias[team].append(FB[i])
                    if team != FM[i] :
                        team_alias[team].append(FM[i])
                team_alias[team] = list(set(team_alias[team]))
        merged_alias = {**existing_alias,**team_alias}
        print(team_alias)
        if write_mode :
            with open(file_path,'w') as f :
                f.write(json.dumps(merged_alias))
        return merged_alias
    except Exception as e:
        print("Err : update_team_alias : ",e)
        import sys,os
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print(exc_type, fname, exc_tb.tb_lineno)
        
    return False
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'])
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'],write_mode = False)

# %%
def getFirstMatchweekOfSeason(WS,FB,FM,season):
    print(f" ===================== SEASON NAME : {season} ===================== ")
    # start_border_date = datetime.strptime(f'25-07-{season}','%d-%m-%Y').date()
    # end_border_date = datetime.strptime(f'25-07-{season+1}','%d-%m-%Y').date()
    start_border_date = pd.to_datetime(datetime.strptime(f'25-07-{season}','%d-%m-%Y'), utc=True)
    end_border_date = pd.to_datetime(datetime.strptime(f'25-07-{season+1}','%d-%m-%Y'), utc=True)
    season = season%2000
    season_name = str(season)+'-'+str(season+1)
    print(season_name)
    # end_border_date = datetime.strptime(f'25-07-{season+1}','%d-%m-%Y')

    # season_wide_df_WS = WS[(WS['date'] > start_border_date) & (WS['date'] < end_border_date)]
    # season_wide_df_FM = FM[(FM['date'] > start_border_date) & (FM['date'] < end_border_date)]
    # season_wide_df_FB = FB[(FB['date'] > start_border_date) & (FB['date'] < end_border_date)]
    
    season_wide_df_WS = WS[WS['season'] == season_name]
    season_wide_df_FM = FM[FM['season'] == season_name]
    season_wide_df_FB = FB[FB['season'] == season_name]
    if season_wide_df_WS.empty or season_wide_df_FM.empty or season_wide_df_FB.empty:
        return pd.DataFrame(),pd.DataFrame(),pd.DataFrame()
    # season_wide_df_WS.to_csv("WS.csv")
    # season_wide_df_FM.to_csv("FM.csv")
    # season_wide_df_FB.to_csv("FB.csv")
    
    ht_team_count_arr =[len(list(season_wide_df_WS['home_team'].unique())),
        len(list(season_wide_df_FB['home_team'].unique())),
        len(list(season_wide_df_FM['home_team'].unique()))
    ]
    at_team_count_arr =[len(sorted(list(season_wide_df_WS['home_team'].unique()))),
        len(sorted(list(season_wide_df_FB['home_team'].unique()))),
        len(sorted(list(season_wide_df_FM['home_team'].unique())))
    ]
    
    ht_team_count = sum(ht_team_count_arr)/len(ht_team_count_arr)
    at_team_count = sum(at_team_count_arr)/len(at_team_count_arr)
    GW_WS = []
    GW_FB = []
    GW_FM = []
    if ht_team_count == at_team_count:
        team_list = list(season_wide_df_WS['home_team'].unique())
        i=0
        while len(team_list):
            # print(f"Left Teams : {len(team_list)}  | {team_list}")
            ht = season_wide_df_WS.iloc[i]['home_team'] 
            at = season_wide_df_WS.iloc[i]['away_team']
            c = 0
            if ht in team_list:
                # print("Removing HT... ",ht)
                team_list.remove(ht)
                c+=1
            if at in team_list:
                # print("Removing AT... ",at)
                team_list.remove(at)
                c+=1
            # print()
            if c != 0:
                # print(f"Adding Game : {ht} v {at} at index = {i}")
                # if i == 15:
                    # display(season_wide_df_WS.iloc[i])
                    # display(season_wide_df_FB.iloc[i])
                    # display(season_wide_df_FM.iloc[i])
                
                GW_WS.append(season_wide_df_WS.iloc[i])
                GW_FB.append(season_wide_df_FB.iloc[i])
                GW_FM.append(season_wide_df_FM.iloc[i])
                # print(f"Counts = WS : {len(GW_WS)} | FB : {len(GW_FB)} | FM : {len(GW_FM)}")
            else:
                # print(f"Can't add game : {ht} v {at} at index = {i}")
                # print("Kela and i hogya,",i, " With  HT : ",ht, " and AT : ",at)
                # print("Kela : ",team_list)
                # print(season_wide_df_WS.shape)
                if i > 120 :
                    break
            i+=1
            # print('=====================================')
    else:
        return f"Error : HT Count : {ht_team_count} | AT Count : {at_team_count}"
    # print(len(GW_WS),len(GW_FB),len(GW_FM))
    return pd.DataFrame(GW_WS),pd.DataFrame(GW_FB),pd.DataFrame(GW_FM)
# 
# a,b,c = getFirstMatchweekOfSeason(WS,FB,FM,2019)

# %%
# for i in range(a.shape[0]) :
#     print(i)
#     ht_ws = a.iloc[i]['home_team']
#     at_ws = a.iloc[i]['away_team']
#     dt_ws = a.iloc[i]['date']
    
#     ht_fb = b.iloc[i]['home_team']
#     at_fb = b.iloc[i]['away_team']
#     dt_fb = b.iloc[i]['date']
    
#     ht_fm = c.iloc[i]['home_team']
#     at_fm = c.iloc[i]['away_team']
#     dt_fm = c.iloc[i]['date']

#     print(f"WS : {ht_ws} v {at_ws} at {dt_ws}")
#     print(f"FB : {ht_fb} v {at_fb} at {dt_fb}")
#     print(f"FM : {ht_fm} v {at_fm} at {dt_fm}")

# %%
def combine_dataframes(WS_init,FB_init,FM_init,team_alias):
    WS = WS_init
    FB = FB_init
    FM = FM_init
    print(WS.shape)
    WS['source'] = "WhoScored"
    FM['source'] = "FotMob"
    FB['source'] = "FBref"
    try:
        WS['date'] = WS['date'].dt.date
        FM['date'] = FM['date'].dt.date
        FB['date'] = FB['date'].dt.date
    except :
        print("Ik about the dt thing")
        
    df = pd.DataFrame()
    dfs = [WS,FM,FB]
    # Find the DataFrame with the least number of rows
    loop_df = min(dfs, key=len)
    try:
        for x in WS.index:
            msg = None
            # Get the row data
            WS_row = WS.loc[x]
            # row = loop_df.loc[x]
            # print("Source is :",row['source'])
            row_home_team = WS_row['home_team']
            row_away_team = WS_row['away_team']
            row_date = WS_row['date']
            row_season = WS_row['season']
            row_round = str(WS_row['stage'])
            acceptable_rounds = ['Regular season', league, "None",None,'nan',league.split('-')[-1].strip(' '),league.replace('_',' '),
                                'Eredivisie ECL Playoff','Europa League Playoff', # Dutch League
                                 'Jupiler League','First Division A','Playoff Championship', # belgian League
                                "Champions League Group Stages","Champions League Final Stage", # UCL
                                 "Europa League Group Stages","Europa League Final Stage" #UEL
                                ]
            # print(acceptable_rounds)
            if row_round.strip(' ') not in acceptable_rounds:
                print("Row Round nikla : ",row_round)
                continue
    
            home_team_alias = team_alias[row_home_team]
            away_team_alias = team_alias[row_away_team]
    
            #Get DF ROWS
            # WS_row = WS[(WS['home_team'].isin(home_team_alias)) & (WS['away_team'].isin(away_team_alias)) & (WS['date'] == row_date)]
            FM_row = FM[(FM['home_team'].isin(home_team_alias)) & (FM['away_team'].isin(away_team_alias)) & (FM['season'] == row_season) & (FM['date'] == row_date)]
            FB_row = FB[(FB['home_team'].isin(home_team_alias)) & (FB['away_team'].isin(away_team_alias)) & (FB['season'] == row_season) & (FB['date'] == row_date)]
    
            if FB_row.empty or FM_row.empty or WS_row.empty:
                print("Guilty index : ",x)
                print(" HT ALias : ",home_team_alias)
                print(" AT ALias : ",away_team_alias)
                print()
                print(WS.loc[x])
                print()
                msg = f"Problem | Home : {row_home_team} | Away : {row_away_team} | Date : {row_date} \n "
                msg += f"DFs | WhoScored : {WS_row.empty} | FBRef : {FB_row.empty} | FotMob : {FM_row.empty}. \n"
                # msg += f"TIME | WhoScored : ({WS['date'][x]}) | FBRef : ({FM['date'][x]}) | FotMob : ({FB['date'][x]})."
                print(msg)
                if not FB_row.empty:
                    print("FB ROW")
                    if "Cancelled" in str(FB_row.iloc[0]['notes']):
                        continue
                return msg
            else:
                # Keeping only first row if all exist
                # print(WS_row.shape,FB_row.shape,FM_row.shape)
                try:
                    FB_row = FB_row.iloc[0]
                    FM_row = FM_row.iloc[0]
                except Exception as e:
                    print(f"DATE : {row_date} | HT : {row_home_team} | AT :{row_away_team}")
                    if "Cancelled" in str(FB_row['notes']):
                        continue
                    print("Excepitoin : ",e)
                    print("FB ROW IS  : ")
                    print(FB_row)
                    print()
                    print("FM ROW IS  : ")
                    print(FM_row)
                    print()
            # avoiding matches which are not played yet
            if str(FB_row['game_id']) == 'nan' or FB_row['match_report'] is None:
                continue
                
            i = df.shape[0]
            
            df.loc[i, 'competition']=WS_row['league']
            df.loc[i, 'season']=WS_row['season']
            df.loc[i, 'stage']=WS_row['stage']
            
            df.loc[i, 'date'] = row_date
            df.loc[i, 'home_team'] = row_home_team        
            df.loc[i, 'away_team'] = row_away_team
            # print("INDEX",df)
            df.loc[i, 'score'] = FB_row['score']
            
            df.loc[i, 'whoscored_id']=WS_row['game_id']
            df.loc[i, 'whoscored_url']=WS_row['url']
            
            df.loc[i, 'fbref_id']=FB_row['game_id']
            df.loc[i, 'fbref_url']=FB_row['match_report']
    
            df.loc[i, 'fotmob_id']=FM_row['id']
            df.loc[i, 'fotmob_url']=FM_row['url']
        return df
    except Exception as e:
        print("Merge DF Exception Occured : ",str(e))
        import sys,os
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print(exc_type, fname, exc_tb.tb_lineno)
        print('-------')
        print('-------', msg)
        raise e
combine_dataframes(WS,FB,FM,team_aliases)
# FM.to_csv("Test.csv")
# Out:
# (136, 9)
#     competition season                       stage        date  \
# 0           UEL  23-24  Europa League Group Stages  2023-09-21
# 1           UEL  23-24  Europa League Group Stages  2023-09-21
# 2           UEL  23-24  Europa League Group Stages  2023-09-21
# 3           UEL  23-24  Europa League Group Stages  2023-09-21
# 4           UEL  23-24  Europa League Group Stages  2023-09-21
# 5           UEL  23-24  Europa League Group Stages  2023-09-21
# 6           UEL  23-24  Europa League Group Stages  2023-09-21
# 7           UEL  23-24  Europa League Group Stages  2023-09-21
# 8           UEL  23-24  Europa League Group Stages  2023-09-21
# 9           UEL  23-24  Europa League Group Stages  2023-09-21
# 10          UEL  23-24  Europa League Group Stages  2023-09-21
# 11          UEL  23-24  Europa League Group Stages  2023-09-21
# 12          UEL  23-24  Europa League Group Stages  2023-09-21
# 13          UEL  23-24  Europa League Group Stages  2023-09-21
# 14          UEL  23-24  Europa League Group Stages  2023-09-21
# 15          UEL  23-24  Europa League Group Stages  2023-09-21
# 16          UEL  23-24  Europa League Group Stages  2023-10-05
# 17          UEL  23-24  Europa League Group Stages  2023-10-05
# 18          UEL  23-24  Europa League Group Stages  2023-10-05
# 19          UEL  23-24  Europa League Group Stages  2023-10-05
# 20          UEL  23-24  Europa League Group Stages  2023-10-05
# 21          UEL  23-24  Europa League Group Stages  2023-10-05
# 22          UEL  23-24  Europa League Group Stages  2023-10-05
# 23          UEL  23-24  Europa League Group Stages  2023-10-05
# 24          UEL  23-24  Europa League Group Stages  2023-10-05
# 25          UEL  23-24  Europa League Group Stages  2023-10-05
# 26          UEL  23-24  Europa League Group Stages  2023-10-05
# 27          UEL  23-24  Europa League Group Stages  2023-10-05
# 28          UEL  23-24  Europa League Group Stages  2023-10-05
# 29          UEL  23-24  Europa League Group Stages  2023-10-05
# 30          UEL  23-24  Europa League Group Stages  2023-10-05
# 31          UEL  23-24  Europa League Group Stages  2023-10-05
# 32          UEL  23-24  Europa League Group Stages  2023-10-26
# 33          UEL  23-24  Europa League Group Stages  2023-10-26
# 34          UEL  23-24  Europa League Group Stages  2023-10-26
# 35          UEL  23-24  Europa League Group Stages  2023-10-26
# 36          UEL  23-24  Europa League Group Stages  2023-10-26
# 37          UEL  23-24  Europa League Group Stages  2023-10-26
# 38          UEL  23-24  Europa League Group Stages  2023-10-26
# 39          UEL  23-24  Europa League Group Stages  2023-10-26
# 40          UEL  23-24  Europa League Group Stages  2023-10-26
# 41          UEL  23-24  Europa League Group Stages  2023-10-26
# 42          UEL  23-24  Europa League Group Stages  2023-10-26
# 43          UEL  23-24  Europa League Group Stages  2023-10-26
# 44          UEL  23-24  Europa League Group Stages  2023-10-26
# 45          UEL  23-24  Europa League Group Stages  2023-10-26
# 46          UEL  23-24  Europa League Group Stages  2023-10-26
# 47          UEL  23-24  Europa League Group Stages  2023-11-09
# 48          UEL  23-24  Europa League Group Stages  2023-11-09
# 49          UEL  23-24  Europa League Group Stages  2023-11-09
# 50          UEL  23-24  Europa League Group Stages  2023-11-09
# 51          UEL  23-24  Europa League Group Stages  2023-11-09
# 52          UEL  23-24  Europa League Group Stages  2023-11-09
# 53          UEL  23-24  Europa League Group Stages  2023-11-09
# 54          UEL  23-24  Europa League Group Stages  2023-11-09
# 55          UEL  23-24  Europa League Group Stages  2023-11-09
# 56          UEL  23-24  Europa League Group Stages  2023-11-09
# 57          UEL  23-24  Europa League Group Stages  2023-11-09
# 58          UEL  23-24  Europa League Group Stages  2023-11-09
# 59          UEL  23-24  Europa League Group Stages  2023-11-09
# 60          UEL  23-24  Europa League Group Stages  2023-11-09
# 61          UEL  23-24  Europa League Group Stages  2023-11-09
# 62          UEL  23-24  Europa League Group Stages  2023-11-09
# 63          UEL  23-24  Europa League Group Stages  2023-11-30
# 64          UEL  23-24  Europa League Group Stages  2023-11-30
# 65          UEL  23-24  Europa League Group Stages  2023-11-30
# 66          UEL  23-24  Europa League Group Stages  2023-11-30
# 67          UEL  23-24  Europa League Group Stages  2023-11-30
# 68          UEL  23-24  Europa League Group Stages  2023-11-30
# 69          UEL  23-24  Europa League Group Stages  2023-11-30
# 70          UEL  23-24  Europa League Group Stages  2023-11-30
# 71          UEL  23-24  Europa League Group Stages  2023-11-30
# 72          UEL  23-24  Europa League Group Stages  2023-11-30
# 73          UEL  23-24  Europa League Group Stages  2023-11-30
# 74          UEL  23-24  Europa League Group Stages  2023-11-30
# 75          UEL  23-24  Europa League Group Stages  2023-11-30
# 76          UEL  23-24  Europa League Group Stages  2023-11-30
# 77          UEL  23-24  Europa League Group Stages  2023-11-30
# 78          UEL  23-24  Europa League Group Stages  2023-11-30
# 79          UEL  23-24  Europa League Group Stages  2023-12-06
# 80          UEL  23-24  Europa League Group Stages  2023-12-14
# 81          UEL  23-24  Europa League Group Stages  2023-12-14
# 82          UEL  23-24  Europa League Group Stages  2023-12-14
# 83          UEL  23-24  Europa League Group Stages  2023-12-14
# 84          UEL  23-24  Europa League Group Stages  2023-12-14
# 85          UEL  23-24  Europa League Group Stages  2023-12-14
# 86          UEL  23-24  Europa League Group Stages  2023-12-14
# 87          UEL  23-24  Europa League Group Stages  2023-12-14
# 88          UEL  23-24  Europa League Group Stages  2023-12-14
# 89          UEL  23-24  Europa League Group Stages  2023-12-14
# 90          UEL  23-24  Europa League Group Stages  2023-12-14
# 91          UEL  23-24  Europa League Group Stages  2023-12-14
# 92          UEL  23-24  Europa League Group Stages  2023-12-14
# 93          UEL  23-24  Europa League Group Stages  2023-12-14
# 94          UEL  23-24  Europa League Group Stages  2023-12-14
# 95          UEL  23-24  Europa League Group Stages  2023-12-14
# 96          UEL  23-24   Europa League Final Stage  2024-02-15
# 97          UEL  23-24   Europa League Final Stage  2024-02-15
# 98          UEL  23-24   Europa League Final Stage  2024-02-15
# 99          UEL  23-24   Europa League Final Stage  2024-02-15
# 100         UEL  23-24   Europa League Final Stage  2024-02-15
# 101         UEL  23-24   Europa League Final Stage  2024-02-15
# 102         UEL  23-24   Europa League Final Stage  2024-02-15
# 103         UEL  23-24   Europa League Final Stage  2024-02-15
# 104         UEL  23-24   Europa League Final Stage  2024-02-22
# 105         UEL  23-24   Europa League Final Stage  2024-02-22
# 106         UEL  23-24   Europa League Final Stage  2024-02-22
# 107         UEL  23-24   Europa League Final Stage  2024-02-22
# 108         UEL  23-24   Europa League Final Stage  2024-02-22
# 109         UEL  23-24   Europa League Final Stage  2024-02-22
# 110         UEL  23-24   Europa League Final Stage  2024-02-22
# 111         UEL  23-24   Europa League Final Stage  2024-02-22
# 112         UEL  23-24   Europa League Final Stage  2024-03-06
# 113         UEL  23-24   Europa League Final Stage  2024-03-07
# 114         UEL  23-24   Europa League Final Stage  2024-03-07
# 115         UEL  23-24   Europa League Final Stage  2024-03-07
# 116         UEL  23-24   Europa League Final Stage  2024-03-07
# 117         UEL  23-24   Europa League Final Stage  2024-03-07
# 118         UEL  23-24   Europa League Final Stage  2024-03-07
# 119         UEL  23-24   Europa League Final Stage  2024-03-07
# 120         UEL  23-24   Europa League Final Stage  2024-03-14
# 121         UEL  23-24   Europa League Final Stage  2024-03-14
# 122         UEL  23-24   Europa League Final Stage  2024-03-14
# 123         UEL  23-24   Europa League Final Stage  2024-03-14
# 124         UEL  23-24   Europa League Final Stage  2024-03-14
# 125         UEL  23-24   Europa League Final Stage  2024-03-14
# 126         UEL  23-24   Europa League Final Stage  2024-03-14
# 127         UEL  23-24   Europa League Final Stage  2024-03-14
#
#              home_team          away_team        score  whoscored_id  \
# 0     Bayer Leverkusen            Haecken          4–0     1775788.0
# 1           FC Sheriff               Roma          1–2     1775740.0
# 2                 LASK          Liverpool          1–3     1775716.0
# 3        Panathinaikos         Villarreal          2–0     1775777.0
# 4           Qarabag FK              Molde          1–0     1775789.0
# 5               Rennes      Maccabi Haifa          3–0     1775776.0
# 6          Servette FC      Slavia Prague          0–2     1775741.0
# 7    Union St.Gilloise           Toulouse          1–1     1775717.0
# 8                 Ajax          Marseille          3–3     1775728.0
# 9             Atalanta  Rakow Czestochowa          2–0     1775774.0
# 10            Brighton         AEK Athens          2–3     1775729.0
# 11          Olympiacos           Freiburg          2–3     1775705.0
# 12             Rangers         Real Betis          1–0     1775753.0
# 13       Sparta Prague      Aris Limassol          3–2     1775752.0
# 14          Sturm Graz        Sporting CP          1–2     1775775.0
# 15            West Ham   TSC Backa Topola          3–1     1775704.0
# 16          AEK Athens               Ajax          1–1     1775731.0
# 17       Aris Limassol            Rangers          2–1     1775755.0
# 18            Freiburg           West Ham          1–2     1775706.0
# 19           Marseille           Brighton          2–2     1775730.0
# 20   Rakow Czestochowa         Sturm Graz          0–1     1775765.0
# 21          Real Betis      Sparta Prague          2–1     1775754.0
# 22         Sporting CP           Atalanta          1–2     1775764.0
# 23    TSC Backa Topola         Olympiacos          2–2     1775707.0
# 24             Haecken         Qarabag FK          0–1     1775791.0
# 25           Liverpool  Union St.Gilloise          2–0     1775718.0
# 26       Maccabi Haifa      Panathinaikos          0–0     1775779.0
# 27               Molde   Bayer Leverkusen          1–2     1775790.0
# 28                Roma        Servette FC          4–0     1775742.0
# 29       Slavia Prague         FC Sheriff          6–0     1775743.0
# 30            Toulouse               LASK          1–0     1775719.0
# 31          Villarreal             Rennes          1–0     1775778.0
# 32       Aris Limassol         Real Betis          0–1     1775757.0
# 33           Marseille         AEK Athens          3–1     1775732.0
# 34               Molde            Haecken          5–1     1775792.0
# 35          Olympiacos           West Ham          2–1     1775708.0
# 36   Rakow Czestochowa        Sporting CP          1–1     1775766.0
# 37       Sparta Prague            Rangers          0–0     1775756.0
# 38          Sturm Graz           Atalanta          2–2     1775767.0
# 39    TSC Backa Topola           Freiburg          1–3     1775709.0
# 40    Bayer Leverkusen         Qarabag FK          5–1     1775793.0
# 41            Brighton               Ajax          2–0     1775733.0
# 42          FC Sheriff        Servette FC          1–1     1775745.0
# 43           Liverpool           Toulouse          5–1     1775721.0
# 44       Panathinaikos             Rennes          1–2     1775780.0
# 45                Roma      Slavia Prague          2–0     1775744.0
# 46   Union St.Gilloise               LASK          2–1     1775720.0
# 47                Ajax           Brighton          0–2     1775734.0
# 48                LASK  Union St.Gilloise          3–0     1775722.0
# 49       Maccabi Haifa         Villarreal          1–2     1775783.0
# 50          Qarabag FK   Bayer Leverkusen          0–1     1775794.0
# 51              Rennes      Panathinaikos          3–1     1775782.0
# 52         Servette FC         FC Sheriff          2–1     1775746.0
# 53       Slavia Prague               Roma          2–0     1775747.0
# 54            Toulouse          Liverpool          3–2     1775723.0
# 55          AEK Athens          Marseille          0–2     1775735.0
# 56            Atalanta         Sturm Graz          1–0     1775768.0
# 57            Freiburg   TSC Backa Topola          5–0     1775710.0
# 58             Haecken              Molde          1–3     1775795.0
# 59             Rangers      Sparta Prague          2–1     1775759.0
# 60          Real Betis      Aris Limassol          4–1     1775758.0
# 61         Sporting CP  Rakow Czestochowa          2–1     1775769.0
# 62            West Ham         Olympiacos          1–0     1775711.0
# 63          AEK Athens           Brighton          0–1     1775736.0
# 64            Atalanta        Sporting CP          1–1     1775770.0
# 65            Freiburg         Olympiacos          5–0     1775712.0
# 66       Maccabi Haifa             Rennes          0–3     1775784.0
# 67       Sparta Prague         Real Betis          1–0     1775760.0
# 68          Sturm Graz  Rakow Czestochowa          0–1     1775771.0
# 69    TSC Backa Topola           West Ham          0–1     1775713.0
# 70          FC Sheriff      Slavia Prague          2–3     1775749.0
# 71             Haecken   Bayer Leverkusen          0–2     1775797.0
# 72           Liverpool               LASK          4–0     1775725.0
# 73           Marseille               Ajax          4–3     1775737.0
# 74               Molde         Qarabag FK          2–2     1775796.0
# 75             Rangers      Aris Limassol          1–1     1775761.0
# 76         Servette FC               Roma          1–1     1775748.0
# 77            Toulouse  Union St.Gilloise          0–0     1775724.0
# 78          Villarreal      Panathinaikos          3–2     1775785.0
# 79          Villarreal      Maccabi Haifa          0–0     1775781.0
# 80    Bayer Leverkusen              Molde          5–1     1775798.0
# 81                LASK           Toulouse          1–2     1775727.0
# 82       Panathinaikos      Maccabi Haifa          1–2     1775787.0
# 83          Qarabag FK            Haecken          2–1     1775799.0
# 84              Rennes         Villarreal          2–3     1775786.0
# 85                Roma         FC Sheriff          3–0     1775750.0
# 86       Slavia Prague        Servette FC          4–0     1775751.0
# 87   Union St.Gilloise          Liverpool          2–1     1775726.0
# 88                Ajax         AEK Athens          3–1     1775738.0
# 89       Aris Limassol      Sparta Prague          1–3     1775763.0
# 90            Brighton          Marseille          1–0     1775739.0
# 91          Olympiacos   TSC Backa Topola          5–2     1775715.0
# 92   Rakow Czestochowa           Atalanta          0–4     1775773.0
# 93          Real Betis            Rangers          2–3     1775762.0
# 94         Sporting CP         Sturm Graz          3–0     1775772.0
# 95            West Ham           Freiburg          2–0     1775714.0
# 96      BSC Young Boys        Sporting CP          1–3     1789453.0
# 97           Feyenoord               Roma          1–1     1789447.0
# 98         Galatasaray      Sparta Prague          3–2     1789459.0
# 99    Shakhtar Donetsk          Marseille          2–2     1789461.0
# 100           AC Milan             Rennes          3–0     1789449.0
# 101            Benfica           Toulouse          2–1     1789455.0
# 102              Braga         Qarabag FK          2–4     1789457.0
# 103               Lens           Freiburg          0–0     1789451.0
# 104           Freiburg               Lens          3–2     1789452.0
# 105         Qarabag FK              Braga          2–3     1789458.0
# 106             Rennes           AC Milan          3–2     1789450.0
# 107           Toulouse            Benfica          0–0     1789456.0
# 108          Marseille   Shakhtar Donetsk          3–1     1789462.0
# 109               Roma          Feyenoord  (4) 1–1 (2)     1789448.0
# 110      Sparta Prague        Galatasaray          4–1     1789460.0
# 111        Sporting CP     BSC Young Boys          1–1     1789454.0
# 112        Sporting CP           Atalanta          1–1     1805545.0
# 113         Qarabag FK   Bayer Leverkusen          2–2     1805549.0
# 114               Roma           Brighton          4–0     1805539.0
# 115      Sparta Prague          Liverpool          1–5     1805535.0
# 116           AC Milan      Slavia Prague          4–2     1805547.0
# 117            Benfica            Rangers          2–2     1805541.0
# 118           Freiburg           West Ham          1–0     1805543.0
# 119          Marseille         Villarreal          4–0     1805537.0
# 120            Rangers            Benfica          0–1     1805542.0
# 121      Slavia Prague           AC Milan          1–3     1805548.0
# 122         Villarreal          Marseille          3–1     1805538.0
# 123           West Ham           Freiburg          5–0     1805544.0
# 124           Atalanta        Sporting CP          2–1     1805546.0
# 125   Bayer Leverkusen         Qarabag FK          3–2     1805550.0
# 126           Brighton               Roma          1–0     1805540.0
# 127          Liverpool      Sparta Prague          6–1     1805536.0
#
#                                                                                                      whoscored_url  \
# 0         https://1xbet.whoscored.com/Matches/1775788/Live/Europe-Europa-League-2023-2024-Bayer-Leverkusen-Haecken
# 1                  https://1xbet.whoscored.com/Matches/1775740/Live/Europe-Europa-League-2023-2024-FC-Sheriff-Roma
# 2                   https://1xbet.whoscored.com/Matches/1775716/Live/Europe-Europa-League-2023-2024-LASK-Liverpool
# 3         https://1xbet.whoscored.com/Matches/1775777/Live/Europe-Europa-League-2023-2024-Panathinaikos-Villarreal
# 4                 https://1xbet.whoscored.com/Matches/1775789/Live/Europe-Europa-League-2023-2024-Qarabag-FK-Molde
# 5             https://1xbet.whoscored.com/Matches/1775776/Live/Europe-Europa-League-2023-2024-Rennes-Maccabi-Haifa
# 6        https://1xbet.whoscored.com/Matches/1775741/Live/Europe-Europa-League-2023-2024-Servette-FC-Slavia-Prague
# 7       https://1xbet.whoscored.com/Matches/1775717/Live/Europe-Europa-League-2023-2024-Union-St-Gilloise-Toulouse
# 8                   https://1xbet.whoscored.com/Matches/1775728/Live/Europe-Europa-League-2023-2024-Ajax-Marseille
# 9       https://1xbet.whoscored.com/Matches/1775774/Live/Europe-Europa-League-2023-2024-Atalanta-Rakow-Czestochowa
# 10             https://1xbet.whoscored.com/Matches/1775729/Live/Europe-Europa-League-2023-2024-Brighton-AEK-Athens
# 11             https://1xbet.whoscored.com/Matches/1775705/Live/Europe-Europa-League-2023-2024-Olympiacos-Freiburg
# 12              https://1xbet.whoscored.com/Matches/1775753/Live/Europe-Europa-League-2023-2024-Rangers-Real-Betis
# 13     https://1xbet.whoscored.com/Matches/1775752/Live/Europe-Europa-League-2023-2024-Sparta-Prague-Aris-Limassol
# 14          https://1xbet.whoscored.com/Matches/1775775/Live/Europe-Europa-League-2023-2024-Sturm-Graz-Sporting-CP
# 15       https://1xbet.whoscored.com/Matches/1775704/Live/Europe-Europa-League-2023-2024-West-Ham-TSC-Backa-Topola
# 16                 https://1xbet.whoscored.com/Matches/1775731/Live/Europe-Europa-League-2023-2024-AEK-Athens-Ajax
# 17           https://1xbet.whoscored.com/Matches/1775755/Live/Europe-Europa-League-2023-2024-Aris-Limassol-Rangers
# 18               https://1xbet.whoscored.com/Matches/1775706/Live/Europe-Europa-League-2023-2024-Freiburg-West-Ham
# 19              https://1xbet.whoscored.com/Matches/1775730/Live/Europe-Europa-League-2023-2024-Marseille-Brighton
# 20    https://1xbet.whoscored.com/Matches/1775765/Live/Europe-Europa-League-2023-2024-Rakow-Czestochowa-Sturm-Graz
# 21        https://1xbet.whoscored.com/Matches/1775754/Live/Europe-Europa-League-2023-2024-Real-Betis-Sparta-Prague
# 22            https://1xbet.whoscored.com/Matches/1775764/Live/Europe-Europa-League-2023-2024-Sporting-CP-Atalanta
# 23     https://1xbet.whoscored.com/Matches/1775707/Live/Europe-Europa-League-2023-2024-TSC-Backa-Topola-Olympiacos
# 24              https://1xbet.whoscored.com/Matches/1775791/Live/Europe-Europa-League-2023-2024-Haecken-Qarabag-FK
# 25     https://1xbet.whoscored.com/Matches/1775718/Live/Europe-Europa-League-2023-2024-Liverpool-Union-St-Gilloise
# 26     https://1xbet.whoscored.com/Matches/1775779/Live/Europe-Europa-League-2023-2024-Maccabi-Haifa-Panathinaikos
# 27          https://1xbet.whoscored.com/Matches/1775790/Live/Europe-Europa-League-2023-2024-Molde-Bayer-Leverkusen
# 28                https://1xbet.whoscored.com/Matches/1775742/Live/Europe-Europa-League-2023-2024-Roma-Servette-FC
# 29        https://1xbet.whoscored.com/Matches/1775743/Live/Europe-Europa-League-2023-2024-Slavia-Prague-FC-Sheriff
# 30                   https://1xbet.whoscored.com/Matches/1775719/Live/Europe-Europa-League-2023-2024-Toulouse-LASK
# 31               https://1xbet.whoscored.com/Matches/1775778/Live/Europe-Europa-League-2023-2024-Villarreal-Rennes
# 32        https://1xbet.whoscored.com/Matches/1775757/Live/Europe-Europa-League-2023-2024-Aris-Limassol-Real-Betis
# 33            https://1xbet.whoscored.com/Matches/1775732/Live/Europe-Europa-League-2023-2024-Marseille-AEK-Athens
# 34                   https://1xbet.whoscored.com/Matches/1775792/Live/Europe-Europa-League-2023-2024-Molde-Haecken
# 35             https://1xbet.whoscored.com/Matches/1775708/Live/Europe-Europa-League-2023-2024-Olympiacos-West-Ham
# 36   https://1xbet.whoscored.com/Matches/1775766/Live/Europe-Europa-League-2023-2024-Rakow-Czestochowa-Sporting-CP
# 37           https://1xbet.whoscored.com/Matches/1775756/Live/Europe-Europa-League-2023-2024-Sparta-Prague-Rangers
# 38             https://1xbet.whoscored.com/Matches/1775767/Live/Europe-Europa-League-2023-2024-Sturm-Graz-Atalanta
# 39       https://1xbet.whoscored.com/Matches/1775709/Live/Europe-Europa-League-2023-2024-TSC-Backa-Topola-Freiburg
# 40     https://1xbet.whoscored.com/Matches/1775793/Live/Europe-Europa-League-2023-2024-Bayer-Leverkusen-Qarabag-FK
# 41                   https://1xbet.whoscored.com/Matches/1775733/Live/Europe-Europa-League-2023-2024-Brighton-Ajax
# 42          https://1xbet.whoscored.com/Matches/1775745/Live/Europe-Europa-League-2023-2024-FC-Sheriff-Servette-FC
# 43              https://1xbet.whoscored.com/Matches/1775721/Live/Europe-Europa-League-2023-2024-Liverpool-Toulouse
# 44            https://1xbet.whoscored.com/Matches/1775780/Live/Europe-Europa-League-2023-2024-Panathinaikos-Rennes
# 45              https://1xbet.whoscored.com/Matches/1775744/Live/Europe-Europa-League-2023-2024-Roma-Slavia-Prague
# 46          https://1xbet.whoscored.com/Matches/1775720/Live/Europe-Europa-League-2023-2024-Union-St-Gilloise-LASK
# 47                   https://1xbet.whoscored.com/Matches/1775734/Live/Europe-Europa-League-2023-2024-Ajax-Brighton
# 48          https://1xbet.whoscored.com/Matches/1775722/Live/Europe-Europa-League-2023-2024-LASK-Union-St-Gilloise
# 49        https://1xbet.whoscored.com/Matches/1775783/Live/Europe-Europa-League-2023-2024-Maccabi-Haifa-Villarreal
# 50     https://1xbet.whoscored.com/Matches/1775794/Live/Europe-Europa-League-2023-2024-Qarabag-FK-Bayer-Leverkusen
# 51            https://1xbet.whoscored.com/Matches/1775782/Live/Europe-Europa-League-2023-2024-Rennes-Panathinaikos
# 52          https://1xbet.whoscored.com/Matches/1775746/Live/Europe-Europa-League-2023-2024-Servette-FC-FC-Sheriff
# 53              https://1xbet.whoscored.com/Matches/1775747/Live/Europe-Europa-League-2023-2024-Slavia-Prague-Roma
# 54              https://1xbet.whoscored.com/Matches/1775723/Live/Europe-Europa-League-2023-2024-Toulouse-Liverpool
# 55            https://1xbet.whoscored.com/Matches/1775735/Live/Europe-Europa-League-2023-2024-AEK-Athens-Marseille
# 56             https://1xbet.whoscored.com/Matches/1775768/Live/Europe-Europa-League-2023-2024-Atalanta-Sturm-Graz
# 57       https://1xbet.whoscored.com/Matches/1775710/Live/Europe-Europa-League-2023-2024-Freiburg-TSC-Backa-Topola
# 58                   https://1xbet.whoscored.com/Matches/1775795/Live/Europe-Europa-League-2023-2024-Haecken-Molde
# 59           https://1xbet.whoscored.com/Matches/1775759/Live/Europe-Europa-League-2023-2024-Rangers-Sparta-Prague
# 60        https://1xbet.whoscored.com/Matches/1775758/Live/Europe-Europa-League-2023-2024-Real-Betis-Aris-Limassol
# 61   https://1xbet.whoscored.com/Matches/1775769/Live/Europe-Europa-League-2023-2024-Sporting-CP-Rakow-Czestochowa
# 62             https://1xbet.whoscored.com/Matches/1775711/Live/Europe-Europa-League-2023-2024-West-Ham-Olympiacos
# 63             https://1xbet.whoscored.com/Matches/1775736/Live/Europe-Europa-League-2023-2024-AEK-Athens-Brighton
# 64            https://1xbet.whoscored.com/Matches/1775770/Live/Europe-Europa-League-2023-2024-Atalanta-Sporting-CP
# 65             https://1xbet.whoscored.com/Matches/1775712/Live/Europe-Europa-League-2023-2024-Freiburg-Olympiacos
# 66            https://1xbet.whoscored.com/Matches/1775784/Live/Europe-Europa-League-2023-2024-Maccabi-Haifa-Rennes
# 67        https://1xbet.whoscored.com/Matches/1775760/Live/Europe-Europa-League-2023-2024-Sparta-Prague-Real-Betis
# 68    https://1xbet.whoscored.com/Matches/1775771/Live/Europe-Europa-League-2023-2024-Sturm-Graz-Rakow-Czestochowa
# 69       https://1xbet.whoscored.com/Matches/1775713/Live/Europe-Europa-League-2023-2024-TSC-Backa-Topola-West-Ham
# 70        https://1xbet.whoscored.com/Matches/1775749/Live/Europe-Europa-League-2023-2024-FC-Sheriff-Slavia-Prague
# 71        https://1xbet.whoscored.com/Matches/1775797/Live/Europe-Europa-League-2023-2024-Haecken-Bayer-Leverkusen
# 72                  https://1xbet.whoscored.com/Matches/1775725/Live/Europe-Europa-League-2023-2024-Liverpool-LASK
# 73                  https://1xbet.whoscored.com/Matches/1775737/Live/Europe-Europa-League-2023-2024-Marseille-Ajax
# 74                https://1xbet.whoscored.com/Matches/1775796/Live/Europe-Europa-League-2023-2024-Molde-Qarabag-FK
# 75           https://1xbet.whoscored.com/Matches/1775761/Live/Europe-Europa-League-2023-2024-Rangers-Aris-Limassol
# 76                https://1xbet.whoscored.com/Matches/1775748/Live/Europe-Europa-League-2023-2024-Servette-FC-Roma
# 77      https://1xbet.whoscored.com/Matches/1775724/Live/Europe-Europa-League-2023-2024-Toulouse-Union-St-Gilloise
# 78        https://1xbet.whoscored.com/Matches/1775785/Live/Europe-Europa-League-2023-2024-Villarreal-Panathinaikos
# 79        https://1xbet.whoscored.com/Matches/1775781/Live/Europe-Europa-League-2023-2024-Villarreal-Maccabi-Haifa
# 80          https://1xbet.whoscored.com/Matches/1775798/Live/Europe-Europa-League-2023-2024-Bayer-Leverkusen-Molde
# 81                   https://1xbet.whoscored.com/Matches/1775727/Live/Europe-Europa-League-2023-2024-LASK-Toulouse
# 82     https://1xbet.whoscored.com/Matches/1775787/Live/Europe-Europa-League-2023-2024-Panathinaikos-Maccabi-Haifa
# 83              https://1xbet.whoscored.com/Matches/1775799/Live/Europe-Europa-League-2023-2024-Qarabag-FK-Haecken
# 84               https://1xbet.whoscored.com/Matches/1775786/Live/Europe-Europa-League-2023-2024-Rennes-Villarreal
# 85                 https://1xbet.whoscored.com/Matches/1775750/Live/Europe-Europa-League-2023-2024-Roma-FC-Sheriff
# 86       https://1xbet.whoscored.com/Matches/1775751/Live/Europe-Europa-League-2023-2024-Slavia-Prague-Servette-FC
# 87     https://1xbet.whoscored.com/Matches/1775726/Live/Europe-Europa-League-2023-2024-Union-St-Gilloise-Liverpool
# 88                 https://1xbet.whoscored.com/Matches/1775738/Live/Europe-Europa-League-2023-2024-Ajax-AEK-Athens
# 89     https://1xbet.whoscored.com/Matches/1775763/Live/Europe-Europa-League-2023-2024-Aris-Limassol-Sparta-Prague
# 90              https://1xbet.whoscored.com/Matches/1775739/Live/Europe-Europa-League-2023-2024-Brighton-Marseille
# 91     https://1xbet.whoscored.com/Matches/1775715/Live/Europe-Europa-League-2023-2024-Olympiacos-TSC-Backa-Topola
# 92      https://1xbet.whoscored.com/Matches/1775773/Live/Europe-Europa-League-2023-2024-Rakow-Czestochowa-Atalanta
# 93              https://1xbet.whoscored.com/Matches/1775762/Live/Europe-Europa-League-2023-2024-Real-Betis-Rangers
# 94          https://1xbet.whoscored.com/Matches/1775772/Live/Europe-Europa-League-2023-2024-Sporting-CP-Sturm-Graz
# 95               https://1xbet.whoscored.com/Matches/1775714/Live/Europe-Europa-League-2023-2024-West-Ham-Freiburg
# 96      https://1xbet.whoscored.com/Matches/1789453/Live/Europe-Europa-League-2023-2024-BSC-Young-Boys-Sporting-CP
# 97                  https://1xbet.whoscored.com/Matches/1789447/Live/Europe-Europa-League-2023-2024-Feyenoord-Roma
# 98       https://1xbet.whoscored.com/Matches/1789459/Live/Europe-Europa-League-2023-2024-Galatasaray-Sparta-Prague
# 99      https://1xbet.whoscored.com/Matches/1789461/Live/Europe-Europa-League-2023-2024-Shakhtar-Donetsk-Marseille
# 100                https://1xbet.whoscored.com/Matches/1789449/Live/Europe-Europa-League-2023-2024-AC-Milan-Rennes
# 101               https://1xbet.whoscored.com/Matches/1789455/Live/Europe-Europa-League-2023-2024-Benfica-Toulouse
# 102               https://1xbet.whoscored.com/Matches/1789457/Live/Europe-Europa-League-2023-2024-Braga-Qarabag-FK
# 103                  https://1xbet.whoscored.com/Matches/1789451/Live/Europe-Europa-League-2023-2024-Lens-Freiburg
# 104                  https://1xbet.whoscored.com/Matches/1789452/Live/Europe-Europa-League-2023-2024-Freiburg-Lens
# 105               https://1xbet.whoscored.com/Matches/1789458/Live/Europe-Europa-League-2023-2024-Qarabag-FK-Braga
# 106                https://1xbet.whoscored.com/Matches/1789450/Live/Europe-Europa-League-2023-2024-Rennes-AC-Milan
# 107               https://1xbet.whoscored.com/Matches/1789456/Live/Europe-Europa-League-2023-2024-Toulouse-Benfica
# 108     https://1xbet.whoscored.com/Matches/1789462/Live/Europe-Europa-League-2023-2024-Marseille-Shakhtar-Donetsk
# 109                 https://1xbet.whoscored.com/Matches/1789448/Live/Europe-Europa-League-2023-2024-Roma-Feyenoord
# 110      https://1xbet.whoscored.com/Matches/1789460/Live/Europe-Europa-League-2023-2024-Sparta-Prague-Galatasaray
# 111     https://1xbet.whoscored.com/Matches/1789454/Live/Europe-Europa-League-2023-2024-Sporting-CP-BSC-Young-Boys
# 112           https://1xbet.whoscored.com/Matches/1805545/Live/Europe-Europa-League-2023-2024-Sporting-CP-Atalanta
# 113    https://1xbet.whoscored.com/Matches/1805549/Live/Europe-Europa-League-2023-2024-Qarabag-FK-Bayer-Leverkusen
# 114                  https://1xbet.whoscored.com/Matches/1805539/Live/Europe-Europa-League-2023-2024-Roma-Brighton
# 115        https://1xbet.whoscored.com/Matches/1805535/Live/Europe-Europa-League-2023-2024-Sparta-Prague-Liverpool
# 116         https://1xbet.whoscored.com/Matches/1805547/Live/Europe-Europa-League-2023-2024-AC-Milan-Slavia-Prague
# 117                https://1xbet.whoscored.com/Matches/1805541/Live/Europe-Europa-League-2023-2024-Benfica-Rangers
# 118              https://1xbet.whoscored.com/Matches/1805543/Live/Europe-Europa-League-2023-2024-Freiburg-West-Ham
# 119           https://1xbet.whoscored.com/Matches/1805537/Live/Europe-Europa-League-2023-2024-Marseille-Villarreal
# 120                https://1xbet.whoscored.com/Matches/1805542/Live/Europe-Europa-League-2023-2024-Rangers-Benfica
# 121         https://1xbet.whoscored.com/Matches/1805548/Live/Europe-Europa-League-2023-2024-Slavia-Prague-AC-Milan
# 122           https://1xbet.whoscored.com/Matches/1805538/Live/Europe-Europa-League-2023-2024-Villarreal-Marseille
# 123              https://1xbet.whoscored.com/Matches/1805544/Live/Europe-Europa-League-2023-2024-West-Ham-Freiburg
# 124           https://1xbet.whoscored.com/Matches/1805546/Live/Europe-Europa-League-2023-2024-Atalanta-Sporting-CP
# 125    https://1xbet.whoscored.com/Matches/1805550/Live/Europe-Europa-League-2023-2024-Bayer-Leverkusen-Qarabag-FK
# 126                  https://1xbet.whoscored.com/Matches/1805540/Live/Europe-Europa-League-2023-2024-Brighton-Roma
# 127        https://1xbet.whoscored.com/Matches/1805536/Live/Europe-Europa-League-2023-2024-Liverpool-Sparta-Prague
#
#      fbref_id  \
# 0    21d5e315
# 1    ff9887c8
# 2    1b1f3de6
# 3    9eb4630b
# 4    e32a79b6
# 5    57ff57bf
# 6    0a120e38
# 7    76a18903
# 8    7933e9bf
# 9    159f2864
# 10   8aebde7a
# 11   fc67cf77
# 12   57ffcbe1
# 13   e5f733c3
# 14   52995d52
# 15   c376e97b
# 16   300d9ac1
# 17   040511a1
# 18   734e1b51
# 19   6e5bc2fb
# 20   7d7140aa
# 21   eca58409
# 22   6b0b141b
# 23   c48ed8ee
# 24   83f61fa7
# 25   bcfbaac5
# 26   410dca2e
# 27   e3072c52
# 28   ca9df6d6
# 29   1e479935
# 30   1e6b3712
# 31   25d48427
# 32   2c402bf4
# 33   3775a614
# 34   54b617f8
# 35   a945ca05
# 36   c91cd9f2
# 37   75a322fc
# 38   b8337593
# 39   1e2739be
# 40   35cae623
# 41   cd2c07a6
# 42   cafe0e08
# 43   85a8a3a3
# 44   b760ba57
# 45   e499c13d
# 46   ee56aa77
# 47   287a023b
# 48   a489b203
# 49   428ed6c7
# 50   1df53dd1
# 51   2ec5d613
# 52   fbc2bf76
# 53   1a6d301d
# 54   e4192b01
# 55   a89acbe6
# 56   10872c8c
# 57   039dde2e
# 58   df6875f3
# 59   113caebe
# 60   2fc064d4
# 61   5d319000
# 62   9778001e
# 63   acd46367
# 64   566625f4
# 65   43088f40
# 66   cd251c0d
# 67   2f09d705
# 68   b2a7934b
# 69   bd8994c2
# 70   f1b17169
# 71   091b2437
# 72   b195c0ca
# 73   fd1247c4
# 74   87815cf0
# 75   9c7cda12
# 76   4b1fd82c
# 77   21f722f2
# 78   9f7a8eb8
# 79   d508f7e4
# 80   22bc15a1
# 81   69e0bc84
# 82   c0b7f5c8
# 83   29b2a5f9
# 84   336d1c85
# 85   62430b73
# 86   1db16521
# 87   54a53a8f
# 88   8754228f
# 89   55ec0665
# 90   91b88fc9
# 91   328fc053
# 92   134b16da
# 93   f3479690
# 94   882df7fa
# 95   1862a88e
# 96   18ac8ed0
# 97   e5d82802
# 98   0fbae547
# 99   b451ba2b
# 100  1f1516a8
# 101  9d2818db
# 102  d8ca0ed5
# 103  e61bbe7a
# 104  0474e6a3
# 105  f94eed97
# 106  9bb87f42
# 107  163104a8
# 108  1961cf03
# 109  cb5a5240
# 110  3554355e
# 111  257ff4f4
# 112  9642c5d6
# 113  2a455224
# 114  1328e56d
# 115  eda83a1d
# 116  49133f4a
# 117  04acbdce
# 118  2f7e2d02
# 119  8e3c0d7f
# 120  42496c8f
# 121  9dae7793
# 122  172fc352
# 123  ccd60080
# 124  84a22633
# 125  58b65788
# 126  7e229c83
# 127  930d92c4
#
#                                                                                     fbref_url  \
# 0                /en/matches/21d5e315/Bayer-Leverkusen-Hacken-September-21-2023-Europa-League
# 1                  /en/matches/ff9887c8/Sheriff-Tiraspol-Roma-September-21-2023-Europa-League
# 2                         /en/matches/1b1f3de6/LASK-Liverpool-September-21-2023-Europa-League
# 3               /en/matches/9eb4630b/Panathinaikos-Villarreal-September-21-2023-Europa-League
# 4                    /en/matches/e32a79b6/Qarabag-Agdam-Molde-September-21-2023-Europa-League
# 5                   /en/matches/57ff57bf/Rennes-Maccabi-Haifa-September-21-2023-Europa-League
# 6              /en/matches/0a120e38/Servette-FC-Slavia-Prague-September-21-2023-Europa-League
# 7                      /en/matches/76a18903/Union-SG-Toulouse-September-21-2023-Europa-League
# 8                         /en/matches/7933e9bf/Ajax-Marseille-September-21-2023-Europa-League
# 9                     /en/matches/159f2864/Atalanta-RKS-Rakow-September-21-2023-Europa-League
# 10   /en/matches/8aebde7a/Brighton-and-Hove-Albion-AEK-Athens-September-21-2023-Europa-League
# 11                   /en/matches/fc67cf77/Olympiacos-Freiburg-September-21-2023-Europa-League
# 12                    /en/matches/57ffcbe1/Rangers-Real-Betis-September-21-2023-Europa-League
# 13        /en/matches/e5f733c3/Sparta-Prague-Aris-Limassol-FC-September-21-2023-Europa-League
# 14                /en/matches/52995d52/Sturm-Graz-Sporting-CP-September-21-2023-Europa-League
# 15         /en/matches/c376e97b/West-Ham-United-TSC-Backa-Top-September-21-2023-Europa-League
# 16                          /en/matches/300d9ac1/AEK-Athens-Ajax-October-5-2023-Europa-League
# 17                 /en/matches/040511a1/Aris-Limassol-FC-Rangers-October-5-2023-Europa-League
# 18                 /en/matches/734e1b51/Freiburg-West-Ham-United-October-5-2023-Europa-League
# 19       /en/matches/6e5bc2fb/Marseille-Brighton-and-Hove-Albion-October-5-2023-Europa-League
# 20                     /en/matches/7d7140aa/RKS-Rakow-Sturm-Graz-October-5-2023-Europa-League
# 21                 /en/matches/eca58409/Real-Betis-Sparta-Prague-October-5-2023-Europa-League
# 22                     /en/matches/6b0b141b/Sporting-CP-Atalanta-October-5-2023-Europa-League
# 23                 /en/matches/c48ed8ee/TSC-Backa-Top-Olympiacos-October-5-2023-Europa-League
# 24                     /en/matches/83f61fa7/Hacken-Qarabag-Agdam-October-5-2023-Europa-League
# 25                       /en/matches/bcfbaac5/Liverpool-Union-SG-October-5-2023-Europa-League
# 26              /en/matches/410dca2e/Maccabi-Haifa-Panathinaikos-October-5-2023-Europa-League
# 27                   /en/matches/e3072c52/Molde-Bayer-Leverkusen-October-5-2023-Europa-League
# 28                         /en/matches/ca9df6d6/Roma-Servette-FC-October-5-2023-Europa-League
# 29           /en/matches/1e479935/Slavia-Prague-Sheriff-Tiraspol-October-5-2023-Europa-League
# 30                            /en/matches/1e6b3712/Toulouse-LASK-October-5-2023-Europa-League
# 31                        /en/matches/25d48427/Villarreal-Rennes-October-5-2023-Europa-League
# 32             /en/matches/2c402bf4/Aris-Limassol-FC-Real-Betis-October-26-2023-Europa-League
# 33                    /en/matches/3775a614/Marseille-AEK-Athens-October-26-2023-Europa-League
# 34                            /en/matches/54b617f8/Molde-Hacken-October-26-2023-Europa-League
# 35              /en/matches/a945ca05/Olympiacos-West-Ham-United-October-26-2023-Europa-League
# 36                   /en/matches/c91cd9f2/RKS-Rakow-Sporting-CP-October-26-2023-Europa-League
# 37                   /en/matches/75a322fc/Sparta-Prague-Rangers-October-26-2023-Europa-League
# 38                     /en/matches/b8337593/Sturm-Graz-Atalanta-October-26-2023-Europa-League
# 39                  /en/matches/1e2739be/TSC-Backa-Top-Freiburg-October-26-2023-Europa-League
# 40          /en/matches/35cae623/Bayer-Leverkusen-Qarabag-Agdam-October-26-2023-Europa-League
# 41           /en/matches/cd2c07a6/Brighton-and-Hove-Albion-Ajax-October-26-2023-Europa-League
# 42            /en/matches/cafe0e08/Sheriff-Tiraspol-Servette-FC-October-26-2023-Europa-League
# 43                      /en/matches/85a8a3a3/Liverpool-Toulouse-October-26-2023-Europa-League
# 44                    /en/matches/b760ba57/Panathinaikos-Rennes-October-26-2023-Europa-League
# 45                      /en/matches/e499c13d/Roma-Slavia-Prague-October-26-2023-Europa-League
# 46                           /en/matches/ee56aa77/Union-SG-LASK-October-26-2023-Europa-League
# 47           /en/matches/287a023b/Ajax-Brighton-and-Hove-Albion-November-9-2023-Europa-League
# 48                           /en/matches/a489b203/LASK-Union-SG-November-9-2023-Europa-League
# 49                /en/matches/428ed6c7/Maccabi-Haifa-Villarreal-November-9-2023-Europa-League
# 50          /en/matches/1df53dd1/Qarabag-Agdam-Bayer-Leverkusen-November-9-2023-Europa-League
# 51                    /en/matches/2ec5d613/Rennes-Panathinaikos-November-9-2023-Europa-League
# 52            /en/matches/fbc2bf76/Servette-FC-Sheriff-Tiraspol-November-9-2023-Europa-League
# 53                      /en/matches/1a6d301d/Slavia-Prague-Roma-November-9-2023-Europa-League
# 54                      /en/matches/e4192b01/Toulouse-Liverpool-November-9-2023-Europa-League
# 55                    /en/matches/a89acbe6/AEK-Athens-Marseille-November-9-2023-Europa-League
# 56                     /en/matches/10872c8c/Atalanta-Sturm-Graz-November-9-2023-Europa-League
# 57                  /en/matches/039dde2e/Freiburg-TSC-Backa-Top-November-9-2023-Europa-League
# 58                            /en/matches/df6875f3/Hacken-Molde-November-9-2023-Europa-League
# 59                   /en/matches/113caebe/Rangers-Sparta-Prague-November-9-2023-Europa-League
# 60             /en/matches/2fc064d4/Real-Betis-Aris-Limassol-FC-November-9-2023-Europa-League
# 61                   /en/matches/5d319000/Sporting-CP-RKS-Rakow-November-9-2023-Europa-League
# 62              /en/matches/9778001e/West-Ham-United-Olympiacos-November-9-2023-Europa-League
# 63    /en/matches/acd46367/AEK-Athens-Brighton-and-Hove-Albion-November-30-2023-Europa-League
# 64                   /en/matches/566625f4/Atalanta-Sporting-CP-November-30-2023-Europa-League
# 65                    /en/matches/43088f40/Freiburg-Olympiacos-November-30-2023-Europa-League
# 66                   /en/matches/cd251c0d/Maccabi-Haifa-Rennes-November-30-2023-Europa-League
# 67               /en/matches/2f09d705/Sparta-Prague-Real-Betis-November-30-2023-Europa-League
# 68                   /en/matches/b2a7934b/Sturm-Graz-RKS-Rakow-November-30-2023-Europa-League
# 69          /en/matches/bd8994c2/TSC-Backa-Top-West-Ham-United-November-30-2023-Europa-League
# 70         /en/matches/f1b17169/Sheriff-Tiraspol-Slavia-Prague-November-30-2023-Europa-League
# 71                /en/matches/091b2437/Hacken-Bayer-Leverkusen-November-30-2023-Europa-League
# 72                         /en/matches/b195c0ca/Liverpool-LASK-November-30-2023-Europa-League
# 73                         /en/matches/fd1247c4/Marseille-Ajax-November-30-2023-Europa-League
# 74                    /en/matches/87815cf0/Molde-Qarabag-Agdam-November-30-2023-Europa-League
# 75               /en/matches/9c7cda12/Rangers-Aris-Limassol-FC-November-30-2023-Europa-League
# 76                       /en/matches/4b1fd82c/Servette-FC-Roma-November-30-2023-Europa-League
# 77                      /en/matches/21f722f2/Toulouse-Union-SG-November-30-2023-Europa-League
# 78               /en/matches/9f7a8eb8/Villarreal-Panathinaikos-November-30-2023-Europa-League
# 79                /en/matches/d508f7e4/Villarreal-Maccabi-Haifa-December-6-2023-Europa-League
# 80                 /en/matches/22bc15a1/Bayer-Leverkusen-Molde-December-14-2023-Europa-League
# 81                          /en/matches/69e0bc84/LASK-Toulouse-December-14-2023-Europa-League
# 82            /en/matches/c0b7f5c8/Panathinaikos-Maccabi-Haifa-December-14-2023-Europa-League
# 83                   /en/matches/29b2a5f9/Qarabag-Agdam-Hacken-December-14-2023-Europa-League
# 84                      /en/matches/336d1c85/Rennes-Villarreal-December-14-2023-Europa-League
# 85                  /en/matches/62430b73/Roma-Sheriff-Tiraspol-December-14-2023-Europa-League
# 86              /en/matches/1db16521/Slavia-Prague-Servette-FC-December-14-2023-Europa-League
# 87                     /en/matches/54a53a8f/Union-SG-Liverpool-December-14-2023-Europa-League
# 88                        /en/matches/8754228f/Ajax-AEK-Athens-December-14-2023-Europa-League
# 89         /en/matches/55ec0665/Aris-Limassol-FC-Sparta-Prague-December-14-2023-Europa-League
# 90     /en/matches/91b88fc9/Brighton-and-Hove-Albion-Marseille-December-14-2023-Europa-League
# 91               /en/matches/328fc053/Olympiacos-TSC-Backa-Top-December-14-2023-Europa-League
# 92                     /en/matches/134b16da/RKS-Rakow-Atalanta-December-14-2023-Europa-League
# 93                     /en/matches/f3479690/Real-Betis-Rangers-December-14-2023-Europa-League
# 94                 /en/matches/882df7fa/Sporting-CP-Sturm-Graz-December-14-2023-Europa-League
# 95               /en/matches/1862a88e/West-Ham-United-Freiburg-December-14-2023-Europa-League
# 96                 /en/matches/18ac8ed0/Young-Boys-Sporting-CP-February-15-2024-Europa-League
# 97                         /en/matches/e5d82802/Feyenoord-Roma-February-15-2024-Europa-League
# 98              /en/matches/0fbae547/Galatasaray-Sparta-Prague-February-15-2024-Europa-League
# 99             /en/matches/b451ba2b/Shakhtar-Donetsk-Marseille-February-15-2024-Europa-League
# 100                          /en/matches/1f1516a8/Milan-Rennes-February-15-2024-Europa-League
# 101                      /en/matches/9d2818db/Benfica-Toulouse-February-15-2024-Europa-League
# 102                   /en/matches/d8ca0ed5/Braga-Qarabag-Agdam-February-15-2024-Europa-League
# 103                         /en/matches/e61bbe7a/Lens-Freiburg-February-15-2024-Europa-League
# 104                         /en/matches/0474e6a3/Freiburg-Lens-February-22-2024-Europa-League
# 105                   /en/matches/f94eed97/Qarabag-Agdam-Braga-February-22-2024-Europa-League
# 106                          /en/matches/9bb87f42/Rennes-Milan-February-22-2024-Europa-League
# 107                      /en/matches/163104a8/Toulouse-Benfica-February-22-2024-Europa-League
# 108            /en/matches/1961cf03/Marseille-Shakhtar-Donetsk-February-22-2024-Europa-League
# 109                        /en/matches/cb5a5240/Roma-Feyenoord-February-22-2024-Europa-League
# 110             /en/matches/3554355e/Sparta-Prague-Galatasaray-February-22-2024-Europa-League
# 111                /en/matches/257ff4f4/Sporting-CP-Young-Boys-February-22-2024-Europa-League
# 112                      /en/matches/9642c5d6/Sporting-CP-Atalanta-March-6-2024-Europa-League
# 113            /en/matches/2a455224/Qarabag-Agdam-Bayer-Leverkusen-March-7-2024-Europa-League
# 114             /en/matches/1328e56d/Roma-Brighton-and-Hove-Albion-March-7-2024-Europa-League
# 115                   /en/matches/eda83a1d/Sparta-Prague-Liverpool-March-7-2024-Europa-League
# 116                       /en/matches/49133f4a/Milan-Slavia-Prague-March-7-2024-Europa-League
# 117                           /en/matches/04acbdce/Benfica-Rangers-March-7-2024-Europa-League
# 118                  /en/matches/2f7e2d02/Freiburg-West-Ham-United-March-7-2024-Europa-League
# 119                      /en/matches/8e3c0d7f/Marseille-Villarreal-March-7-2024-Europa-League
# 120                          /en/matches/42496c8f/Rangers-Benfica-March-14-2024-Europa-League
# 121                      /en/matches/9dae7793/Slavia-Prague-Milan-March-14-2024-Europa-League
# 122                     /en/matches/172fc352/Villarreal-Marseille-March-14-2024-Europa-League
# 123                 /en/matches/ccd60080/West-Ham-United-Freiburg-March-14-2024-Europa-League
# 124                     /en/matches/84a22633/Atalanta-Sporting-CP-March-14-2024-Europa-League
# 125           /en/matches/58b65788/Bayer-Leverkusen-Qarabag-Agdam-March-14-2024-Europa-League
# 126            /en/matches/7e229c83/Brighton-and-Hove-Albion-Roma-March-14-2024-Europa-League
# 127                  /en/matches/930d92c4/Liverpool-Sparta-Prague-March-14-2024-Europa-League
#
#     fotmob_id                                                     fotmob_url
# 0     4315153             /matches/bayer-leverkusen-vs-hacken/2a3li5#4315153
# 1     4315105                     /matches/roma-vs-fc-sheriff/2syky1#4315105
# 2     4315081                      /matches/liverpool-vs-lask/2vaqvz#4315081
# 3     4315142            /matches/panathinaikos-vs-villarreal/3fyi0k#4315142
# 4     4315154                    /matches/qarabag-fk-vs-molde/2nddwk#4315154
# 5     4315141                /matches/rennes-vs-maccabi-haifa/3bikdh#4315141
# 6     4315106              /matches/slavia-prague-vs-servette/2jug3r#4315106
# 7     4315082           /matches/union-stgilloise-vs-toulouse/2nlg45#4315082
# 8     4315093                      /matches/marseille-vs-ajax/2fxa2q#4315093
# 9     4315117          /matches/rakow-czestochowa-vs-atalanta/1avowm#4315117
# 10    4315094     /matches/aek-athens-vs-brighton-hove-albion/2wutl7#4315094
# 11    4315070              /matches/sc-freiburg-vs-olympiacos/2e01o8#4315070
# 12    4315130                  /matches/rangers-vs-real-betis/2fkrob#4315130
# 13    4315129         /matches/aris-limassol-vs-sparta-prague/19ngvc#4315129
# 14    4315118              /matches/sporting-cp-vs-sturm-graz/38i6al#4315118
# 15    4315069  /matches/west-ham-united-vs-tsc-backa-topola/2zpqflnh#4315069
# 16    4315096                     /matches/aek-athens-vs-ajax/2fmluj#4315096
# 17    4315132                /matches/aris-limassol-vs-rangers/xzl8q#4315132
# 18    4315071         /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315071
# 19    4315095      /matches/marseille-vs-brighton-hove-albion/2x6hvy#4315095
# 20    4315120        /matches/rakow-czestochowa-vs-sturm-graz/1mo4ut#4315120
# 21    4315131            /matches/real-betis-vs-sparta-prague/2xsa7i#4315131
# 22    4315119                /matches/atalanta-vs-sporting-cp/2rm71m#4315119
# 23    4315072       /matches/olympiacos-vs-tsc-backa-topola/2zpjwrhh#4315072
# 24    4315156                   /matches/qarabag-fk-vs-hacken/285w6p#4315156
# 25    4315083          /matches/union-stgilloise-vs-liverpool/2abfrg#4315083
# 26    4315144         /matches/maccabi-haifa-vs-panathinaikos/3fpr9l#4315144
# 27    4315155              /matches/bayer-leverkusen-vs-molde/2phdk5#4315155
# 28    4315107                       /matches/roma-vs-servette/2thjxd#4315107
# 29    4315108            /matches/slavia-prague-vs-fc-sheriff/2jcef3#4315108
# 30    4315084                       /matches/toulouse-vs-lask/3a41j6#4315084
# 31    4315143                   /matches/rennes-vs-villarreal/3br5qf#4315143
# 32    4315134             /matches/aris-limassol-vs-real-betis/yc7vt#4315134
# 33    4315097                /matches/aek-athens-vs-marseille/2fm8ly#4315097
# 34    4315157                        /matches/hacken-vs-molde/2s70be#4315157
# 35    4315073          /matches/olympiacos-vs-west-ham-united/2h0tek#4315073
# 36    4315121       /matches/rakow-czestochowa-vs-sporting-cp/1kmvx4#4315121
# 37    4315133               /matches/rangers-vs-sparta-prague/2x63cm#4315133
# 38    4315122                 /matches/atalanta-vs-sturm-graz/2ub9mb#4315122
# 39    4315074      /matches/sc-freiburg-vs-tsc-backa-topola/2zmdrzjl#4315074
# 40    4315158         /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315158
# 41    4315098           /matches/ajax-vs-brighton-hove-albion/2x6we4#4315098
# 42    4315110                 /matches/fc-sheriff-vs-servette/359yr0#4315110
# 43    4315086                  /matches/liverpool-vs-toulouse/2uwdxh#4315086
# 44    4315145                /matches/rennes-vs-panathinaikos/3bp0d5#4315145
# 45    4315109                  /matches/slavia-prague-vs-roma/28sgb7#4315109
# 46    4315085               /matches/union-stgilloise-vs-lask/2nzaen#4315085
# 47    4315099           /matches/ajax-vs-brighton-hove-albion/2x6we4#4315099
# 48    4315087               /matches/union-stgilloise-vs-lask/2nzaen#4315087
# 49    4315148            /matches/maccabi-haifa-vs-villarreal/3frxxe#4315148
# 50    4315159         /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315159
# 51    4315147                /matches/rennes-vs-panathinaikos/3bp0d5#4315147
# 52    4315111                 /matches/fc-sheriff-vs-servette/359yr0#4315111
# 53    4315112                  /matches/slavia-prague-vs-roma/28sgb7#4315112
# 54    4315088                  /matches/liverpool-vs-toulouse/2uwdxh#4315088
# 55    4315100                /matches/aek-athens-vs-marseille/2fm8ly#4315100
# 56    4315123                 /matches/atalanta-vs-sturm-graz/2ub9mb#4315123
# 57    4315075      /matches/sc-freiburg-vs-tsc-backa-topola/2zmdrzjl#4315075
# 58    4315160                        /matches/hacken-vs-molde/2s70be#4315160
# 59    4315136               /matches/rangers-vs-sparta-prague/2x63cm#4315136
# 60    4315135             /matches/aris-limassol-vs-real-betis/yc7vt#4315135
# 61    4315124       /matches/rakow-czestochowa-vs-sporting-cp/1kmvx4#4315124
# 62    4315076          /matches/olympiacos-vs-west-ham-united/2h0tek#4315076
# 63    4315101     /matches/aek-athens-vs-brighton-hove-albion/2wutl7#4315101
# 64    4315125                /matches/atalanta-vs-sporting-cp/2rm71m#4315125
# 65    4315077              /matches/sc-freiburg-vs-olympiacos/2e01o8#4315077
# 66    4315149                /matches/rennes-vs-maccabi-haifa/3bikdh#4315149
# 67    4315137            /matches/real-betis-vs-sparta-prague/2xsa7i#4315137
# 68    4315126        /matches/rakow-czestochowa-vs-sturm-graz/1mo4ut#4315126
# 69    4315078  /matches/west-ham-united-vs-tsc-backa-topola/2zpqflnh#4315078
# 70    4315114            /matches/slavia-prague-vs-fc-sheriff/2jcef3#4315114
# 71    4315162             /matches/bayer-leverkusen-vs-hacken/2a3li5#4315162
# 72    4315090                      /matches/liverpool-vs-lask/2vaqvz#4315090
# 73    4315102                      /matches/marseille-vs-ajax/2fxa2q#4315102
# 74    4315161                    /matches/qarabag-fk-vs-molde/2nddwk#4315161
# 75    4315138                /matches/aris-limassol-vs-rangers/xzl8q#4315138
# 76    4315113                       /matches/roma-vs-servette/2thjxd#4315113
# 77    4315089           /matches/union-stgilloise-vs-toulouse/2nlg45#4315089
# 78    4315150            /matches/panathinaikos-vs-villarreal/3fyi0k#4315150
# 79    4315146            /matches/maccabi-haifa-vs-villarreal/3frxxe#4315146
# 80    4315163              /matches/bayer-leverkusen-vs-molde/2phdk5#4315163
# 81    4315092                       /matches/toulouse-vs-lask/3a41j6#4315092
# 82    4315152         /matches/maccabi-haifa-vs-panathinaikos/3fpr9l#4315152
# 83    4315164                   /matches/qarabag-fk-vs-hacken/285w6p#4315164
# 84    4315151                   /matches/rennes-vs-villarreal/3br5qf#4315151
# 85    4315115                     /matches/roma-vs-fc-sheriff/2syky1#4315115
# 86    4315116              /matches/slavia-prague-vs-servette/2jug3r#4315116
# 87    4315091          /matches/union-stgilloise-vs-liverpool/2abfrg#4315091
# 88    4315103                     /matches/aek-athens-vs-ajax/2fmluj#4315103
# 89    4315140         /matches/aris-limassol-vs-sparta-prague/19ngvc#4315140
# 90    4315104      /matches/marseille-vs-brighton-hove-albion/2x6hvy#4315104
# 91    4315080       /matches/olympiacos-vs-tsc-backa-topola/2zpjwrhh#4315080
# 92    4315128          /matches/rakow-czestochowa-vs-atalanta/1avowm#4315128
# 93    4315139                  /matches/rangers-vs-real-betis/2fkrob#4315139
# 94    4315127              /matches/sporting-cp-vs-sturm-graz/38i6al#4315127
# 95    4315079         /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315079
# 96    4384257              /matches/sporting-cp-vs-young-boys/3alzk4#4384257
# 97    4384251                      /matches/roma-vs-feyenoord/2yl0x7#4384251
# 98    4384263           /matches/galatasaray-vs-sparta-prague/2y617r#4384263
# 99    4384265          /matches/marseille-vs-shakhtar-donetsk/2rx6iw#4384265
# 100   4384253                     /matches/ac-milan-vs-rennes/2syl1f#4384253
# 101   4384259                    /matches/benfica-vs-toulouse/37oz12#4384259
# 102   4384261                    /matches/qarabag-fk-vs-braga/2r3r4s#4384261
# 103   4384255                    /matches/sc-freiburg-vs-lens/2dhuvb#4384255
# 104   4384256                    /matches/sc-freiburg-vs-lens/2dhuvb#4384256
# 105   4384262                    /matches/qarabag-fk-vs-braga/2r3r4s#4384262
# 106   4384254                     /matches/ac-milan-vs-rennes/2syl1f#4384254
# 107   4384260                    /matches/benfica-vs-toulouse/37oz12#4384260
# 108   4384266          /matches/marseille-vs-shakhtar-donetsk/2rx6iw#4384266
# 109   4384252                      /matches/roma-vs-feyenoord/2yl0x7#4384252
# 110   4384264           /matches/galatasaray-vs-sparta-prague/2y617r#4384264
# 111   4384258              /matches/sporting-cp-vs-young-boys/3alzk4#4384258
# 112   4430808                /matches/atalanta-vs-sporting-cp/2rm71m#4430808
# 113   4430813         /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4430813
# 114   4430800           /matches/roma-vs-brighton-hove-albion/2y8gp1#4430800
# 115   4430795             /matches/liverpool-vs-sparta-prague/2ybapv#4430795
# 116   4430810              /matches/slavia-prague-vs-ac-milan/27lj7o#4430810
# 117   4430803                     /matches/rangers-vs-benfica/2rx6k4#4430803
# 118   4430806         /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4430806
# 119   4430798                /matches/marseille-vs-villarreal/2x6we3#4430798
# 120   4430804                     /matches/rangers-vs-benfica/2rx6k4#4430804
# 121   4430812              /matches/slavia-prague-vs-ac-milan/27lj7o#4430812
# 122   4430799                /matches/marseille-vs-villarreal/2x6we3#4430799
# 123   4430807         /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4430807
# 124   4430809                /matches/atalanta-vs-sporting-cp/2rm71m#4430809
# 125   4430814         /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4430814
# 126   4430802           /matches/roma-vs-brighton-hove-albion/2y8gp1#4430802
# 127   4430797             /matches/liverpool-vs-sparta-prague/2ybapv#4430797

# %%
w.to_csv("w.csv")

# %%
w = WS[WS['season'] == '23-24']
b = FB[FB['season'] == '23-24']
m = FM[FM['season'] == '23-24']

# %%
m[(m['home_team'] == 'Leverkusen' ) ]
# Out:
#      index       id league season  \
# 34      34  4315153    UEL  23-24
# 74      74  4315158    UEL  23-24
# 114    114  4315163    UEL  23-24
# 159    159  4430814    UEL  23-24
# 163    163  4446405    UEL  23-24
#
#                                                              url   home_team  \
# 34            /matches/bayer-leverkusen-vs-hacken/2a3li5#4315153  Leverkusen
# 74        /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315158  Leverkusen
# 114            /matches/bayer-leverkusen-vs-molde/2phdk5#4315163  Leverkusen
# 159       /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4430814  Leverkusen
# 163  /matches/bayer-leverkusen-vs-west-ham-united/2ccl9q#4446405  Leverkusen
#
#       away_team        date  source
# 34       Häcken  2023-09-21  FotMob
# 74   Qarabag FK  2023-10-26  FotMob
# 114       Molde  2023-12-14  FotMob
# 159  Qarabag FK  2024-03-14  FotMob
# 163    West Ham  2024-04-11  FotMob

# %%
leagues = [
    # 'ENG-Premier League',
    # 'ESP-La Liga',
    # 'Eredivisie',
    # 'FRA-Ligue 1',
    # 'GER-Bundesliga',
    # 'ITA-Serie A',
    # 'Primeira_Liga',
    # 'Pro_League',
    # 'UCL',
    # 'UECL'
    'UEL'
]

# %%
league = leagues[0]
season = [x for x in range(23,24)]
# season = [x for x in range(21,24)] # For UECL ONLY
ws = sd.WhoScored(leagues=league, seasons=season)
fb = sd.FBref(leagues=league, seasons=season)

# # get all 3 dfs
# print("Fetching DataFrames ... ")
whoscored_df = ws.read_schedule()
fbref_df = fb.read_schedule()
fotmob_df = getFotMobSeasonFixture(league,season)
# Out:
# [03/26/24 08:46:37] INFO     Saving cached data to C:\Users\Hp\soccerdata\data\WhoScored              _common.py:91
# [03/26/24 08:46:38] INFO     Saving cached data to C:\Users\Hp\soccerdata\data\FBref                  _common.py:91
# [03/26/24 08:47:09] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22687/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Final Stage'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22687/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Alhamisi, Feb 15 2024                      whoscored.py:327
# [03/26/24 08:47:10] INFO     Scraping game schedule for Alhamisi, Feb 22 2024                      whoscored.py:327
# [03/26/24 08:47:11] INFO     Scraping game schedule for Jumatano, Mac 6 2024                       whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Mac 7 2024                       whoscored.py:327
# [03/26/24 08:47:13] INFO     Scraping game schedule for Alhamisi, Mac 14 2024                      whoscored.py:327
# [03/26/24 08:47:14] INFO     Scraping game schedule for Alhamisi, Apr 11 2024                      whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Apr 18 2024                      whoscored.py:327
# [03/26/24 08:47:23] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22539/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Group Stages'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22539/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Alhamisi, Sep 21 2023                      whoscored.py:327
# [03/26/24 08:47:26] INFO     Scraping game schedule for Alhamisi, Okt 5 2023                       whoscored.py:327
# [03/26/24 08:47:28] INFO     Scraping game schedule for Alhamisi, Okt 26 2023                      whoscored.py:327
# [03/26/24 08:47:30] INFO     Scraping game schedule for Alhamisi, Nov 9 2023                       whoscored.py:327
# [03/26/24 08:47:33] INFO     Scraping game schedule for Alhamisi, Nov 30 2023                      whoscored.py:327
# [03/26/24 08:47:35] INFO     Scraping game schedule for Jumatano, Des 6 2023                       whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Des 14 2023                      whoscored.py:327
# [03/26/24 08:47:44] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22356/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Qualification'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22356/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Jumanne, Ago 8 2023                        whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Ago 10 2023                      whoscored.py:327
# [03/26/24 08:47:45] INFO     Scraping game schedule for Alhamisi, Ago 17 2023                      whoscored.py:327
# [03/26/24 08:47:46] INFO     Scraping game schedule for Alhamisi, Ago 24 2023                      whoscored.py:327
# [03/26/24 08:47:48] INFO     Scraping game schedule for Alhamisi, Ago 31 2023                      whoscored.py:327
# Returning 1 DFs combination

# %%
print("Preparing Fetched DataFrames ... ")
# # prepare DFs
WS = pre_process_dataframe_for_schedules('WS',whoscored_df)
FB = pre_process_dataframe_for_schedules('FB',fbref_df)
FM = pre_process_dataframe_for_schedules('FM',fotmob_df)
# 1/0
print(league)
if league == 'UCL' or league =='UEL' or league == 'UECL':
    FM_dfs = []
    WS_dfs = []
    for season in FM['season'].unique():
        temp_df = FM[FM['season'] == season]
        group_stage_start = min(FB[FB['season'] == season]['date'])
        print(f"Season {season} | Group Stage Start {group_stage_start}")
        sw_FM_df = temp_df[temp_df['date'].dt.date >=group_stage_start.date()]
        FM_dfs.append(sw_FM_df)
        if league == "UECL" :
            t_ws_df = WS[WS['season'] == season]
            print(t_ws_df.shape)
            sw_WS_df = t_ws_df[t_ws_df['date'] >=group_stage_start]
            print("MIN: ",min(t_ws_df['date']).date(),"MAX : ",max(t_ws_df['date']).date(), " VS  ",group_stage_start.date())
            WS_dfs.append(sw_WS_df)
        print(f"WS : {WS[WS['season'] == season].shape} | FB : {FB[FB['season'] == season].shape} | FM : {sw_FM_df.shape}")
    FM = pd.concat(FM_dfs)
    if league != "UECL":
        WS = WS[WS['stage'].str.contains('Final|Group Stages', case=False)]
    else:
        print([x.shape for x in WS_dfs])
        WS = pd.concat(WS_dfs)
# Out:
# Preparing Fetched DataFrames ...
# UEL
# Season 23-24 | Group Stage Start 2023-09-21 16:45:00+00:00
# WS : (170, 9) | FB : (136, 19) | FM : (141, 8)

# %%
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'])
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'],write_mode=False)

# %%
with open(CONFIG['team_name_path'],'r') as f :
    team_aliases = json.load(f)

# %%
# merge dfs
print("Merging Fetched DataFrames ... ")
merged_df = combine_dataframes(WS,FB,FM,team_aliases)
# print("DFGHJKL",str(merged_df))
# Out:
# Merging Fetched DataFrames ...
# (1232, 9)
# Guilty index :  1488
#  HT ALias :  ['Getafe']
#  AT ALias :  ['Inter']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Getafe-Inter
# date                                                                                           2020-03-19
# home_team                                                                                          Getafe
# away_team                                                                                           Inter
# game_id                                                                                           1456775
# url          https://1xbet.whoscored.com/Matches/1456775/Show/Europe-Europa-League-2019-2020-Getafe-Inter
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1488, dtype: object
#
# Problem | Home : Getafe | Away : Inter | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW
# Guilty index :  1489
#  HT ALias :  ['Roma', 'AS Roma']
#  AT ALias :  ['Sevilla']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Roma-Sevilla
# date                                                                                           2020-03-19
# home_team                                                                                            Roma
# away_team                                                                                         Sevilla
# game_id                                                                                           1456776
# url          https://1xbet.whoscored.com/Matches/1456776/Show/Europe-Europa-League-2019-2020-Roma-Sevilla
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1489, dtype: object
#
# Problem | Home : Roma | Away : Sevilla | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW

# %%
# merged_df.to_csv(rf"./combined_sch/combined_{league}.csv")

# %%
league
# Out:
# 'UEL'

# %%
# merged_dfs = {}

# %%
merged_dfs[league] = merged_df

# %%
merged_dfs.keys()
# Out:
# dict_keys(['ENG-Premier League', 'ESP-La Liga', 'Eredivisie', 'FRA-Ligue 1', 'GER-Bundesliga', 'ITA-Serie A', 'Primeira_Liga', 'Pro_League', 'UCL', 'UEL'])

# %%
for k,v in merged_dfs.items():
    v.to_csv(rf"./combined_sch/combined_{k}_1.csv")

# %%
# # get missing data info
# print("Get missing games |DataFrames ... ")
# miss_WS = WS[~WS['game_id'].isin(merged_df['whoscored_id'])]
# miss_FM = FM[~FM['id'].isin(merged_df['fotmob_id'])]
# miss_FB = FB[~FB['game_id'].isin(merged_df['fbref_id'])]

# miss_WS.to_csv(rf"./missing_matches/miss_WS_{league}.csv")
# miss_FB.to_csv(rf"./missing_matches/miss_FB_{league}.csv")
# miss_FM.to_csv(rf"./missing_matches/miss_FM_{league}.csv")
# Out:
# Get missing games |DataFrames ...

# %%
for k,v in merged_dfs.items():
    print(k," : ",max(v['date']))
# Out:
# ENG-Premier League  :  2024-03-17
# ESP-La Liga  :  2024-03-17
# Eredivisie  :  2024-03-17
# FRA-Ligue 1  :  2024-03-17
# GER-Bundesliga  :  2024-03-17
# ITA-Serie A  :  2024-03-17
# Primeira_Liga  :  2024-03-17
# Pro_League  :  2024-03-30
# UCL  :  2024-03-13
# UEL  :  2024-03-14

# %%
all_merged = pd.concat(list(merged_dfs.values()))

# %%
[]
# Out:
# (20370, 13)

# %%
all_merged.to_csv(r"./combined_sch/all_merged_2.csv")
