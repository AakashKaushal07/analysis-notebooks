# %%
import pandas as pd
from datetime import datetime
import soccerdata as sd
import os,sys,requests
import sql_connector as SQL
import config
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\322462531.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# [03/28/24 05:07:20] INFO     Custom team name replacements loaded from                                _config.py:82
#                              C:\Users\Hp\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    _config.py:204
#                              C:\Users\Hp\soccerdata\config\league_dict.json.

# %%
matches = SQL.execute_select_query("select * from match_schedule")

# %%
matches = pd.DataFrame(matches)

# %%
matches.head(2)
# Out:
#       id         competition season stage        date home_team  away_team  \
# 0  42740  ENG-Premier League  17-18   nan  2017-08-11   Arsenal  Leicester
# 1  42741  ENG-Premier League  17-18   nan  2017-08-12   Watford  Liverpool
#
#   score  whoscored_id                                      whoscored_url  \
# 0   4–3     1190170.0  https://1xbet.whoscored.com/Matches/1190174/Li...
# 1   3–3     1190180.0  https://1xbet.whoscored.com/Matches/1190182/Li...
#
#    fbref_id                                          fbref_url  fotmob_id  \
# 0  e3c3ddf0  /en/matches/e3c3ddf0/Arsenal-Leicester-City-Au...    2522743
# 1  60f6cc1d  /en/matches/60f6cc1d/Watford-Liverpool-August-...    2522751
#
#                                           fotmob_url read_status
# 0  /matches/leicester-city-vs-arsenal/2op49y#2522743  NotStarted
# 1       /matches/liverpool-vs-watford/2tj4y7#2522751  NotStarted

# %%
def check_WSurl_contains_id(row):
    if str(int(row['whoscored_id'])) in str(row['whoscored_url']):
        return True
    else:
        return False
def check_FBurl_contains_id(row):
    if str(row['fbref_id']) in str(row['fbref_url']):
        return True
    else:
        return False
                
def check_FMurl_contains_id(row):
    if str(row['fotmob_id']) in str(row['fotmob_id']):
        return True
    else:
        return False

# %%
df = pd.DataFrame()
# Apply the function to each row and create a new column 'contains_id'
df= matches[['id','competition','season','stage','date','home_team','away_team','score','whoscored_id','whoscored_url']]
df['WS_contains_id'] = matches.apply(check_WSurl_contains_id, axis=1)
df['FB_contains_id'] = matches.apply(check_FBurl_contains_id, axis=1)
df['FM_contains_id'] = matches.apply(check_FMurl_contains_id, axis=1)
df['whoscored_id'] = df['whoscored_id'].astype(int)
# Display the DataFrame with the new column
df
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\2148059069.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WS_contains_id'] = matches.apply(check_WSurl_contains_id, axis=1)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\2148059069.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FB_contains_id'] = matches.apply(check_FBurl_contains_id, axis=1)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\2148059069.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FM_contains_id'] = matches.apply(check_FMurl_contains_id, axis=1)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\2148059069.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['whoscored_id'] = df['whoscored_id'].astype(int)
#           id         competition season                      stage  \
# 0      42740  ENG-Premier League  17-18                        nan
# 1      42741  ENG-Premier League  17-18                        nan
# 2      42742  ENG-Premier League  17-18                        nan
# 3      42743  ENG-Premier League  17-18                        nan
# 4      42744  ENG-Premier League  17-18                        nan
# ...      ...                 ...    ...                        ...
# 20364  63105                 UEL  23-24  Europa League Final Stage
# 20365  63106                 UEL  23-24  Europa League Final Stage
# 20366  63107                 UEL  23-24  Europa League Final Stage
# 20367  63108                 UEL  23-24  Europa League Final Stage
# 20368  63109       Primeira_Liga  23-24                       None
#
#              date         home_team             away_team score  whoscored_id  \
# 0      2017-08-11           Arsenal             Leicester   4–3       1190170
# 1      2017-08-12           Watford             Liverpool   3–3       1190180
# 2      2017-08-12           Chelsea               Burnley   2–3       1190180
# 3      2017-08-12    Crystal Palace          Huddersfield   0–3       1190180
# 4      2017-08-12           Everton                 Stoke   1–0       1190180
# ...           ...               ...                   ...   ...           ...
# 20364  2024-03-14          Atalanta           Sporting CP   2–1       1805550
# 20365  2024-03-14  Bayer Leverkusen            Qarabag FK   3–2       1805550
# 20366  2024-03-14          Brighton                  Roma   1–0       1805540
# 20367  2024-03-14         Liverpool         Sparta Prague   6–1       1805540
# 20368  2024-03-17            Chaves  Vitoria de Guimaraes   1–2       1748590
#
#                                            whoscored_url  WS_contains_id  \
# 0      https://1xbet.whoscored.com/Matches/1190174/Li...           False
# 1      https://1xbet.whoscored.com/Matches/1190182/Li...           False
# 2      https://1xbet.whoscored.com/Matches/1190176/Li...           False
# 3      https://1xbet.whoscored.com/Matches/1190177/Li...           False
# 4      https://1xbet.whoscored.com/Matches/1190178/Li...           False
# ...                                                  ...             ...
# 20364  https://1xbet.whoscored.com/Matches/1805546/Li...           False
# 20365  https://1xbet.whoscored.com/Matches/1805550/Li...            True
# 20366  https://1xbet.whoscored.com/Matches/1805540/Li...            True
# 20367  https://1xbet.whoscored.com/Matches/1805536/Li...           False
# 20368  https://1xbet.whoscored.com/Matches/1748587/Li...           False
#
#        FB_contains_id  FM_contains_id
# 0                True            True
# 1                True            True
# 2                True            True
# 3                True            True
# 4                True            True
# ...               ...             ...
# 20364            True            True
# 20365            True            True
# 20366            True            True
# 20367            True            True
# 20368            True            True
#
# [20369 rows x 13 columns]

# %%
df['WS_contains_id'].value_counts(),\
df['FB_contains_id'].value_counts(),\
df['FM_contains_id'].value_counts()
# Out:
# (WS_contains_id
#  False    18324
#  True      2045
#  Name: count, dtype: int64,
#  FB_contains_id
#  True    20369
#  Name: count, dtype: int64,
#  FM_contains_id
#  True    20369
#  Name: count, dtype: int64)

# %%
def extract_id_from_url(row):
    # Define the regex pattern to match the ID in the URL
    pattern = r'/Matches/(\d+)/'
    import re
    # Search for the pattern in the URL
    match = re.search(pattern, row['whoscored_url'])

    if match:
        # Extract the ID from the matched group
        return match.group(1)
    else:
        # If no match found, return None
        return None

# %%
df['correct_ws_id'] = df.apply(extract_id_from_url,axis=1)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3260\3817345907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['correct_ws_id'] = df.apply(extract_id_from_url,axis=1)

# %%
for ws_id,id in zip(df['whoscored_id'],df['id']):
    print(ws_id,id)
    r = SQL.execute_select_query("select * from match_schedule where whoscored_id = '{}' and id = '{}'".format(ws_id,id))
    if len(r) == 1:
        print(r)
        # SQL.execute_update_query("update match_schedule set whoscored_id = '{}' where id = '{}'".format(ws_id,id))
    break
# Out:
# 1190170 42740
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Too many connections
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[15], line 3
#       1 for ws_id,id in zip(df['whoscored_id'],df['id']):
#       2     print(ws_id,id)
# ----> 3     r = SQL.execute_select_query("select * from match_schedule where whoscored_id = '{}' and id = '{}'".format(ws_id,id))
#       4     if len(r) == 1:
#       5         print(r)
#
# File D:\Visual Analysis\analysis-notebooks\Notebooks\General Utilities\sql_connector.py:18, in execute_select_query(query)
#      17 def execute_select_query(query):
# ---> 18     cursor, cnx = connect_to_database()
#      19     cursor.execute(query)
#      20     result = cursor.fetchall()
#
# File D:\Visual Analysis\analysis-notebooks\Notebooks\General Utilities\sql_connector.py:5, in connect_to_database()
#       3 def connect_to_database():
#       4     # Connect to the MySQL database
# ----> 5     cnx = connect(
#       6         host="localhost",
#       7         user="root",
#       8         password="pass,123",
#       9         database="analysis"
#      10     )
#      12     # Create a cursor object to execute SQL queries
#      13     cursor = cnx.cursor()
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\mysql\connector\connection_cext.py:140, in CMySQLConnection.__init__(self, **kwargs)
#     138 if kwargs:
#     139     try:
# --> 140         self.connect(**kwargs)
#     141     except Exception:
#     142         self.close()
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\mysql\connector\abstracts.py:1363, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1360     self.config(**kwargs)
#    1362 self.disconnect()
# -> 1363 self._open_connection()
#    1365 charset, collation = (
#    1366     kwargs.pop("charset", None),
#    1367     kwargs.pop("collation", None),
#    1368 )
#    1369 if charset or collation:
#
# File D:\Visual Analysis\analysis-notebooks\notebook-env\lib\site-packages\mysql\connector\connection_cext.py:328, in CMySQLConnection._open_connection(self)
#     326         self.converter.str_fallback = self._converter_str_fallback
#     327 except MySQLInterfaceError as err:
# --> 328     raise get_mysql_exception(
#     329         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     330     ) from err
#     332 self._do_handshake()
#
# DatabaseError: 1040 (HY000): Too many connections

# %%
df
# Out:
#           id         competition season                      stage  \
# 0      42740  ENG-Premier League  17-18                        nan
# 1      42741  ENG-Premier League  17-18                        nan
# 2      42742  ENG-Premier League  17-18                        nan
# 3      42743  ENG-Premier League  17-18                        nan
# 4      42744  ENG-Premier League  17-18                        nan
# ...      ...                 ...    ...                        ...
# 20364  63105                 UEL  23-24  Europa League Final Stage
# 20365  63106                 UEL  23-24  Europa League Final Stage
# 20366  63107                 UEL  23-24  Europa League Final Stage
# 20367  63108                 UEL  23-24  Europa League Final Stage
# 20368  63109       Primeira_Liga  23-24                       None
#
#              date         home_team             away_team score  whoscored_id  \
# 0      2017-08-11           Arsenal             Leicester   4–3       1190170
# 1      2017-08-12           Watford             Liverpool   3–3       1190180
# 2      2017-08-12           Chelsea               Burnley   2–3       1190180
# 3      2017-08-12    Crystal Palace          Huddersfield   0–3       1190180
# 4      2017-08-12           Everton                 Stoke   1–0       1190180
# ...           ...               ...                   ...   ...           ...
# 20364  2024-03-14          Atalanta           Sporting CP   2–1       1805550
# 20365  2024-03-14  Bayer Leverkusen            Qarabag FK   3–2       1805550
# 20366  2024-03-14          Brighton                  Roma   1–0       1805540
# 20367  2024-03-14         Liverpool         Sparta Prague   6–1       1805540
# 20368  2024-03-17            Chaves  Vitoria de Guimaraes   1–2       1748590
#
#                                            whoscored_url  WS_contains_id  \
# 0      https://1xbet.whoscored.com/Matches/1190174/Li...           False
# 1      https://1xbet.whoscored.com/Matches/1190182/Li...           False
# 2      https://1xbet.whoscored.com/Matches/1190176/Li...           False
# 3      https://1xbet.whoscored.com/Matches/1190177/Li...           False
# 4      https://1xbet.whoscored.com/Matches/1190178/Li...           False
# ...                                                  ...             ...
# 20364  https://1xbet.whoscored.com/Matches/1805546/Li...           False
# 20365  https://1xbet.whoscored.com/Matches/1805550/Li...            True
# 20366  https://1xbet.whoscored.com/Matches/1805540/Li...            True
# 20367  https://1xbet.whoscored.com/Matches/1805536/Li...           False
# 20368  https://1xbet.whoscored.com/Matches/1748587/Li...           False
#
#        FB_contains_id  FM_contains_id correct_ws_id
# 0                True            True       1190174
# 1                True            True       1190182
# 2                True            True       1190176
# 3                True            True       1190177
# 4                True            True       1190178
# ...               ...             ...           ...
# 20364            True            True       1805546
# 20365            True            True       1805550
# 20366            True            True       1805540
# 20367            True            True       1805536
# 20368            True            True       1748587
#
# [20369 rows x 14 columns]
