# %%
import soccerdata as sd
import pandas as pd
import traceback
import matplotlib.pyplot as plt
from mplsoccer import Pitch,VerticalPitch
from datetime import datetime,timedelta
import requests,json,config
import matplotlib.patches as patches
import math,sys,os,random
from threading import Thread
import time,concurrent
import numpy as np
from math import isnan
# import mysql.connector
from bs4 import BeautifulSoup

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# [03/26/24 02:51:47] INFO     Custom team name replacements loaded from                                _config.py:82
#                              C:\Users\Hp\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    _config.py:204
#                              C:\Users\Hp\soccerdata\config\league_dict.json.

# %%
FOTMOB_URL = config.getFotMobUrls()
FOTMOB_LEAGUE = config.getFotMobLeagueDict()
CONFIG = config.getGeneralConfig()

# %%
FOTMOB_LEAGUE
# Out:
# {'ENG-Premier League': 47,
#  'ESP-La Liga': 87,
#  'ITA-Serie A': 55,
#  'GER-Bundesliga': 54,
#  'FRA-Ligue 1': 53,
#  'INT-World Cup': 77,
#  'UCL': 42,
#  'UEL': 73,
#  'UECL': 10216,
#  'Eredivisie': 57,
#  'Pro_League': 40,
#  'Primeira_Liga': 61}

# %%
def getFotMobSeasonFixture(league,seasons): # Example [2016,2017] or "23_24"
    # # making season list
    if "list" in str(type(seasons)):
        # "%2F".join(['20'+str(x)for x in season.split('_')])
        season_name_str = [(f'{x%2000}-{(x+1)%2000}',f'20{str(x)}%2F20{str(x+1)}')for x in seasons]
        fixture_urls = [(season,FOTMOB_URL['fixture'].format(FOTMOB_LEAGUE[league],season_str)) for season,season_str in season_name_str]
        
    else:
        season_name_str = "%2F".join(['20'+str(x)for x in seasons.split('_')])
        fixture_urls = [FOTMOB_URL['fixture'].format(FOTMOB_LEAGUE[league],season_name)]
    all_fixtures = []
    for season_nm,fixture_url in fixture_urls:
        fixture_res = requests.get(fixture_url)
        # return
        df = pd.DataFrame()
        
        if fixture_res.status_code == 200 :
            try:
                fixtures = fixture_res.json()
                for match in fixtures :
                    i = df.shape[0]
                    df.loc[i, 'id']=match['id']
                    df.loc[i, 'league']=league.split('-')[-1].strip(' ')
                    df.loc[i, 'season']=season_nm
                    df.loc[i, 'url']=match['pageUrl']
                    df.loc[i, 'home_team']=match['home']['name']
                    df.loc[i, 'away_team']=match['away']['name']
                    df.loc[i, 'date']=match['status']['utcTime']
                all_fixtures.append(df)
            except JSONDecodeError as jde :
                print("Json Error ")
                print("Data Response ",fixture_res.content.decode())
                all_fixtures.append(df)
            except Exception as e :
                print("General Error ")
                print("Exception as  : ",str(e))
                all_fixtures.append(df)
    print(f"Returning {len(all_fixtures)} DFs combination")            
    return pd.concat(all_fixtures, ignore_index=True)    
# getFotMobSeasonFixture(league,season_name)
# getFotMobSeasonFixture(league,[2017,2016])
# getFotMobSeasonFixture(league,season)

# %%
def pre_process_dataframe_for_schedules(df_name,df_under):
    
    df_under = df_under
    if df_name == "WS":
        df_under = df_under.reset_index()
        df_under['date'] = pd.to_datetime(df_under['date']).dt.tz_localize(None).dt.tz_localize('UTC') + timedelta(hours=-1)
        df_under['season'] = df_under['season'].astype(str).apply(lambda x: x[:2] + '-' + x[2:])
    elif df_name == "FB" :
        df_under = df_under.reset_index()
        df_under['season'] = df_under['season'].astype(str).apply(lambda x: x[:2] + '-' + x[2:])
        df_under['date'] = df_under['date'].astype(str)
        df_under['time'] = df_under['time'].astype(str).replace('<NA>',"00:00")
        df_under['date'] = df_under['date']+' '+df_under['time']+":00"
        df_under['date'] = pd.to_datetime(df_under['date']).dt.tz_localize(None).dt.tz_localize('UTC') + timedelta(hours=-2)
        
    else:
        df_under = df_under.reset_index()
        df_under['date'] = pd.to_datetime(df_under['date'].str.split('Z').str[0].str.split(".").str[0],format='%Y-%m-%dT%H:%M:%S')
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('.').str[0],format='%Y-%m-%dT%H:%M:%SZ')
        # df_under['date'] = pd.to_datetime(df_under['date']) + timedelta(hours=1)
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('T').str[0])
        # df_under['date'] = pd.to_datetime(df_under['date'].str.split('T').str[0])
        df_under['date'] = df_under['date'].dt.tz_localize(None).dt.tz_localize('UTC')

    # df_under['date'] = df_under['date'].dt.date
    return df_under.sort_values(['date', 'home_team', 'away_team'])
# pre_process_dataframe_for_schedules('FM',fotmob_df),\
# pre_process_dataframe_for_schedules('FB',fbref_df),\
# pre_process_dataframe_for_schedules('WS',whoscored_df)

# %%
def update_team_alias(WS_df,FB_df,FM_df,file_path,write_mode=True):
    try:
        season_set = set([x.year for x in WS_df['date']])
        if write_mode or 1:
            with open(file_path,'r') as f :
                existing_alias = json.load(f)
        else:
            existing_alias = {}
        team_alias = existing_alias      
        for season in season_set:
            # print("")
            # print(team_alias)
            WS_mw1,FB_mw1,FM_mw1 = getFirstMatchweekOfSeason(WS_df,FB_df,FM_df,season)
            if WS_mw1.empty or FB_mw1.empty or FM_mw1.empty:
                continue
            # x = getFirstMatchweekOfSeason(WS_df,FB_df,FM_df,season)
            # WS = sorted(list(set(sortedlist(WS_mw1['home_team'].unique()) + list(WS_mw1['away_team'].unique())))))
            # FB = sorted(list(set(sorted(list(FB_mw1['home_team'].unique()) + list(FB_mw1['away_team'].unique())))))
            # FM = sorted(list(set(sorted(list(FM_mw1['home_team'].unique()) + list(FM_mw1['away_team'].unique())))))
            
            WS = list(WS_mw1['home_team'].unique()) + list(WS_mw1['away_team'].unique())
            FB = list(FB_mw1['home_team'].unique()) + list(FB_mw1['away_team'].unique())
            FM = list(FM_mw1['home_team'].unique()) + list(FM_mw1['away_team'].unique())
            print(len(WS),len(FB),len(FM))
            # print(WS)
            # print(FM)
            # print(FB)
            for i,team in enumerate(WS):
                flag = False
                if team not in team_alias.keys():
                    team_alias[team] = [team]
                    flag = True
                if flag : 
                    if team != FB[i] :
                        team_alias[team].append(FB[i])
                    if team != FM[i] :
                        team_alias[team].append(FM[i])
                team_alias[team] = list(set(team_alias[team]))
        merged_alias = {**existing_alias,**team_alias}
        print(team_alias)
        if write_mode :
            with open(file_path,'w') as f :
                f.write(json.dumps(merged_alias))
        return merged_alias
    except Exception as e:
        print("Err : update_team_alias : ",e)
        import sys,os
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print(exc_type, fname, exc_tb.tb_lineno)
        
    return False
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'])
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'],write_mode = False)

# %%
def getFirstMatchweekOfSeason(WS,FB,FM,season):
    print(f" ===================== SEASON NAME : {season} ===================== ")
    # start_border_date = datetime.strptime(f'25-07-{season}','%d-%m-%Y').date()
    # end_border_date = datetime.strptime(f'25-07-{season+1}','%d-%m-%Y').date()
    start_border_date = pd.to_datetime(datetime.strptime(f'25-07-{season}','%d-%m-%Y'), utc=True)
    end_border_date = pd.to_datetime(datetime.strptime(f'25-07-{season+1}','%d-%m-%Y'), utc=True)
    season = season%2000
    season_name = str(season)+'-'+str(season+1)
    print(season_name)
    # end_border_date = datetime.strptime(f'25-07-{season+1}','%d-%m-%Y')

    # season_wide_df_WS = WS[(WS['date'] > start_border_date) & (WS['date'] < end_border_date)]
    # season_wide_df_FM = FM[(FM['date'] > start_border_date) & (FM['date'] < end_border_date)]
    # season_wide_df_FB = FB[(FB['date'] > start_border_date) & (FB['date'] < end_border_date)]
    
    season_wide_df_WS = WS[WS['season'] == season_name]
    season_wide_df_FM = FM[FM['season'] == season_name]
    season_wide_df_FB = FB[FB['season'] == season_name]
    if season_wide_df_WS.empty or season_wide_df_FM.empty or season_wide_df_FB.empty:
        return pd.DataFrame(),pd.DataFrame(),pd.DataFrame()
    # season_wide_df_WS.to_csv("WS.csv")
    # season_wide_df_FM.to_csv("FM.csv")
    # season_wide_df_FB.to_csv("FB.csv")
    
    ht_team_count_arr =[len(list(season_wide_df_WS['home_team'].unique())),
        len(list(season_wide_df_FB['home_team'].unique())),
        len(list(season_wide_df_FM['home_team'].unique()))
    ]
    at_team_count_arr =[len(sorted(list(season_wide_df_WS['home_team'].unique()))),
        len(sorted(list(season_wide_df_FB['home_team'].unique()))),
        len(sorted(list(season_wide_df_FM['home_team'].unique())))
    ]
    
    ht_team_count = sum(ht_team_count_arr)/len(ht_team_count_arr)
    at_team_count = sum(at_team_count_arr)/len(at_team_count_arr)
    GW_WS = []
    GW_FB = []
    GW_FM = []
    if ht_team_count == at_team_count:
        team_list = list(season_wide_df_WS['home_team'].unique())
        i=0
        while len(team_list):
            # print(f"Left Teams : {len(team_list)}  | {team_list}")
            ht = season_wide_df_WS.iloc[i]['home_team'] 
            at = season_wide_df_WS.iloc[i]['away_team']
            c = 0
            if ht in team_list:
                # print("Removing HT... ",ht)
                team_list.remove(ht)
                c+=1
            if at in team_list:
                # print("Removing AT... ",at)
                team_list.remove(at)
                c+=1
            # print()
            if c != 0:
                # print(f"Adding Game : {ht} v {at} at index = {i}")
                # if i == 15:
                    # display(season_wide_df_WS.iloc[i])
                    # display(season_wide_df_FB.iloc[i])
                    # display(season_wide_df_FM.iloc[i])
                
                GW_WS.append(season_wide_df_WS.iloc[i])
                GW_FB.append(season_wide_df_FB.iloc[i])
                GW_FM.append(season_wide_df_FM.iloc[i])
                # print(f"Counts = WS : {len(GW_WS)} | FB : {len(GW_FB)} | FM : {len(GW_FM)}")
            else:
                # print(f"Can't add game : {ht} v {at} at index = {i}")
                # print("Kela and i hogya,",i, " With  HT : ",ht, " and AT : ",at)
                # print("Kela : ",team_list)
                # print(season_wide_df_WS.shape)
                if i > 120 :
                    break
            i+=1
            # print('=====================================')
    else:
        return f"Error : HT Count : {ht_team_count} | AT Count : {at_team_count}"
    # print(len(GW_WS),len(GW_FB),len(GW_FM))
    return pd.DataFrame(GW_WS),pd.DataFrame(GW_FB),pd.DataFrame(GW_FM)
# 
# a,b,c = getFirstMatchweekOfSeason(WS,FB,FM,2019)

# %%
# for i in range(a.shape[0]) :
#     print(i)
#     ht_ws = a.iloc[i]['home_team']
#     at_ws = a.iloc[i]['away_team']
#     dt_ws = a.iloc[i]['date']
    
#     ht_fb = b.iloc[i]['home_team']
#     at_fb = b.iloc[i]['away_team']
#     dt_fb = b.iloc[i]['date']
    
#     ht_fm = c.iloc[i]['home_team']
#     at_fm = c.iloc[i]['away_team']
#     dt_fm = c.iloc[i]['date']

#     print(f"WS : {ht_ws} v {at_ws} at {dt_ws}")
#     print(f"FB : {ht_fb} v {at_fb} at {dt_fb}")
#     print(f"FM : {ht_fm} v {at_fm} at {dt_fm}")

# %%
def combine_dataframes(WS_init,FB_init,FM_init,team_alias):
    WS = WS_init
    FB = FB_init
    FM = FM_init
    print(WS.shape)
    WS['source'] = "WhoScored"
    FM['source'] = "FotMob"
    FB['source'] = "FBref"
    try:
        WS['date'] = WS['date'].dt.date
        FM['date'] = FM['date'].dt.date
        FB['date'] = FB['date'].dt.date
    except :
        print("Ik about the dt thing")
        
    df = pd.DataFrame()
    dfs = [WS,FM,FB]
    # Find the DataFrame with the least number of rows
    loop_df = min(dfs, key=len)
    try:
        for x in WS.index:
            msg = None
            # Get the row data
            WS_row = WS.loc[x]
            # row = loop_df.loc[x]
            # print("Source is :",row['source'])
            row_home_team = WS_row['home_team']
            row_away_team = WS_row['away_team']
            row_date = WS_row['date']
            row_season = WS_row['season']
            row_round = str(WS_row['stage'])
            acceptable_rounds = ['Regular season', league, "None",None,'nan',league.split('-')[-1].strip(' '),league.replace('_',' '),
                                'Eredivisie ECL Playoff','Europa League Playoff', # Dutch League
                                 'Jupiler League','First Division A','Playoff Championship', # belgian League
                                "Champions League Group Stages","Champions League Final Stage", # UCL
                                 "Europa League Group Stages","Europa League Final Stage" #UEL
                                ]
            # print(acceptable_rounds)
            if row_round.strip(' ') not in acceptable_rounds:
                print("Row Round nikla : ",row_round)
                continue
    
            home_team_alias = team_alias[row_home_team]
            away_team_alias = team_alias[row_away_team]
    
            #Get DF ROWS
            # WS_row = WS[(WS['home_team'].isin(home_team_alias)) & (WS['away_team'].isin(away_team_alias)) & (WS['date'] == row_date)]
            FM_row = FM[(FM['home_team'].isin(home_team_alias)) & (FM['away_team'].isin(away_team_alias)) & (FM['season'] == row_season)]
            FB_row = FB[(FB['home_team'].isin(home_team_alias)) & (FB['away_team'].isin(away_team_alias)) & (FB['season'] == row_season)]
    
            if FB_row.empty or FM_row.empty or WS_row.empty:
                print("Guilty index : ",x)
                print(" HT ALias : ",home_team_alias)
                print(" AT ALias : ",away_team_alias)
                print()
                print(WS.loc[x])
                print()
                msg = f"Problem | Home : {row_home_team} | Away : {row_away_team} | Date : {row_date} \n "
                msg += f"DFs | WhoScored : {WS_row.empty} | FBRef : {FB_row.empty} | FotMob : {FM_row.empty}. \n"
                # msg += f"TIME | WhoScored : ({WS['date'][x]}) | FBRef : ({FM['date'][x]}) | FotMob : ({FB['date'][x]})."
                print(msg)
                if not FB_row.empty:
                    print("FB ROW")
                    if "Cancelled" in str(FB_row.iloc[0]['notes']):
                        continue
                return msg
            else:
                # Keeping only first row if all exist
                # print(WS_row.shape,FB_row.shape,FM_row.shape)
                try:
                    FB_row = FB_row.iloc[0]
                    FM_row = FM_row.iloc[0]
                except Exception as e:
                    print(f"DATE : {row_date} | HT : {row_home_team} | AT :{row_away_team}")
                    if "Cancelled" in str(FB_row['notes']):
                        continue
                    print("Excepitoin : ",e)
                    print("FB ROW IS  : ")
                    print(FB_row)
                    print()
                    print("FM ROW IS  : ")
                    print(FM_row)
                    print()
            # avoiding matches which are not played yet
            if str(FB_row['game_id']) == 'nan' or FB_row['match_report'] is None:
                continue
                
            i = df.shape[0]
            
            df.loc[i, 'competition']=WS_row['league']
            df.loc[i, 'season']=WS_row['season']
            df.loc[i, 'stage']=WS_row['stage']
            
            df.loc[i, 'date'] = row_date
            df.loc[i, 'home_team'] = row_home_team        
            df.loc[i, 'away_team'] = row_away_team
            # print("INDEX",df)
            df.loc[i, 'score'] = FB_row['score']
            
            df.loc[i, 'whoscored_id']=WS_row['game_id']
            df.loc[i, 'whoscored_url']=WS_row['url']
            
            df.loc[i, 'fbref_id']=FB_row['game_id']
            df.loc[i, 'fbref_url']=FB_row['match_report']
    
            df.loc[i, 'fotmob_id']=FM_row['id']
            df.loc[i, 'fotmob_url']=FM_row['url']
        return df
    except Exception as e:
        print("Merge DF Exception Occured : ",str(e))
        import sys,os
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print(exc_type, fname, exc_tb.tb_lineno)
        print('-------')
        print('-------', msg)
        raise e
combine_dataframes(WS,FB,FM,team_aliases)
# FM.to_csv("Test.csv")
# Out:
# (1232, 10)
# Ik about the dt thing
# Guilty index :  1488
#  HT ALias :  ['Getafe']
#  AT ALias :  ['Inter']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Getafe-Inter
# date                                                                                           2020-03-19
# home_team                                                                                          Getafe
# away_team                                                                                           Inter
# game_id                                                                                           1456775
# url          https://1xbet.whoscored.com/Matches/1456775/Show/Europe-Europa-League-2019-2020-Getafe-Inter
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1488, dtype: object
#
# Problem | Home : Getafe | Away : Inter | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW
# Guilty index :  1489
#  HT ALias :  ['Roma', 'AS Roma']
#  AT ALias :  ['Sevilla']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Roma-Sevilla
# date                                                                                           2020-03-19
# home_team                                                                                            Roma
# away_team                                                                                         Sevilla
# game_id                                                                                           1456776
# url          https://1xbet.whoscored.com/Matches/1456776/Show/Europe-Europa-League-2019-2020-Roma-Sevilla
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1489, dtype: object
#
# Problem | Home : Roma | Away : Sevilla | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW
#      competition season                       stage        date  \
# 0            UEL  17-18  Europa League Group Stages  2017-09-14
# 1            UEL  17-18  Europa League Group Stages  2017-09-14
# 2            UEL  17-18  Europa League Group Stages  2017-09-14
# 3            UEL  17-18  Europa League Group Stages  2017-09-14
# 4            UEL  17-18  Europa League Group Stages  2017-09-14
# 5            UEL  17-18  Europa League Group Stages  2017-09-14
# 6            UEL  17-18  Europa League Group Stages  2017-09-14
# 7            UEL  17-18  Europa League Group Stages  2017-09-14
# 8            UEL  17-18  Europa League Group Stages  2017-09-14
# 9            UEL  17-18  Europa League Group Stages  2017-09-14
# 10           UEL  17-18  Europa League Group Stages  2017-09-14
# 11           UEL  17-18  Europa League Group Stages  2017-09-14
# 12           UEL  17-18  Europa League Group Stages  2017-09-14
# 13           UEL  17-18  Europa League Group Stages  2017-09-14
# 14           UEL  17-18  Europa League Group Stages  2017-09-14
# 15           UEL  17-18  Europa League Group Stages  2017-09-14
# 16           UEL  17-18  Europa League Group Stages  2017-09-14
# 17           UEL  17-18  Europa League Group Stages  2017-09-14
# 18           UEL  17-18  Europa League Group Stages  2017-09-14
# 19           UEL  17-18  Europa League Group Stages  2017-09-14
# 20           UEL  17-18  Europa League Group Stages  2017-09-14
# 21           UEL  17-18  Europa League Group Stages  2017-09-14
# 22           UEL  17-18  Europa League Group Stages  2017-09-14
# 23           UEL  17-18  Europa League Group Stages  2017-09-14
# 24           UEL  17-18  Europa League Group Stages  2017-09-28
# 25           UEL  17-18  Europa League Group Stages  2017-09-28
# 26           UEL  17-18  Europa League Group Stages  2017-09-28
# 27           UEL  17-18  Europa League Group Stages  2017-09-28
# 28           UEL  17-18  Europa League Group Stages  2017-09-28
# 29           UEL  17-18  Europa League Group Stages  2017-09-28
# 30           UEL  17-18  Europa League Group Stages  2017-09-28
# 31           UEL  17-18  Europa League Group Stages  2017-09-28
# 32           UEL  17-18  Europa League Group Stages  2017-09-28
# 33           UEL  17-18  Europa League Group Stages  2017-09-28
# 34           UEL  17-18  Europa League Group Stages  2017-09-28
# 35           UEL  17-18  Europa League Group Stages  2017-09-28
# 36           UEL  17-18  Europa League Group Stages  2017-09-28
# 37           UEL  17-18  Europa League Group Stages  2017-09-28
# 38           UEL  17-18  Europa League Group Stages  2017-09-28
# 39           UEL  17-18  Europa League Group Stages  2017-09-28
# 40           UEL  17-18  Europa League Group Stages  2017-09-28
# 41           UEL  17-18  Europa League Group Stages  2017-09-28
# 42           UEL  17-18  Europa League Group Stages  2017-09-28
# 43           UEL  17-18  Europa League Group Stages  2017-09-28
# 44           UEL  17-18  Europa League Group Stages  2017-09-28
# 45           UEL  17-18  Europa League Group Stages  2017-09-28
# 46           UEL  17-18  Europa League Group Stages  2017-09-28
# 47           UEL  17-18  Europa League Group Stages  2017-09-28
# 48           UEL  17-18  Europa League Group Stages  2017-10-19
# 49           UEL  17-18  Europa League Group Stages  2017-10-19
# 50           UEL  17-18  Europa League Group Stages  2017-10-19
# 51           UEL  17-18  Europa League Group Stages  2017-10-19
# 52           UEL  17-18  Europa League Group Stages  2017-10-19
# 53           UEL  17-18  Europa League Group Stages  2017-10-19
# 54           UEL  17-18  Europa League Group Stages  2017-10-19
# 55           UEL  17-18  Europa League Group Stages  2017-10-19
# 56           UEL  17-18  Europa League Group Stages  2017-10-19
# 57           UEL  17-18  Europa League Group Stages  2017-10-19
# 58           UEL  17-18  Europa League Group Stages  2017-10-19
# 59           UEL  17-18  Europa League Group Stages  2017-10-19
# 60           UEL  17-18  Europa League Group Stages  2017-10-19
# 61           UEL  17-18  Europa League Group Stages  2017-10-19
# 62           UEL  17-18  Europa League Group Stages  2017-10-19
# 63           UEL  17-18  Europa League Group Stages  2017-10-19
# 64           UEL  17-18  Europa League Group Stages  2017-10-19
# 65           UEL  17-18  Europa League Group Stages  2017-10-19
# 66           UEL  17-18  Europa League Group Stages  2017-10-19
# 67           UEL  17-18  Europa League Group Stages  2017-10-19
# 68           UEL  17-18  Europa League Group Stages  2017-10-19
# 69           UEL  17-18  Europa League Group Stages  2017-10-19
# 70           UEL  17-18  Europa League Group Stages  2017-10-19
# 71           UEL  17-18  Europa League Group Stages  2017-10-19
# 72           UEL  17-18  Europa League Group Stages  2017-11-02
# 73           UEL  17-18  Europa League Group Stages  2017-11-02
# 74           UEL  17-18  Europa League Group Stages  2017-11-02
# 75           UEL  17-18  Europa League Group Stages  2017-11-02
# 76           UEL  17-18  Europa League Group Stages  2017-11-02
# 77           UEL  17-18  Europa League Group Stages  2017-11-02
# 78           UEL  17-18  Europa League Group Stages  2017-11-02
# 79           UEL  17-18  Europa League Group Stages  2017-11-02
# 80           UEL  17-18  Europa League Group Stages  2017-11-02
# 81           UEL  17-18  Europa League Group Stages  2017-11-02
# 82           UEL  17-18  Europa League Group Stages  2017-11-02
# 83           UEL  17-18  Europa League Group Stages  2017-11-02
# 84           UEL  17-18  Europa League Group Stages  2017-11-02
# 85           UEL  17-18  Europa League Group Stages  2017-11-02
# 86           UEL  17-18  Europa League Group Stages  2017-11-02
# 87           UEL  17-18  Europa League Group Stages  2017-11-02
# 88           UEL  17-18  Europa League Group Stages  2017-11-02
# 89           UEL  17-18  Europa League Group Stages  2017-11-02
# 90           UEL  17-18  Europa League Group Stages  2017-11-02
# 91           UEL  17-18  Europa League Group Stages  2017-11-02
# 92           UEL  17-18  Europa League Group Stages  2017-11-02
# 93           UEL  17-18  Europa League Group Stages  2017-11-02
# 94           UEL  17-18  Europa League Group Stages  2017-11-02
# 95           UEL  17-18  Europa League Group Stages  2017-11-02
# 96           UEL  17-18  Europa League Group Stages  2017-11-23
# 97           UEL  17-18  Europa League Group Stages  2017-11-23
# 98           UEL  17-18  Europa League Group Stages  2017-11-23
# 99           UEL  17-18  Europa League Group Stages  2017-11-23
# 100          UEL  17-18  Europa League Group Stages  2017-11-23
# 101          UEL  17-18  Europa League Group Stages  2017-11-23
# 102          UEL  17-18  Europa League Group Stages  2017-11-23
# 103          UEL  17-18  Europa League Group Stages  2017-11-23
# 104          UEL  17-18  Europa League Group Stages  2017-11-23
# 105          UEL  17-18  Europa League Group Stages  2017-11-23
# 106          UEL  17-18  Europa League Group Stages  2017-11-23
# 107          UEL  17-18  Europa League Group Stages  2017-11-23
# 108          UEL  17-18  Europa League Group Stages  2017-11-23
# 109          UEL  17-18  Europa League Group Stages  2017-11-23
# 110          UEL  17-18  Europa League Group Stages  2017-11-23
# 111          UEL  17-18  Europa League Group Stages  2017-11-23
# 112          UEL  17-18  Europa League Group Stages  2017-11-23
# 113          UEL  17-18  Europa League Group Stages  2017-11-23
# 114          UEL  17-18  Europa League Group Stages  2017-11-23
# 115          UEL  17-18  Europa League Group Stages  2017-11-23
# 116          UEL  17-18  Europa League Group Stages  2017-11-23
# 117          UEL  17-18  Europa League Group Stages  2017-11-23
# 118          UEL  17-18  Europa League Group Stages  2017-11-23
# 119          UEL  17-18  Europa League Group Stages  2017-11-23
# 120          UEL  17-18  Europa League Group Stages  2017-12-07
# 121          UEL  17-18  Europa League Group Stages  2017-12-07
# 122          UEL  17-18  Europa League Group Stages  2017-12-07
# 123          UEL  17-18  Europa League Group Stages  2017-12-07
# 124          UEL  17-18  Europa League Group Stages  2017-12-07
# 125          UEL  17-18  Europa League Group Stages  2017-12-07
# 126          UEL  17-18  Europa League Group Stages  2017-12-07
# 127          UEL  17-18  Europa League Group Stages  2017-12-07
# 128          UEL  17-18  Europa League Group Stages  2017-12-07
# 129          UEL  17-18  Europa League Group Stages  2017-12-07
# 130          UEL  17-18  Europa League Group Stages  2017-12-07
# 131          UEL  17-18  Europa League Group Stages  2017-12-07
# 132          UEL  17-18  Europa League Group Stages  2017-12-07
# 133          UEL  17-18  Europa League Group Stages  2017-12-07
# 134          UEL  17-18  Europa League Group Stages  2017-12-07
# 135          UEL  17-18  Europa League Group Stages  2017-12-07
# 136          UEL  17-18  Europa League Group Stages  2017-12-07
# 137          UEL  17-18  Europa League Group Stages  2017-12-07
# 138          UEL  17-18  Europa League Group Stages  2017-12-07
# 139          UEL  17-18  Europa League Group Stages  2017-12-07
# 140          UEL  17-18  Europa League Group Stages  2017-12-07
# 141          UEL  17-18  Europa League Group Stages  2017-12-07
# 142          UEL  17-18  Europa League Group Stages  2017-12-07
# 143          UEL  17-18  Europa League Group Stages  2017-12-07
# 144          UEL  17-18   Europa League Final Stage  2018-02-13
# 145          UEL  17-18   Europa League Final Stage  2018-02-15
# 146          UEL  17-18   Europa League Final Stage  2018-02-15
# 147          UEL  17-18   Europa League Final Stage  2018-02-15
# 148          UEL  17-18   Europa League Final Stage  2018-02-15
# 149          UEL  17-18   Europa League Final Stage  2018-02-15
# 150          UEL  17-18   Europa League Final Stage  2018-02-15
# 151          UEL  17-18   Europa League Final Stage  2018-02-15
# 152          UEL  17-18   Europa League Final Stage  2018-02-15
# 153          UEL  17-18   Europa League Final Stage  2018-02-15
# 154          UEL  17-18   Europa League Final Stage  2018-02-15
# 155          UEL  17-18   Europa League Final Stage  2018-02-15
# 156          UEL  17-18   Europa League Final Stage  2018-02-15
# 157          UEL  17-18   Europa League Final Stage  2018-02-15
# 158          UEL  17-18   Europa League Final Stage  2018-02-15
# 159          UEL  17-18   Europa League Final Stage  2018-02-15
# 160          UEL  17-18   Europa League Final Stage  2018-02-21
# 161          UEL  17-18   Europa League Final Stage  2018-02-22
# 162          UEL  17-18   Europa League Final Stage  2018-02-22
# 163          UEL  17-18   Europa League Final Stage  2018-02-22
# 164          UEL  17-18   Europa League Final Stage  2018-02-22
# 165          UEL  17-18   Europa League Final Stage  2018-02-22
# 166          UEL  17-18   Europa League Final Stage  2018-02-22
# 167          UEL  17-18   Europa League Final Stage  2018-02-22
# 168          UEL  17-18   Europa League Final Stage  2018-02-22
# 169          UEL  17-18   Europa League Final Stage  2018-02-22
# 170          UEL  17-18   Europa League Final Stage  2018-02-22
# 171          UEL  17-18   Europa League Final Stage  2018-02-22
# 172          UEL  17-18   Europa League Final Stage  2018-02-22
# 173          UEL  17-18   Europa League Final Stage  2018-02-22
# 174          UEL  17-18   Europa League Final Stage  2018-02-22
# 175          UEL  17-18   Europa League Final Stage  2018-02-22
# 176          UEL  17-18   Europa League Final Stage  2018-03-08
# 177          UEL  17-18   Europa League Final Stage  2018-03-08
# 178          UEL  17-18   Europa League Final Stage  2018-03-08
# 179          UEL  17-18   Europa League Final Stage  2018-03-08
# 180          UEL  17-18   Europa League Final Stage  2018-03-08
# 181          UEL  17-18   Europa League Final Stage  2018-03-08
# 182          UEL  17-18   Europa League Final Stage  2018-03-08
# 183          UEL  17-18   Europa League Final Stage  2018-03-08
# 184          UEL  17-18   Europa League Final Stage  2018-03-15
# 185          UEL  17-18   Europa League Final Stage  2018-03-15
# 186          UEL  17-18   Europa League Final Stage  2018-03-15
# 187          UEL  17-18   Europa League Final Stage  2018-03-15
# 188          UEL  17-18   Europa League Final Stage  2018-03-15
# 189          UEL  17-18   Europa League Final Stage  2018-03-15
# 190          UEL  17-18   Europa League Final Stage  2018-03-15
# 191          UEL  17-18   Europa League Final Stage  2018-03-15
# 192          UEL  17-18   Europa League Final Stage  2018-04-05
# 193          UEL  17-18   Europa League Final Stage  2018-04-05
# 194          UEL  17-18   Europa League Final Stage  2018-04-05
# 195          UEL  17-18   Europa League Final Stage  2018-04-05
# 196          UEL  17-18   Europa League Final Stage  2018-04-12
# 197          UEL  17-18   Europa League Final Stage  2018-04-12
# 198          UEL  17-18   Europa League Final Stage  2018-04-12
# 199          UEL  17-18   Europa League Final Stage  2018-04-12
# 200          UEL  17-18   Europa League Final Stage  2018-04-26
# 201          UEL  17-18   Europa League Final Stage  2018-04-26
# 202          UEL  17-18   Europa League Final Stage  2018-05-03
# 203          UEL  17-18   Europa League Final Stage  2018-05-03
# 204          UEL  17-18   Europa League Final Stage  2018-05-16
# 205          UEL  18-19  Europa League Group Stages  2018-09-20
# 206          UEL  18-19  Europa League Group Stages  2018-09-20
# 207          UEL  18-19  Europa League Group Stages  2018-09-20
# 208          UEL  18-19  Europa League Group Stages  2018-09-20
# 209          UEL  18-19  Europa League Group Stages  2018-09-20
# 210          UEL  18-19  Europa League Group Stages  2018-09-20
# 211          UEL  18-19  Europa League Group Stages  2018-09-20
# 212          UEL  18-19  Europa League Group Stages  2018-09-20
# 213          UEL  18-19  Europa League Group Stages  2018-09-20
# 214          UEL  18-19  Europa League Group Stages  2018-09-20
# 215          UEL  18-19  Europa League Group Stages  2018-09-20
# 216          UEL  18-19  Europa League Group Stages  2018-09-20
# 217          UEL  18-19  Europa League Group Stages  2018-09-20
# 218          UEL  18-19  Europa League Group Stages  2018-09-20
# 219          UEL  18-19  Europa League Group Stages  2018-09-20
# 220          UEL  18-19  Europa League Group Stages  2018-09-20
# 221          UEL  18-19  Europa League Group Stages  2018-09-20
# 222          UEL  18-19  Europa League Group Stages  2018-09-20
# 223          UEL  18-19  Europa League Group Stages  2018-09-20
# 224          UEL  18-19  Europa League Group Stages  2018-09-20
# 225          UEL  18-19  Europa League Group Stages  2018-09-20
# 226          UEL  18-19  Europa League Group Stages  2018-09-20
# 227          UEL  18-19  Europa League Group Stages  2018-09-20
# 228          UEL  18-19  Europa League Group Stages  2018-09-20
# 229          UEL  18-19  Europa League Group Stages  2018-10-04
# 230          UEL  18-19  Europa League Group Stages  2018-10-04
# 231          UEL  18-19  Europa League Group Stages  2018-10-04
# 232          UEL  18-19  Europa League Group Stages  2018-10-04
# 233          UEL  18-19  Europa League Group Stages  2018-10-04
# 234          UEL  18-19  Europa League Group Stages  2018-10-04
# 235          UEL  18-19  Europa League Group Stages  2018-10-04
# 236          UEL  18-19  Europa League Group Stages  2018-10-04
# 237          UEL  18-19  Europa League Group Stages  2018-10-04
# 238          UEL  18-19  Europa League Group Stages  2018-10-04
# 239          UEL  18-19  Europa League Group Stages  2018-10-04
# 240          UEL  18-19  Europa League Group Stages  2018-10-04
# 241          UEL  18-19  Europa League Group Stages  2018-10-04
# 242          UEL  18-19  Europa League Group Stages  2018-10-04
# 243          UEL  18-19  Europa League Group Stages  2018-10-04
# 244          UEL  18-19  Europa League Group Stages  2018-10-04
# 245          UEL  18-19  Europa League Group Stages  2018-10-04
# 246          UEL  18-19  Europa League Group Stages  2018-10-04
# 247          UEL  18-19  Europa League Group Stages  2018-10-04
# 248          UEL  18-19  Europa League Group Stages  2018-10-04
# 249          UEL  18-19  Europa League Group Stages  2018-10-04
# 250          UEL  18-19  Europa League Group Stages  2018-10-04
# 251          UEL  18-19  Europa League Group Stages  2018-10-04
# 252          UEL  18-19  Europa League Group Stages  2018-10-04
# 253          UEL  18-19  Europa League Group Stages  2018-10-25
# 254          UEL  18-19  Europa League Group Stages  2018-10-25
# 255          UEL  18-19  Europa League Group Stages  2018-10-25
# 256          UEL  18-19  Europa League Group Stages  2018-10-25
# 257          UEL  18-19  Europa League Group Stages  2018-10-25
# 258          UEL  18-19  Europa League Group Stages  2018-10-25
# 259          UEL  18-19  Europa League Group Stages  2018-10-25
# 260          UEL  18-19  Europa League Group Stages  2018-10-25
# 261          UEL  18-19  Europa League Group Stages  2018-10-25
# 262          UEL  18-19  Europa League Group Stages  2018-10-25
# 263          UEL  18-19  Europa League Group Stages  2018-10-25
# 264          UEL  18-19  Europa League Group Stages  2018-10-25
# 265          UEL  18-19  Europa League Group Stages  2018-10-25
# 266          UEL  18-19  Europa League Group Stages  2018-10-25
# 267          UEL  18-19  Europa League Group Stages  2018-10-25
# 268          UEL  18-19  Europa League Group Stages  2018-10-25
# 269          UEL  18-19  Europa League Group Stages  2018-10-25
# 270          UEL  18-19  Europa League Group Stages  2018-10-25
# 271          UEL  18-19  Europa League Group Stages  2018-10-25
# 272          UEL  18-19  Europa League Group Stages  2018-10-25
# 273          UEL  18-19  Europa League Group Stages  2018-10-25
# 274          UEL  18-19  Europa League Group Stages  2018-10-25
# 275          UEL  18-19  Europa League Group Stages  2018-10-25
# 276          UEL  18-19  Europa League Group Stages  2018-10-25
# 277          UEL  18-19  Europa League Group Stages  2018-11-08
# 278          UEL  18-19  Europa League Group Stages  2018-11-08
# 279          UEL  18-19  Europa League Group Stages  2018-11-08
# 280          UEL  18-19  Europa League Group Stages  2018-11-08
# 281          UEL  18-19  Europa League Group Stages  2018-11-08
# 282          UEL  18-19  Europa League Group Stages  2018-11-08
# 283          UEL  18-19  Europa League Group Stages  2018-11-08
# 284          UEL  18-19  Europa League Group Stages  2018-11-08
# 285          UEL  18-19  Europa League Group Stages  2018-11-08
# 286          UEL  18-19  Europa League Group Stages  2018-11-08
# 287          UEL  18-19  Europa League Group Stages  2018-11-08
# 288          UEL  18-19  Europa League Group Stages  2018-11-08
# 289          UEL  18-19  Europa League Group Stages  2018-11-08
# 290          UEL  18-19  Europa League Group Stages  2018-11-08
# 291          UEL  18-19  Europa League Group Stages  2018-11-08
# 292          UEL  18-19  Europa League Group Stages  2018-11-08
# 293          UEL  18-19  Europa League Group Stages  2018-11-08
# 294          UEL  18-19  Europa League Group Stages  2018-11-08
# 295          UEL  18-19  Europa League Group Stages  2018-11-08
# 296          UEL  18-19  Europa League Group Stages  2018-11-08
# 297          UEL  18-19  Europa League Group Stages  2018-11-08
# 298          UEL  18-19  Europa League Group Stages  2018-11-08
# 299          UEL  18-19  Europa League Group Stages  2018-11-08
# 300          UEL  18-19  Europa League Group Stages  2018-11-08
# 301          UEL  18-19  Europa League Group Stages  2018-11-29
# 302          UEL  18-19  Europa League Group Stages  2018-11-29
# 303          UEL  18-19  Europa League Group Stages  2018-11-29
# 304          UEL  18-19  Europa League Group Stages  2018-11-29
# 305          UEL  18-19  Europa League Group Stages  2018-11-29
# 306          UEL  18-19  Europa League Group Stages  2018-11-29
# 307          UEL  18-19  Europa League Group Stages  2018-11-29
# 308          UEL  18-19  Europa League Group Stages  2018-11-29
# 309          UEL  18-19  Europa League Group Stages  2018-11-29
# 310          UEL  18-19  Europa League Group Stages  2018-11-29
# 311          UEL  18-19  Europa League Group Stages  2018-11-29
# 312          UEL  18-19  Europa League Group Stages  2018-11-29
# 313          UEL  18-19  Europa League Group Stages  2018-11-29
# 314          UEL  18-19  Europa League Group Stages  2018-11-29
# 315          UEL  18-19  Europa League Group Stages  2018-11-29
# 316          UEL  18-19  Europa League Group Stages  2018-11-29
# 317          UEL  18-19  Europa League Group Stages  2018-11-29
# 318          UEL  18-19  Europa League Group Stages  2018-11-29
# 319          UEL  18-19  Europa League Group Stages  2018-11-29
# 320          UEL  18-19  Europa League Group Stages  2018-11-29
# 321          UEL  18-19  Europa League Group Stages  2018-11-29
# 322          UEL  18-19  Europa League Group Stages  2018-11-29
# 323          UEL  18-19  Europa League Group Stages  2018-11-29
# 324          UEL  18-19  Europa League Group Stages  2018-11-29
# 325          UEL  18-19  Europa League Group Stages  2018-12-13
# 326          UEL  18-19  Europa League Group Stages  2018-12-13
# 327          UEL  18-19  Europa League Group Stages  2018-12-13
# 328          UEL  18-19  Europa League Group Stages  2018-12-13
# 329          UEL  18-19  Europa League Group Stages  2018-12-13
# 330          UEL  18-19  Europa League Group Stages  2018-12-13
# 331          UEL  18-19  Europa League Group Stages  2018-12-13
# 332          UEL  18-19  Europa League Group Stages  2018-12-13
# 333          UEL  18-19  Europa League Group Stages  2018-12-13
# 334          UEL  18-19  Europa League Group Stages  2018-12-13
# 335          UEL  18-19  Europa League Group Stages  2018-12-13
# 336          UEL  18-19  Europa League Group Stages  2018-12-13
# 337          UEL  18-19  Europa League Group Stages  2018-12-13
# 338          UEL  18-19  Europa League Group Stages  2018-12-13
# 339          UEL  18-19  Europa League Group Stages  2018-12-13
# 340          UEL  18-19  Europa League Group Stages  2018-12-13
# 341          UEL  18-19  Europa League Group Stages  2018-12-13
# 342          UEL  18-19  Europa League Group Stages  2018-12-13
# 343          UEL  18-19  Europa League Group Stages  2018-12-13
# 344          UEL  18-19  Europa League Group Stages  2018-12-13
# 345          UEL  18-19  Europa League Group Stages  2018-12-13
# 346          UEL  18-19  Europa League Group Stages  2018-12-13
# 347          UEL  18-19  Europa League Group Stages  2018-12-13
# 348          UEL  18-19  Europa League Group Stages  2018-12-13
# 349          UEL  18-19   Europa League Final Stage  2019-02-12
# 350          UEL  18-19   Europa League Final Stage  2019-02-14
# 351          UEL  18-19   Europa League Final Stage  2019-02-14
# 352          UEL  18-19   Europa League Final Stage  2019-02-14
# 353          UEL  18-19   Europa League Final Stage  2019-02-14
# 354          UEL  18-19   Europa League Final Stage  2019-02-14
# 355          UEL  18-19   Europa League Final Stage  2019-02-14
# 356          UEL  18-19   Europa League Final Stage  2019-02-14
# 357          UEL  18-19   Europa League Final Stage  2019-02-14
# 358          UEL  18-19   Europa League Final Stage  2019-02-14
# 359          UEL  18-19   Europa League Final Stage  2019-02-14
# 360          UEL  18-19   Europa League Final Stage  2019-02-14
# 361          UEL  18-19   Europa League Final Stage  2019-02-14
# 362          UEL  18-19   Europa League Final Stage  2019-02-14
# 363          UEL  18-19   Europa League Final Stage  2019-02-14
# 364          UEL  18-19   Europa League Final Stage  2019-02-14
# 365          UEL  18-19   Europa League Final Stage  2019-02-20
# 366          UEL  18-19   Europa League Final Stage  2019-02-21
# 367          UEL  18-19   Europa League Final Stage  2019-02-21
# 368          UEL  18-19   Europa League Final Stage  2019-02-21
# 369          UEL  18-19   Europa League Final Stage  2019-02-21
# 370          UEL  18-19   Europa League Final Stage  2019-02-21
# 371          UEL  18-19   Europa League Final Stage  2019-02-21
# 372          UEL  18-19   Europa League Final Stage  2019-02-21
# 373          UEL  18-19   Europa League Final Stage  2019-02-21
# 374          UEL  18-19   Europa League Final Stage  2019-02-21
# 375          UEL  18-19   Europa League Final Stage  2019-02-21
# 376          UEL  18-19   Europa League Final Stage  2019-02-21
# 377          UEL  18-19   Europa League Final Stage  2019-02-21
# 378          UEL  18-19   Europa League Final Stage  2019-02-21
# 379          UEL  18-19   Europa League Final Stage  2019-02-21
# 380          UEL  18-19   Europa League Final Stage  2019-02-21
# 381          UEL  18-19   Europa League Final Stage  2019-03-07
# 382          UEL  18-19   Europa League Final Stage  2019-03-07
# 383          UEL  18-19   Europa League Final Stage  2019-03-07
# 384          UEL  18-19   Europa League Final Stage  2019-03-07
# 385          UEL  18-19   Europa League Final Stage  2019-03-07
# 386          UEL  18-19   Europa League Final Stage  2019-03-07
# 387          UEL  18-19   Europa League Final Stage  2019-03-07
# 388          UEL  18-19   Europa League Final Stage  2019-03-07
# 389          UEL  18-19   Europa League Final Stage  2019-03-14
# 390          UEL  18-19   Europa League Final Stage  2019-03-14
# 391          UEL  18-19   Europa League Final Stage  2019-03-14
# 392          UEL  18-19   Europa League Final Stage  2019-03-14
# 393          UEL  18-19   Europa League Final Stage  2019-03-14
# 394          UEL  18-19   Europa League Final Stage  2019-03-14
# 395          UEL  18-19   Europa League Final Stage  2019-03-14
# 396          UEL  18-19   Europa League Final Stage  2019-03-14
# 397          UEL  18-19   Europa League Final Stage  2019-04-11
# 398          UEL  18-19   Europa League Final Stage  2019-04-11
# 399          UEL  18-19   Europa League Final Stage  2019-04-11
# 400          UEL  18-19   Europa League Final Stage  2019-04-11
# 401          UEL  18-19   Europa League Final Stage  2019-04-18
# 402          UEL  18-19   Europa League Final Stage  2019-04-18
# 403          UEL  18-19   Europa League Final Stage  2019-04-18
# 404          UEL  18-19   Europa League Final Stage  2019-04-18
# 405          UEL  18-19   Europa League Final Stage  2019-05-02
# 406          UEL  18-19   Europa League Final Stage  2019-05-02
# 407          UEL  18-19   Europa League Final Stage  2019-05-09
# 408          UEL  18-19   Europa League Final Stage  2019-05-09
# 409          UEL  18-19   Europa League Final Stage  2019-05-29
# 410          UEL  19-20  Europa League Group Stages  2019-09-19
# 411          UEL  19-20  Europa League Group Stages  2019-09-19
# 412          UEL  19-20  Europa League Group Stages  2019-09-19
# 413          UEL  19-20  Europa League Group Stages  2019-09-19
# 414          UEL  19-20  Europa League Group Stages  2019-09-19
# 415          UEL  19-20  Europa League Group Stages  2019-09-19
# 416          UEL  19-20  Europa League Group Stages  2019-09-19
# 417          UEL  19-20  Europa League Group Stages  2019-09-19
# 418          UEL  19-20  Europa League Group Stages  2019-09-19
# 419          UEL  19-20  Europa League Group Stages  2019-09-19
# 420          UEL  19-20  Europa League Group Stages  2019-09-19
# 421          UEL  19-20  Europa League Group Stages  2019-09-19
# 422          UEL  19-20  Europa League Group Stages  2019-09-19
# 423          UEL  19-20  Europa League Group Stages  2019-09-19
# 424          UEL  19-20  Europa League Group Stages  2019-09-19
# 425          UEL  19-20  Europa League Group Stages  2019-09-19
# 426          UEL  19-20  Europa League Group Stages  2019-09-19
# 427          UEL  19-20  Europa League Group Stages  2019-09-19
# 428          UEL  19-20  Europa League Group Stages  2019-09-19
# 429          UEL  19-20  Europa League Group Stages  2019-09-19
# 430          UEL  19-20  Europa League Group Stages  2019-09-19
# 431          UEL  19-20  Europa League Group Stages  2019-09-19
# 432          UEL  19-20  Europa League Group Stages  2019-09-19
# 433          UEL  19-20  Europa League Group Stages  2019-09-19
# 434          UEL  19-20  Europa League Group Stages  2019-10-03
# 435          UEL  19-20  Europa League Group Stages  2019-10-03
# 436          UEL  19-20  Europa League Group Stages  2019-10-03
# 437          UEL  19-20  Europa League Group Stages  2019-10-03
# 438          UEL  19-20  Europa League Group Stages  2019-10-03
# 439          UEL  19-20  Europa League Group Stages  2019-10-03
# 440          UEL  19-20  Europa League Group Stages  2019-10-03
# 441          UEL  19-20  Europa League Group Stages  2019-10-03
# 442          UEL  19-20  Europa League Group Stages  2019-10-03
# 443          UEL  19-20  Europa League Group Stages  2019-10-03
# 444          UEL  19-20  Europa League Group Stages  2019-10-03
# 445          UEL  19-20  Europa League Group Stages  2019-10-03
# 446          UEL  19-20  Europa League Group Stages  2019-10-03
# 447          UEL  19-20  Europa League Group Stages  2019-10-03
# 448          UEL  19-20  Europa League Group Stages  2019-10-03
# 449          UEL  19-20  Europa League Group Stages  2019-10-03
# 450          UEL  19-20  Europa League Group Stages  2019-10-03
# 451          UEL  19-20  Europa League Group Stages  2019-10-03
# 452          UEL  19-20  Europa League Group Stages  2019-10-03
# 453          UEL  19-20  Europa League Group Stages  2019-10-03
# 454          UEL  19-20  Europa League Group Stages  2019-10-03
# 455          UEL  19-20  Europa League Group Stages  2019-10-03
# 456          UEL  19-20  Europa League Group Stages  2019-10-03
# 457          UEL  19-20  Europa League Group Stages  2019-10-03
# 458          UEL  19-20  Europa League Group Stages  2019-10-24
# 459          UEL  19-20  Europa League Group Stages  2019-10-24
# 460          UEL  19-20  Europa League Group Stages  2019-10-24
# 461          UEL  19-20  Europa League Group Stages  2019-10-24
# 462          UEL  19-20  Europa League Group Stages  2019-10-24
# 463          UEL  19-20  Europa League Group Stages  2019-10-24
# 464          UEL  19-20  Europa League Group Stages  2019-10-24
# 465          UEL  19-20  Europa League Group Stages  2019-10-24
# 466          UEL  19-20  Europa League Group Stages  2019-10-24
# 467          UEL  19-20  Europa League Group Stages  2019-10-24
# 468          UEL  19-20  Europa League Group Stages  2019-10-24
# 469          UEL  19-20  Europa League Group Stages  2019-10-24
# 470          UEL  19-20  Europa League Group Stages  2019-10-24
# 471          UEL  19-20  Europa League Group Stages  2019-10-24
# 472          UEL  19-20  Europa League Group Stages  2019-10-24
# 473          UEL  19-20  Europa League Group Stages  2019-10-24
# 474          UEL  19-20  Europa League Group Stages  2019-10-24
# 475          UEL  19-20  Europa League Group Stages  2019-10-24
# 476          UEL  19-20  Europa League Group Stages  2019-10-24
# 477          UEL  19-20  Europa League Group Stages  2019-10-24
# 478          UEL  19-20  Europa League Group Stages  2019-10-24
# 479          UEL  19-20  Europa League Group Stages  2019-10-24
# 480          UEL  19-20  Europa League Group Stages  2019-10-24
# 481          UEL  19-20  Europa League Group Stages  2019-10-24
# 482          UEL  19-20  Europa League Group Stages  2019-11-06
# 483          UEL  19-20  Europa League Group Stages  2019-11-07
# 484          UEL  19-20  Europa League Group Stages  2019-11-07
# 485          UEL  19-20  Europa League Group Stages  2019-11-07
# 486          UEL  19-20  Europa League Group Stages  2019-11-07
# 487          UEL  19-20  Europa League Group Stages  2019-11-07
# 488          UEL  19-20  Europa League Group Stages  2019-11-07
# 489          UEL  19-20  Europa League Group Stages  2019-11-07
# 490          UEL  19-20  Europa League Group Stages  2019-11-07
# 491          UEL  19-20  Europa League Group Stages  2019-11-07
# 492          UEL  19-20  Europa League Group Stages  2019-11-07
# 493          UEL  19-20  Europa League Group Stages  2019-11-07
# 494          UEL  19-20  Europa League Group Stages  2019-11-07
# 495          UEL  19-20  Europa League Group Stages  2019-11-07
# 496          UEL  19-20  Europa League Group Stages  2019-11-07
# 497          UEL  19-20  Europa League Group Stages  2019-11-07
# 498          UEL  19-20  Europa League Group Stages  2019-11-07
# 499          UEL  19-20  Europa League Group Stages  2019-11-07
# 500          UEL  19-20  Europa League Group Stages  2019-11-07
# 501          UEL  19-20  Europa League Group Stages  2019-11-07
# 502          UEL  19-20  Europa League Group Stages  2019-11-07
# 503          UEL  19-20  Europa League Group Stages  2019-11-07
# 504          UEL  19-20  Europa League Group Stages  2019-11-07
# 505          UEL  19-20  Europa League Group Stages  2019-11-07
# 506          UEL  19-20  Europa League Group Stages  2019-11-28
# 507          UEL  19-20  Europa League Group Stages  2019-11-28
# 508          UEL  19-20  Europa League Group Stages  2019-11-28
# 509          UEL  19-20  Europa League Group Stages  2019-11-28
# 510          UEL  19-20  Europa League Group Stages  2019-11-28
# 511          UEL  19-20  Europa League Group Stages  2019-11-28
# 512          UEL  19-20  Europa League Group Stages  2019-11-28
# 513          UEL  19-20  Europa League Group Stages  2019-11-28
# 514          UEL  19-20  Europa League Group Stages  2019-11-28
# 515          UEL  19-20  Europa League Group Stages  2019-11-28
# 516          UEL  19-20  Europa League Group Stages  2019-11-28
# 517          UEL  19-20  Europa League Group Stages  2019-11-28
# 518          UEL  19-20  Europa League Group Stages  2019-11-28
# 519          UEL  19-20  Europa League Group Stages  2019-11-28
# 520          UEL  19-20  Europa League Group Stages  2019-11-28
# 521          UEL  19-20  Europa League Group Stages  2019-11-28
# 522          UEL  19-20  Europa League Group Stages  2019-11-28
# 523          UEL  19-20  Europa League Group Stages  2019-11-28
# 524          UEL  19-20  Europa League Group Stages  2019-11-28
# 525          UEL  19-20  Europa League Group Stages  2019-11-28
# 526          UEL  19-20  Europa League Group Stages  2019-11-28
# 527          UEL  19-20  Europa League Group Stages  2019-11-28
# 528          UEL  19-20  Europa League Group Stages  2019-11-28
# 529          UEL  19-20  Europa League Group Stages  2019-11-28
# 530          UEL  19-20  Europa League Group Stages  2019-12-12
# 531          UEL  19-20  Europa League Group Stages  2019-12-12
# 532          UEL  19-20  Europa League Group Stages  2019-12-12
# 533          UEL  19-20  Europa League Group Stages  2019-12-12
# 534          UEL  19-20  Europa League Group Stages  2019-12-12
# 535          UEL  19-20  Europa League Group Stages  2019-12-12
# 536          UEL  19-20  Europa League Group Stages  2019-12-12
# 537          UEL  19-20  Europa League Group Stages  2019-12-12
# 538          UEL  19-20  Europa League Group Stages  2019-12-12
# 539          UEL  19-20  Europa League Group Stages  2019-12-12
# 540          UEL  19-20  Europa League Group Stages  2019-12-12
# 541          UEL  19-20  Europa League Group Stages  2019-12-12
# 542          UEL  19-20  Europa League Group Stages  2019-12-12
# 543          UEL  19-20  Europa League Group Stages  2019-12-12
# 544          UEL  19-20  Europa League Group Stages  2019-12-12
# 545          UEL  19-20  Europa League Group Stages  2019-12-12
# 546          UEL  19-20  Europa League Group Stages  2019-12-12
# 547          UEL  19-20  Europa League Group Stages  2019-12-12
# 548          UEL  19-20  Europa League Group Stages  2019-12-12
# 549          UEL  19-20  Europa League Group Stages  2019-12-12
# 550          UEL  19-20  Europa League Group Stages  2019-12-12
# 551          UEL  19-20  Europa League Group Stages  2019-12-12
# 552          UEL  19-20  Europa League Group Stages  2019-12-12
# 553          UEL  19-20  Europa League Group Stages  2019-12-12
# 554          UEL  19-20   Europa League Final Stage  2020-02-20
# 555          UEL  19-20   Europa League Final Stage  2020-02-20
# 556          UEL  19-20   Europa League Final Stage  2020-02-20
# 557          UEL  19-20   Europa League Final Stage  2020-02-20
# 558          UEL  19-20   Europa League Final Stage  2020-02-20
# 559          UEL  19-20   Europa League Final Stage  2020-02-20
# 560          UEL  19-20   Europa League Final Stage  2020-02-20
# 561          UEL  19-20   Europa League Final Stage  2020-02-20
# 562          UEL  19-20   Europa League Final Stage  2020-02-20
# 563          UEL  19-20   Europa League Final Stage  2020-02-20
# 564          UEL  19-20   Europa League Final Stage  2020-02-20
# 565          UEL  19-20   Europa League Final Stage  2020-02-20
# 566          UEL  19-20   Europa League Final Stage  2020-02-20
# 567          UEL  19-20   Europa League Final Stage  2020-02-20
# 568          UEL  19-20   Europa League Final Stage  2020-02-20
# 569          UEL  19-20   Europa League Final Stage  2020-02-20
# 570          UEL  19-20   Europa League Final Stage  2020-02-26
# 571          UEL  19-20   Europa League Final Stage  2020-02-27
# 572          UEL  19-20   Europa League Final Stage  2020-02-27
# 573          UEL  19-20   Europa League Final Stage  2020-02-27
# 574          UEL  19-20   Europa League Final Stage  2020-02-27
# 575          UEL  19-20   Europa League Final Stage  2020-02-27
# 576          UEL  19-20   Europa League Final Stage  2020-02-27
# 577          UEL  19-20   Europa League Final Stage  2020-02-27
# 578          UEL  19-20   Europa League Final Stage  2020-02-27
# 579          UEL  19-20   Europa League Final Stage  2020-02-27
# 580          UEL  19-20   Europa League Final Stage  2020-02-27
# 581          UEL  19-20   Europa League Final Stage  2020-02-27
# 582          UEL  19-20   Europa League Final Stage  2020-02-27
# 583          UEL  19-20   Europa League Final Stage  2020-02-27
# 584          UEL  19-20   Europa League Final Stage  2020-02-27
# 585          UEL  19-20   Europa League Final Stage  2020-02-28
# 586          UEL  19-20   Europa League Final Stage  2020-03-12
# 587          UEL  19-20   Europa League Final Stage  2020-03-12
# 588          UEL  19-20   Europa League Final Stage  2020-03-12
# 589          UEL  19-20   Europa League Final Stage  2020-03-12
# 590          UEL  19-20   Europa League Final Stage  2020-03-12
# 591          UEL  19-20   Europa League Final Stage  2020-03-12
# 592          UEL  19-20   Europa League Final Stage  2020-08-05
# 593          UEL  19-20   Europa League Final Stage  2020-08-05
# 594          UEL  19-20   Europa League Final Stage  2020-08-05
# 595          UEL  19-20   Europa League Final Stage  2020-08-05
# 596          UEL  19-20   Europa League Final Stage  2020-08-06
# 597          UEL  19-20   Europa League Final Stage  2020-08-06
# 598          UEL  19-20   Europa League Final Stage  2020-08-06
# 599          UEL  19-20   Europa League Final Stage  2020-08-06
# 600          UEL  19-20   Europa League Final Stage  2020-08-10
# 601          UEL  19-20   Europa League Final Stage  2020-08-10
# 602          UEL  19-20   Europa League Final Stage  2020-08-11
# 603          UEL  19-20   Europa League Final Stage  2020-08-11
# 604          UEL  19-20   Europa League Final Stage  2020-08-16
# 605          UEL  19-20   Europa League Final Stage  2020-08-17
# 606          UEL  19-20   Europa League Final Stage  2020-08-21
# 607          UEL  20-21  Europa League Group Stages  2020-10-22
# 608          UEL  20-21  Europa League Group Stages  2020-10-22
# 609          UEL  20-21  Europa League Group Stages  2020-10-22
# 610          UEL  20-21  Europa League Group Stages  2020-10-22
# 611          UEL  20-21  Europa League Group Stages  2020-10-22
# 612          UEL  20-21  Europa League Group Stages  2020-10-22
# 613          UEL  20-21  Europa League Group Stages  2020-10-22
# 614          UEL  20-21  Europa League Group Stages  2020-10-22
# 615          UEL  20-21  Europa League Group Stages  2020-10-22
# 616          UEL  20-21  Europa League Group Stages  2020-10-22
# 617          UEL  20-21  Europa League Group Stages  2020-10-22
# 618          UEL  20-21  Europa League Group Stages  2020-10-22
# 619          UEL  20-21  Europa League Group Stages  2020-10-22
# 620          UEL  20-21  Europa League Group Stages  2020-10-22
# 621          UEL  20-21  Europa League Group Stages  2020-10-22
# 622          UEL  20-21  Europa League Group Stages  2020-10-22
# 623          UEL  20-21  Europa League Group Stages  2020-10-22
# 624          UEL  20-21  Europa League Group Stages  2020-10-22
# 625          UEL  20-21  Europa League Group Stages  2020-10-22
# 626          UEL  20-21  Europa League Group Stages  2020-10-22
# 627          UEL  20-21  Europa League Group Stages  2020-10-22
# 628          UEL  20-21  Europa League Group Stages  2020-10-22
# 629          UEL  20-21  Europa League Group Stages  2020-10-22
# 630          UEL  20-21  Europa League Group Stages  2020-10-22
# 631          UEL  20-21  Europa League Group Stages  2020-10-29
# 632          UEL  20-21  Europa League Group Stages  2020-10-29
# 633          UEL  20-21  Europa League Group Stages  2020-10-29
# 634          UEL  20-21  Europa League Group Stages  2020-10-29
# 635          UEL  20-21  Europa League Group Stages  2020-10-29
# 636          UEL  20-21  Europa League Group Stages  2020-10-29
# 637          UEL  20-21  Europa League Group Stages  2020-10-29
# 638          UEL  20-21  Europa League Group Stages  2020-10-29
# 639          UEL  20-21  Europa League Group Stages  2020-10-29
# 640          UEL  20-21  Europa League Group Stages  2020-10-29
# 641          UEL  20-21  Europa League Group Stages  2020-10-29
# 642          UEL  20-21  Europa League Group Stages  2020-10-29
# 643          UEL  20-21  Europa League Group Stages  2020-10-29
# 644          UEL  20-21  Europa League Group Stages  2020-10-29
# 645          UEL  20-21  Europa League Group Stages  2020-10-29
# 646          UEL  20-21  Europa League Group Stages  2020-10-29
# 647          UEL  20-21  Europa League Group Stages  2020-10-29
# 648          UEL  20-21  Europa League Group Stages  2020-10-29
# 649          UEL  20-21  Europa League Group Stages  2020-10-29
# 650          UEL  20-21  Europa League Group Stages  2020-10-29
# 651          UEL  20-21  Europa League Group Stages  2020-10-29
# 652          UEL  20-21  Europa League Group Stages  2020-10-29
# 653          UEL  20-21  Europa League Group Stages  2020-10-29
# 654          UEL  20-21  Europa League Group Stages  2020-10-29
# 655          UEL  20-21  Europa League Group Stages  2020-11-05
# 656          UEL  20-21  Europa League Group Stages  2020-11-05
# 657          UEL  20-21  Europa League Group Stages  2020-11-05
# 658          UEL  20-21  Europa League Group Stages  2020-11-05
# 659          UEL  20-21  Europa League Group Stages  2020-11-05
# 660          UEL  20-21  Europa League Group Stages  2020-11-05
# 661          UEL  20-21  Europa League Group Stages  2020-11-05
# 662          UEL  20-21  Europa League Group Stages  2020-11-05
# 663          UEL  20-21  Europa League Group Stages  2020-11-05
# 664          UEL  20-21  Europa League Group Stages  2020-11-05
# 665          UEL  20-21  Europa League Group Stages  2020-11-05
# 666          UEL  20-21  Europa League Group Stages  2020-11-05
# 667          UEL  20-21  Europa League Group Stages  2020-11-05
# 668          UEL  20-21  Europa League Group Stages  2020-11-05
# 669          UEL  20-21  Europa League Group Stages  2020-11-05
# 670          UEL  20-21  Europa League Group Stages  2020-11-05
# 671          UEL  20-21  Europa League Group Stages  2020-11-05
# 672          UEL  20-21  Europa League Group Stages  2020-11-05
# 673          UEL  20-21  Europa League Group Stages  2020-11-05
# 674          UEL  20-21  Europa League Group Stages  2020-11-05
# 675          UEL  20-21  Europa League Group Stages  2020-11-05
# ...
# 1022                     /matches/union-stgilloise-vs-malmo-ff/2qs14m#4010670
# 1023                         /matches/psv-eindhoven-vs-arsenal/2ticgi#4010263
# 1024                            /matches/union-berlin-vs-braga/2sxrb4#4010669
# 1025                  /matches/fk-crvena-zvezda-vs-trabzonspor/2t827o#4010657
# 1026                            /matches/ferencvaros-vs-monaco/2p0bvv#4010658
# 1027                        /matches/sc-freiburg-vs-olympiacos/2e01o8#4010552
# 1028                                      /matches/roma-vs-hjk/2uevf7#4010540
# 1029                  /matches/fc-sheriff-vs-manchester-united/3ayei0#4010313
# 1030                             /matches/qarabag-fk-vs-nantes/2mg38k#4010553
# 1031                  /matches/omonia-nicosia-vs-real-sociedad/2a2vza#4010314
# 1032                          /matches/sturm-graz-vs-feyenoord/3e2j7k#4010383
# 1033                        /matches/midtjylland-vs-sturm-graz/2ptrd5#4010384
# 1034                     /matches/omonia-nicosia-vs-fc-sheriff/2m1lgs#4010316
# 1035                               /matches/lazio-vs-feyenoord/2wz8wu#4010385
# 1036                       /matches/fk-crvena-zvezda-vs-monaco/2u2k47#4010659
# 1037                             /matches/olympiacos-vs-nantes/2tjj7k#4010555
# 1038                        /matches/qarabag-fk-vs-sc-freiburg/27hbpg#4010554
# 1039               /matches/real-sociedad-vs-manchester-united/2xg662#4010315
# 1040                       /matches/ferencvaros-vs-trabzonspor/2o6llx#4010660
# 1041                            /matches/arsenal-vs-fc-zuerich/3bwbh7#4010264
# 1042                       /matches/bodoglimt-vs-psv-eindhoven/2egtrf#4010265
# 1043                                /matches/malmo-ff-vs-braga/3h4l4v#4010672
# 1044                        /matches/dynamo-kyiv-vs-fenerbahce/2hymub#4010303
# 1045                                /matches/real-betis-vs-hjk/2thy8l#4010542
# 1046                            /matches/aek-larnaca-vs-rennes/2kq5bn#4010304
# 1047                      /matches/roma-vs-ludogorets-razgrad/b0328n4#4010543
# 1048                 /matches/union-stgilloise-vs-union-berlin/25fk2d#4010671
# 1049                             /matches/union-berlin-vs-ajax/2bg7fa#4060620
# 1050                   /matches/barcelona-vs-manchester-united/2ya2yr#4060616
# 1051                                 /matches/roma-vs-salzburg/2w3ir4#4060623
# 1052                       /matches/shakhtar-donetsk-vs-rennes/364jlx#4060619
# 1053                       /matches/bayer-leverkusen-vs-monaco/2ojbrt#4060621
# 1054                               /matches/nantes-vs-juventus/37pter#4060617
# 1055                         /matches/sevilla-vs-psv-eindhoven/2dgem1#4060622
# 1056                       /matches/midtjylland-vs-sporting-cp/2n6v4d#4060618
# 1057                       /matches/midtjylland-vs-sporting-cp/2n6v4d#4060626
# 1058                       /matches/bayer-leverkusen-vs-monaco/2ojbrt#4060629
# 1059                               /matches/nantes-vs-juventus/37pter#4060625
# 1060                         /matches/sevilla-vs-psv-eindhoven/2dgem1#4060630
# 1061                   /matches/barcelona-vs-manchester-united/2ya2yr#4060624
# 1062                       /matches/shakhtar-donetsk-vs-rennes/364jlx#4060627
# 1063                                 /matches/roma-vs-salzburg/2w3ir4#4060631
# 1064                             /matches/union-berlin-vs-ajax/2bg7fa#4060628
# 1065                  /matches/bayer-leverkusen-vs-ferencvaros/282q3q#4128629
# 1066                            /matches/real-sociedad-vs-roma/2gjsgv#4128632
# 1067                           /matches/sporting-cp-vs-arsenal/36af66#4128630
# 1068                 /matches/union-stgilloise-vs-union-berlin/25fk2d#4010662
# 1069                          /matches/sc-freiburg-vs-juventus/2r30g3#4128628
# 1070                  /matches/real-betis-vs-manchester-united/2xxjcz#4128631
# 1071                            /matches/sevilla-vs-fenerbahce/2e0ety#4128627
# 1072                    /matches/shakhtar-donetsk-vs-feyenoord/3an9qi#4128633
# 1073                            /matches/sevilla-vs-fenerbahce/2e0ety#4128635
# 1074                    /matches/shakhtar-donetsk-vs-feyenoord/3an9qi#4128641
# 1075                          /matches/sc-freiburg-vs-juventus/2r30g3#4128636
# 1076                  /matches/real-betis-vs-manchester-united/2xxjcz#4128639
# 1077                           /matches/sporting-cp-vs-arsenal/36af66#4128638
# 1078                  /matches/bayer-leverkusen-vs-ferencvaros/282q3q#4128637
# 1079                            /matches/real-sociedad-vs-roma/2gjsgv#4128640
# 1080                 /matches/union-stgilloise-vs-union-berlin/25fk2d#4010671
# 1081                                /matches/roma-vs-feyenoord/2yl0x7#4140619
# 1082             /matches/union-stgilloise-vs-bayer-leverkusen/25plag#4140617
# 1083                          /matches/sporting-cp-vs-juventus/36znpo#4140615
# 1084                     /matches/sevilla-vs-manchester-united/2uksz5#4140613
# 1085                                /matches/roma-vs-feyenoord/2yl0x7#4140620
# 1086                     /matches/sevilla-vs-manchester-united/2uksz5#4140614
# 1087                          /matches/sporting-cp-vs-juventus/36znpo#4140616
# 1088             /matches/union-stgilloise-vs-bayer-leverkusen/25plag#4140618
# 1089                              /matches/sevilla-vs-juventus/2qh5cv#4140621
# 1090                         /matches/bayer-leverkusen-vs-roma/2co5b2#4140623
# 1091                         /matches/bayer-leverkusen-vs-roma/2co5b2#4140624
# 1092                              /matches/sevilla-vs-juventus/2qh5cv#4140622
# 1093                                  /matches/sevilla-vs-roma/2dx4tg#4140625
# 1094                       /matches/bayer-leverkusen-vs-hacken/2a3li5#4315153
# 1095                               /matches/roma-vs-fc-sheriff/2syky1#4315105
# 1096                                /matches/liverpool-vs-lask/2vaqvz#4315081
# 1097                      /matches/panathinaikos-vs-villarreal/3fyi0k#4315142
# 1098                              /matches/qarabag-fk-vs-molde/2nddwk#4315154
# 1099                          /matches/rennes-vs-maccabi-haifa/3bikdh#4315141
# 1100                        /matches/slavia-prague-vs-servette/2jug3r#4315106
# 1101                     /matches/union-stgilloise-vs-toulouse/2nlg45#4315082
# 1102                                /matches/marseille-vs-ajax/2fxa2q#4315093
# 1103                    /matches/rakow-czestochowa-vs-atalanta/1avowm#4315117
# 1104               /matches/aek-athens-vs-brighton-hove-albion/2wutl7#4315094
# 1105                        /matches/sc-freiburg-vs-olympiacos/2e01o8#4315070
# 1106                            /matches/rangers-vs-real-betis/2fkrob#4315130
# 1107                   /matches/aris-limassol-vs-sparta-prague/19ngvc#4315129
# 1108                        /matches/sporting-cp-vs-sturm-graz/38i6al#4315118
# 1109            /matches/west-ham-united-vs-tsc-backa-topola/2zpqflnh#4315069
# 1110                               /matches/aek-athens-vs-ajax/2fmluj#4315096
# 1111                          /matches/aris-limassol-vs-rangers/xzl8q#4315132
# 1112                   /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315071
# 1113                /matches/marseille-vs-brighton-hove-albion/2x6hvy#4315095
# 1114                  /matches/rakow-czestochowa-vs-sturm-graz/1mo4ut#4315120
# 1115                      /matches/real-betis-vs-sparta-prague/2xsa7i#4315131
# 1116                          /matches/atalanta-vs-sporting-cp/2rm71m#4315119
# 1117                 /matches/olympiacos-vs-tsc-backa-topola/2zpjwrhh#4315072
# 1118                             /matches/qarabag-fk-vs-hacken/285w6p#4315156
# 1119                    /matches/union-stgilloise-vs-liverpool/2abfrg#4315083
# 1120                   /matches/maccabi-haifa-vs-panathinaikos/3fpr9l#4315144
# 1121                        /matches/bayer-leverkusen-vs-molde/2phdk5#4315155
# 1122                                 /matches/roma-vs-servette/2thjxd#4315107
# 1123                      /matches/slavia-prague-vs-fc-sheriff/2jcef3#4315108
# 1124                                 /matches/toulouse-vs-lask/3a41j6#4315084
# 1125                             /matches/rennes-vs-villarreal/3br5qf#4315143
# 1126                       /matches/aris-limassol-vs-real-betis/yc7vt#4315134
# 1127                          /matches/aek-athens-vs-marseille/2fm8ly#4315097
# 1128                                  /matches/hacken-vs-molde/2s70be#4315157
# 1129                    /matches/olympiacos-vs-west-ham-united/2h0tek#4315073
# 1130                 /matches/rakow-czestochowa-vs-sporting-cp/1kmvx4#4315121
# 1131                         /matches/rangers-vs-sparta-prague/2x63cm#4315133
# 1132                           /matches/atalanta-vs-sturm-graz/2ub9mb#4315122
# 1133                /matches/sc-freiburg-vs-tsc-backa-topola/2zmdrzjl#4315074
# 1134                   /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315158
# 1135                     /matches/ajax-vs-brighton-hove-albion/2x6we4#4315098
# 1136                           /matches/fc-sheriff-vs-servette/359yr0#4315110
# 1137                            /matches/liverpool-vs-toulouse/2uwdxh#4315086
# 1138                          /matches/rennes-vs-panathinaikos/3bp0d5#4315145
# 1139                            /matches/slavia-prague-vs-roma/28sgb7#4315109
# 1140                         /matches/union-stgilloise-vs-lask/2nzaen#4315085
# 1141                     /matches/ajax-vs-brighton-hove-albion/2x6we4#4315099
# 1142                         /matches/union-stgilloise-vs-lask/2nzaen#4315087
# 1143                      /matches/maccabi-haifa-vs-villarreal/3frxxe#4315148
# 1144                   /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315159
# 1145                          /matches/rennes-vs-panathinaikos/3bp0d5#4315147
# 1146                           /matches/fc-sheriff-vs-servette/359yr0#4315111
# 1147                            /matches/slavia-prague-vs-roma/28sgb7#4315112
# 1148                            /matches/liverpool-vs-toulouse/2uwdxh#4315088
# 1149                          /matches/aek-athens-vs-marseille/2fm8ly#4315100
# 1150                           /matches/atalanta-vs-sturm-graz/2ub9mb#4315123
# 1151                /matches/sc-freiburg-vs-tsc-backa-topola/2zmdrzjl#4315075
# 1152                                  /matches/hacken-vs-molde/2s70be#4315160
# 1153                         /matches/rangers-vs-sparta-prague/2x63cm#4315136
# 1154                       /matches/aris-limassol-vs-real-betis/yc7vt#4315135
# 1155                 /matches/rakow-czestochowa-vs-sporting-cp/1kmvx4#4315124
# 1156                    /matches/olympiacos-vs-west-ham-united/2h0tek#4315076
# 1157               /matches/aek-athens-vs-brighton-hove-albion/2wutl7#4315101
# 1158                          /matches/atalanta-vs-sporting-cp/2rm71m#4315125
# 1159                        /matches/sc-freiburg-vs-olympiacos/2e01o8#4315077
# 1160                          /matches/rennes-vs-maccabi-haifa/3bikdh#4315149
# 1161                      /matches/real-betis-vs-sparta-prague/2xsa7i#4315137
# 1162                  /matches/rakow-czestochowa-vs-sturm-graz/1mo4ut#4315126
# 1163            /matches/west-ham-united-vs-tsc-backa-topola/2zpqflnh#4315078
# 1164                      /matches/slavia-prague-vs-fc-sheriff/2jcef3#4315114
# 1165                       /matches/bayer-leverkusen-vs-hacken/2a3li5#4315162
# 1166                                /matches/liverpool-vs-lask/2vaqvz#4315090
# 1167                                /matches/marseille-vs-ajax/2fxa2q#4315102
# 1168                              /matches/qarabag-fk-vs-molde/2nddwk#4315161
# 1169                          /matches/aris-limassol-vs-rangers/xzl8q#4315138
# 1170                                 /matches/roma-vs-servette/2thjxd#4315113
# 1171                     /matches/union-stgilloise-vs-toulouse/2nlg45#4315089
# 1172                      /matches/panathinaikos-vs-villarreal/3fyi0k#4315150
# 1173                      /matches/maccabi-haifa-vs-villarreal/3frxxe#4315146
# 1174                        /matches/bayer-leverkusen-vs-molde/2phdk5#4315163
# 1175                                 /matches/toulouse-vs-lask/3a41j6#4315092
# 1176                   /matches/maccabi-haifa-vs-panathinaikos/3fpr9l#4315152
# 1177                             /matches/qarabag-fk-vs-hacken/285w6p#4315164
# 1178                             /matches/rennes-vs-villarreal/3br5qf#4315151
# 1179                               /matches/roma-vs-fc-sheriff/2syky1#4315115
# 1180                        /matches/slavia-prague-vs-servette/2jug3r#4315116
# 1181                    /matches/union-stgilloise-vs-liverpool/2abfrg#4315091
# 1182                               /matches/aek-athens-vs-ajax/2fmluj#4315103
# 1183                   /matches/aris-limassol-vs-sparta-prague/19ngvc#4315140
# 1184                /matches/marseille-vs-brighton-hove-albion/2x6hvy#4315104
# 1185                 /matches/olympiacos-vs-tsc-backa-topola/2zpjwrhh#4315080
# 1186                    /matches/rakow-czestochowa-vs-atalanta/1avowm#4315128
# 1187                            /matches/rangers-vs-real-betis/2fkrob#4315139
# 1188                        /matches/sporting-cp-vs-sturm-graz/38i6al#4315127
# 1189                   /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315079
# 1190                        /matches/sporting-cp-vs-young-boys/3alzk4#4384257
# 1191                                /matches/roma-vs-feyenoord/2yl0x7#4384251
# 1192                     /matches/galatasaray-vs-sparta-prague/2y617r#4384263
# 1193                    /matches/marseille-vs-shakhtar-donetsk/2rx6iw#4384265
# 1194                               /matches/ac-milan-vs-rennes/2syl1f#4384253
# 1195                              /matches/benfica-vs-toulouse/37oz12#4384259
# 1196                              /matches/qarabag-fk-vs-braga/2r3r4s#4384261
# 1197                              /matches/sc-freiburg-vs-lens/2dhuvb#4384255
# 1198                              /matches/sc-freiburg-vs-lens/2dhuvb#4384256
# 1199                              /matches/qarabag-fk-vs-braga/2r3r4s#4384262
# 1200                               /matches/ac-milan-vs-rennes/2syl1f#4384254
# 1201                              /matches/benfica-vs-toulouse/37oz12#4384260
# 1202                    /matches/marseille-vs-shakhtar-donetsk/2rx6iw#4384266
# 1203                                /matches/roma-vs-feyenoord/2yl0x7#4384252
# 1204                     /matches/galatasaray-vs-sparta-prague/2y617r#4384264
# 1205                        /matches/sporting-cp-vs-young-boys/3alzk4#4384258
# 1206                          /matches/atalanta-vs-sporting-cp/2rm71m#4315119
# 1207                   /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315159
# 1208                     /matches/roma-vs-brighton-hove-albion/2y8gp1#4430800
# 1209                       /matches/liverpool-vs-sparta-prague/2ybapv#4430795
# 1210                        /matches/slavia-prague-vs-ac-milan/27lj7o#4430810
# 1211                               /matches/rangers-vs-benfica/2rx6k4#4430803
# 1212                   /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315071
# 1213                          /matches/marseille-vs-villarreal/2x6we3#4430798
# 1214                               /matches/rangers-vs-benfica/2rx6k4#4430804
# 1215                        /matches/slavia-prague-vs-ac-milan/27lj7o#4430812
# 1216                          /matches/marseille-vs-villarreal/2x6we3#4430799
# 1217                   /matches/sc-freiburg-vs-west-ham-united/2e5vm8#4315079
# 1218                          /matches/atalanta-vs-sporting-cp/2rm71m#4315125
# 1219                   /matches/qarabag-fk-vs-bayer-leverkusen/25qmoy#4315158
# 1220                     /matches/roma-vs-brighton-hove-albion/2y8gp1#4430802
# 1221                       /matches/liverpool-vs-sparta-prague/2ybapv#4430797

# %%
w.to_csv("w.csv")

# %%
w = WS[WS['season'] == '19-20']
b = FB[FB['season'] == '19-20']
m = FM[FM['season'] == '19-20']

# %%
m[(m['home_team'] == 'Getafe' ) | ( m['away_team'] == 'Getafe' )]
# Out:
#       index       id league season  \
# 1314   1314  3171246    UEL  19-20
# 1347   1347  3171231    UEL  19-20
# 1373   1373  3171247    UEL  19-20
# 1383   1383  3171249    UEL  19-20
# 1406   1406  3171266    UEL  19-20
# 1434   1434  3171251    UEL  19-20
# 1455   1455  3236273    UEL  19-20
# 1476   1476  3236274    UEL  19-20
# 1488   1488  3284791    UEL  19-20
# 1494   1494  3284799    UEL  19-20
#
#                                                   url    home_team  \
# 1314    /matches/getafe-vs-trabzonspor/2p2net#3171246       Getafe
# 1347  /matches/getafe-vs-fc-krasnodar/774tq9d#3171231    Krasnodar
# 1373          /matches/getafe-vs-basel/2r09yp#3171247       Getafe
# 1383          /matches/getafe-vs-basel/2r09yp#3171249        Basel
# 1406    /matches/getafe-vs-trabzonspor/2p2net#3171266  Trabzonspor
# 1434  /matches/getafe-vs-fc-krasnodar/774tq9d#3171251       Getafe
# 1455           /matches/getafe-vs-ajax/2d0g44#3236273       Getafe
# 1476           /matches/getafe-vs-ajax/2d0g44#3236274         Ajax
# 1488          /matches/getafe-vs-inter/2dg1jb#3284791        Inter
# 1494          /matches/getafe-vs-inter/2dg1jb#3284799        Inter
#
#         away_team        date  source
# 1314  Trabzonspor  2019-09-19  FotMob
# 1347       Getafe  2019-10-03  FotMob
# 1373        Basel  2019-10-24  FotMob
# 1383       Getafe  2019-11-07  FotMob
# 1406       Getafe  2019-11-28  FotMob
# 1434    Krasnodar  2019-12-12  FotMob
# 1455         Ajax  2020-02-20  FotMob
# 1476       Getafe  2020-02-27  FotMob
# 1488       Getafe  2020-03-12  FotMob
# 1494       Getafe  2020-08-05  FotMob

# %%
leagues = [
    # 'ENG-Premier League',
    # 'ESP-La Liga',
    # 'Eredivisie',
    # 'FRA-Ligue 1',
    # 'GER-Bundesliga',
    # 'ITA-Serie A',
    # 'Primeira_Liga',
    # 'Pro_League',
    # 'UCL',
    # 'UECL'
    'UEL'
]

# %%
league = leagues[0]
season = [x for x in range(17,24)]
# season = [x for x in range(21,24)] # For UECL ONLY
ws = sd.WhoScored(leagues=league, seasons=season)
fb = sd.FBref(leagues=league, seasons=season)

# # get all 3 dfs
# print("Fetching DataFrames ... ")
whoscored_df = ws.read_schedule()
fbref_df = fb.read_schedule()
fotmob_df = getFotMobSeasonFixture(league,season)
# Out:
# [03/26/24 03:39:52] INFO     Saving cached data to C:\Users\Hp\soccerdata\data\WhoScored              _common.py:91
# [03/26/24 03:39:53] INFO     Saving cached data to C:\Users\Hp\soccerdata\data\FBref                  _common.py:91
#                     INFO     Retrieving game schedule of UEL - 1718 from the cache                 whoscored.py:438
#                     INFO     Retrieving game schedule of UEL - 1819 from the cache                 whoscored.py:438
#                     INFO     Retrieving game schedule of UEL - 1920 from the cache                 whoscored.py:438
#                     INFO     Retrieving game schedule of UEL - 2021 from the cache                 whoscored.py:438
#                     INFO     Retrieving game schedule of UEL - 2122 from the cache                 whoscored.py:438
#                     INFO     Retrieving game schedule of UEL - 2223 from the cache                 whoscored.py:438
# [03/26/24 03:40:16] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22687/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Final Stage'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22687/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Alhamisi, Feb 15 2024                      whoscored.py:327
# [03/26/24 03:40:17] INFO     Scraping game schedule for Alhamisi, Feb 22 2024                      whoscored.py:327
# [03/26/24 03:40:18] INFO     Scraping game schedule for Jumatano, Mac 6 2024                       whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Mac 7 2024                       whoscored.py:327
# [03/26/24 03:40:19] INFO     Scraping game schedule for Alhamisi, Mac 14 2024                      whoscored.py:327
# [03/26/24 03:40:21] INFO     Scraping game schedule for Alhamisi, Apr 11 2024                      whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Apr 18 2024                      whoscored.py:327
# [03/26/24 03:40:29] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22539/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Group Stages'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22539/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Alhamisi, Sep 21 2023                      whoscored.py:327
# [03/26/24 03:40:31] INFO     Scraping game schedule for Alhamisi, Okt 5 2023                       whoscored.py:327
# [03/26/24 03:40:34] INFO     Scraping game schedule for Alhamisi, Okt 26 2023                      whoscored.py:327
# [03/26/24 03:40:36] INFO     Scraping game schedule for Alhamisi, Nov 9 2023                       whoscored.py:327
# [03/26/24 03:40:38] INFO     Scraping game schedule for Alhamisi, Nov 30 2023                      whoscored.py:327
# [03/26/24 03:40:41] INFO     Scraping game schedule for Jumatano, Des 6 2023                       whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Des 14 2023                      whoscored.py:327
# [03/26/24 03:40:49] INFO     Scraping game schedule with stage={'url':                             whoscored.py:408
#                              '/Regions/250/Tournaments/30/Seasons/9778/Stages/22356/Show/Europe-Eu
#                              ropa-League-2023-2024', 'name': 'Europa League Qualification'} from
#                              https://www.whoscored.com/Regions/250/Tournaments/30/Seasons/9778/Sta
#                              ges/22356/Fixtures/Europe-Europa-League-2023-2024
#                     INFO     Scraping game schedule for Jumanne, Ago 8 2023                        whoscored.py:327
#                     INFO     Scraping game schedule for Alhamisi, Ago 10 2023                      whoscored.py:327
# [03/26/24 03:40:50] INFO     Scraping game schedule for Alhamisi, Ago 17 2023                      whoscored.py:327
# [03/26/24 03:40:51] INFO     Scraping game schedule for Alhamisi, Ago 24 2023                      whoscored.py:327
# [03/26/24 03:40:52] INFO     Scraping game schedule for Alhamisi, Ago 31 2023                      whoscored.py:327
# Returning 7 DFs combination

# %%
print("Preparing Fetched DataFrames ... ")
# # prepare DFs
WS = pre_process_dataframe_for_schedules('WS',whoscored_df)
FB = pre_process_dataframe_for_schedules('FB',fbref_df)
FM = pre_process_dataframe_for_schedules('FM',fotmob_df)
# 1/0
print(league)
if league == 'UCL' or league =='UEL' or league == 'UECL':
    FM_dfs = []
    WS_dfs = []
    for season in FM['season'].unique():
        temp_df = FM[FM['season'] == season]
        group_stage_start = min(FB[FB['season'] == season]['date'])
        print(f"Season {season} | Group Stage Start {group_stage_start}")
        sw_FM_df = temp_df[temp_df['date'].dt.date >=group_stage_start.date()]
        FM_dfs.append(sw_FM_df)
        if league == "UECL" :
            t_ws_df = WS[WS['season'] == season]
            print(t_ws_df.shape)
            sw_WS_df = t_ws_df[t_ws_df['date'] >=group_stage_start]
            print("MIN: ",min(t_ws_df['date']).date(),"MAX : ",max(t_ws_df['date']).date(), " VS  ",group_stage_start.date())
            WS_dfs.append(sw_WS_df)
        print(f"WS : {WS[WS['season'] == season].shape} | FB : {FB[FB['season'] == season].shape} | FM : {sw_FM_df.shape}")
    FM = pd.concat(FM_dfs)
    if league != "UECL":
        WS = WS[WS['stage'].str.contains('Final|Group Stages', case=False)]
    else:
        print([x.shape for x in WS_dfs])
        WS = pd.concat(WS_dfs)
# Out:
# Preparing Fetched DataFrames ...
# UEL
# Season 17-18 | Group Stage Start 2017-09-14 17:00:00+00:00
# WS : (473, 9) | FB : (205, 19) | FM : (205, 8)
# Season 18-19 | Group Stage Start 2018-09-20 16:55:00+00:00
# WS : (519, 9) | FB : (205, 19) | FM : (205, 8)
# Season 19-20 | Group Stage Start 2019-09-19 16:55:00+00:00
# WS : (513, 9) | FB : (199, 19) | FM : (199, 8)
# Season 20-21 | Group Stage Start 2020-10-22 15:55:00+00:00
# WS : (362, 9) | FB : (205, 19) | FM : (205, 8)
# Season 21-22 | Group Stage Start 2021-09-15 15:30:00+00:00
# WS : (177, 9) | FB : (141, 19) | FM : (141, 8)
# Season 22-23 | Group Stage Start 2022-09-08 16:45:00+00:00
# WS : (175, 9) | FB : (141, 19) | FM : (141, 8)
# Season 23-24 | Group Stage Start 2023-09-21 16:45:00+00:00
# WS : (170, 9) | FB : (136, 19) | FM : (141, 8)

# %%
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'])
# team_aliases = update_team_alias(WS,FB,FM,CONFIG['team_name_path'],write_mode=False)

# %%
with open(CONFIG['team_name_path'],'r') as f :
    team_aliases = json.load(f)

# %%
# merge dfs
print("Merging Fetched DataFrames ... ")
merged_df = combine_dataframes(WS,FB,FM,team_aliases)
# print("DFGHJKL",str(merged_df))
# Out:
# Merging Fetched DataFrames ...
# (1232, 9)
# Guilty index :  1488
#  HT ALias :  ['Getafe']
#  AT ALias :  ['Inter']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Getafe-Inter
# date                                                                                           2020-03-19
# home_team                                                                                          Getafe
# away_team                                                                                           Inter
# game_id                                                                                           1456775
# url          https://1xbet.whoscored.com/Matches/1456775/Show/Europe-Europa-League-2019-2020-Getafe-Inter
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1488, dtype: object
#
# Problem | Home : Getafe | Away : Inter | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW
# Guilty index :  1489
#  HT ALias :  ['Roma', 'AS Roma']
#  AT ALias :  ['Sevilla']
#
# league                                                                                                UEL
# season                                                                                              19-20
# game                                                                              2020-03-19 Roma-Sevilla
# date                                                                                           2020-03-19
# home_team                                                                                            Roma
# away_team                                                                                         Sevilla
# game_id                                                                                           1456776
# url          https://1xbet.whoscored.com/Matches/1456776/Show/Europe-Europa-League-2019-2020-Roma-Sevilla
# stage                                                                           Europa League Final Stage
# source                                                                                          WhoScored
# Name: 1489, dtype: object
#
# Problem | Home : Roma | Away : Sevilla | Date : 2020-03-19
#  DFs | WhoScored : False | FBRef : False | FotMob : True.
#
# FB ROW

# %%
# merged_df.to_csv(rf"./combined_sch/combined_{league}.csv")

# %%
league
# Out:
# 'UEL'

# %%
# merged_dfs = {}

# %%
merged_dfs[league] = merged_df

# %%
merged_dfs.keys()
# Out:
# dict_keys(['ENG-Premier League', 'ESP-La Liga', 'Eredivisie', 'FRA-Ligue 1', 'GER-Bundesliga', 'ITA-Serie A', 'Primeira_Liga', 'Pro_League', 'UCL', 'UEL'])

# %%
# # get missing data info
# print("Get missing games |DataFrames ... ")
# miss_WS = WS[~WS['game_id'].isin(merged_df['whoscored_id'])]
# miss_FM = FM[~FM['id'].isin(merged_df['fotmob_id'])]
# miss_FB = FB[~FB['game_id'].isin(merged_df['fbref_id'])]

# miss_WS.to_csv(rf"./missing_matches/miss_WS_{league}.csv")
# miss_FB.to_csv(rf"./missing_matches/miss_FB_{league}.csv")
# miss_FM.to_csv(rf"./missing_matches/miss_FM_{league}.csv")
# Out:
# Get missing games |DataFrames ...

# %%
for k,v in merged_dfs.items():
    print(k," : ",max(v['date']))
# Out:
# ENG-Premier League  :  2024-03-17
# ESP-La Liga  :  2024-03-17
# Eredivisie  :  2024-03-17
# FRA-Ligue 1  :  2024-03-17
# GER-Bundesliga  :  2024-03-17
# ITA-Serie A  :  2024-03-17
# Primeira_Liga  :  2024-03-17
# Pro_League  :  2024-03-30
# UCL  :  2024-03-13
# UEL  :  2024-03-14

# %%
all_merged = pd.concat(list(merged_dfs.values()))

# %%
all_merged.shape
# Out:
# (20370, 13)

# %%
all_merged.to_csv(r"./combined_sch/all_merged_2.csv)
